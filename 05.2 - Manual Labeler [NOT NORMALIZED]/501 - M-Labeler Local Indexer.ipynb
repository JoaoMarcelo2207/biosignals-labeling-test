# %% [markdown]
# # Import dependencies

# %%
import os
import sys
import pandas as pd

# Import library with current code functions
sys.path.append(os.path.join("..", "lib"))
import indexer_functions as indx_fun, general_functions as gf, files_paths as fp

# %% [markdown]
# ## Defining variables

# %%
FILE_LIST_VD_REF_SEED = gf.find_files_in_all_subdirectories([fp.VIDEO_SOURCE_SEED], '*' + '.mp4')
FILE_LIST_VD_INFO = gf.find_files_in_all_subdirectories([fp.DATASET_SEED_NOT_NORMALIZED], fp.VD_INFO)
VIDEOS_NAMES = [gf.get_file_name(current_path_location, '.mp4') for current_path_location in FILE_LIST_VD_REF_SEED]

# %% [markdown]
# ## Check which videos has the INFO file

# %%
for file in FILE_LIST_VD_INFO:
    video_info = pd.read_csv(file)
    video_id = video_info['link_video'][0]
    if video_id in VIDEOS_NAMES:
        VIDEOS_NAMES.remove(video_id)

# %%
number_of_videos = len(VIDEOS_NAMES)
VIDEO_ID = gf.collect_next_video_id(FILE_LIST_VD_INFO)
FOLDER_PREFIX = "VD_R_"
ORIGIN_VID = 'D'

for i, video_name in enumerate(VIDEOS_NAMES):
    current_path_location = os.path.join(fp.VIDEO_SOURCE_SEED, video_name + '.mp4')

    print (str(i+1) + " of " + str(number_of_videos) + " : " + "Starting to process the " + video_name)
    
    INFO_COLLECTED_SUCCESSFULLY, SHAPE_ORIGINAL, DURATION_ORIGINAL, FPS_ORIGINAL = gf.collect_video_info(current_path_location)

    if INFO_COLLECTED_SUCCESSFULLY:
        indx_fun.create_vd_info(VIDEO_ID, DURATION_ORIGINAL, FPS_ORIGINAL, SHAPE_ORIGINAL, FOLDER_PREFIX, fp.DATASET_SEED_NOT_NORMALIZED, fp.VD_INFO, video_name, ORIGIN_VID)
        VIDEO_ID += 1
# Out:
# 1 of 211 : Starting to process the 295xopXuU5E_happy_1
# 2 of 211 : Starting to process the 295xopXuU5E_happy_2
# 3 of 211 : Starting to process the 295xopXuU5E_happy_3
# 4 of 211 : Starting to process the 295xopXuU5E_neutral_1
# 5 of 211 : Starting to process the 295xopXuU5E_neutral_2
# 6 of 211 : Starting to process the 295xopXuU5E_neutral_3
# 7 of 211 : Starting to process the 295xopXuU5E_others_1
# 8 of 211 : Starting to process the 295xopXuU5E_others_2
# 9 of 211 : Starting to process the 2q_eNp4mDGU_happy_1
# 10 of 211 : Starting to process the 2q_eNp4mDGU_happy_2
# 11 of 211 : Starting to process the 2q_eNp4mDGU_happy_3
# 12 of 211 : Starting to process the 2q_eNp4mDGU_neutral_1
# 13 of 211 : Starting to process the 2q_eNp4mDGU_neutral_2
# 14 of 211 : Starting to process the 2q_eNp4mDGU_neutral_3
# 15 of 211 : Starting to process the 2q_eNp4mDGU_others_1
# 16 of 211 : Starting to process the 2q_eNp4mDGU_others_2
# 17 of 211 : Starting to process the 2q_eNp4mDGU_others_3
# 18 of 211 : Starting to process the 4W09LPCCJ4U_happy_1
# 19 of 211 : Starting to process the 4W09LPCCJ4U_happy_2
# 20 of 211 : Starting to process the 4W09LPCCJ4U_happy_3
# 21 of 211 : Starting to process the 4W09LPCCJ4U_neutral_1
# 22 of 211 : Starting to process the 4W09LPCCJ4U_neutral_2
# 23 of 211 : Starting to process the 4W09LPCCJ4U_neutral_3
# 24 of 211 : Starting to process the 4W09LPCCJ4U_others_1
# 25 of 211 : Starting to process the 4W09LPCCJ4U_others_2
# 26 of 211 : Starting to process the 5KY8V6HBAro_happy_1
# 27 of 211 : Starting to process the 5KY8V6HBAro_neutral_1
# 28 of 211 : Starting to process the 5KY8V6HBAro_neutral_2
# 29 of 211 : Starting to process the 5KY8V6HBAro_neutral_3
# 30 of 211 : Starting to process the 5KY8V6HBAro_others_1
# 31 of 211 : Starting to process the 5KY8V6HBAro_others_2
# 32 of 211 : Starting to process the 5KY8V6HBAro_others_3
# 33 of 211 : Starting to process the 61gzN0c9K3g_neutral_1
# 34 of 211 : Starting to process the 61gzN0c9K3g_neutral_2
# 35 of 211 : Starting to process the 61gzN0c9K3g_neutral_3
# 36 of 211 : Starting to process the 61gzN0c9K3g_others_1
# 37 of 211 : Starting to process the 61gzN0c9K3g_others_2
# 38 of 211 : Starting to process the 61gzN0c9K3g_others_3
# 39 of 211 : Starting to process the 61gzN0c9K3g_others_4
# 40 of 211 : Starting to process the 61gzN0c9K3g_others_5
# 41 of 211 : Starting to process the 6koC82XF9bc_happy_1
# 42 of 211 : Starting to process the 6koC82XF9bc_happy_2
# 43 of 211 : Starting to process the 6koC82XF9bc_happy_3
# 44 of 211 : Starting to process the 6koC82XF9bc_neutral_1
# 45 of 211 : Starting to process the 6koC82XF9bc_neutral_2
# 46 of 211 : Starting to process the 6koC82XF9bc_neutral_3
# 47 of 211 : Starting to process the 6koC82XF9bc_others_1
# 48 of 211 : Starting to process the 6koC82XF9bc_others_2
# 49 of 211 : Starting to process the 6koC82XF9bc_others_3
# 50 of 211 : Starting to process the 6koC82XF9bc_others_4
# 51 of 211 : Starting to process the 8hDfY5JR4Ic_happy_1
# 52 of 211 : Starting to process the 8hDfY5JR4Ic_happy_2
# 53 of 211 : Starting to process the 8hDfY5JR4Ic_happy_3
# 54 of 211 : Starting to process the 8hDfY5JR4Ic_neutral_1
# 55 of 211 : Starting to process the 8hDfY5JR4Ic_neutral_2
# 56 of 211 : Starting to process the 8hDfY5JR4Ic_neutral_3
# 57 of 211 : Starting to process the 8hDfY5JR4Ic_others_1
# 58 of 211 : Starting to process the 8hDfY5JR4Ic_others_2
# 59 of 211 : Starting to process the 8hDfY5JR4Ic_others_3
# 60 of 211 : Starting to process the AjHji_Ff4Mc_happy_1
# 61 of 211 : Starting to process the AjHji_Ff4Mc_happy_2
# 62 of 211 : Starting to process the AjHji_Ff4Mc_neutral_1
# 63 of 211 : Starting to process the AjHji_Ff4Mc_neutral_2
# 64 of 211 : Starting to process the AjHji_Ff4Mc_neutral_3
# 65 of 211 : Starting to process the AjHji_Ff4Mc_others_1
# 66 of 211 : Starting to process the AjHji_Ff4Mc_others_2
# 67 of 211 : Starting to process the AjHji_Ff4Mc_others_3
# 68 of 211 : Starting to process the Gerôncio Henrique Neto_neutral_1
# 69 of 211 : Starting to process the Gerôncio Henrique Neto_neutral_2
# 70 of 211 : Starting to process the Gerôncio Henrique Neto_neutral_3
# 71 of 211 : Starting to process the Gerôncio Henrique Neto_others_1
# 72 of 211 : Starting to process the Gerôncio Henrique Neto_others_2
# 73 of 211 : Starting to process the Gerôncio Henrique Neto_others_3
# 74 of 211 : Starting to process the Gerôncio Henrique Neto_others_4
# 75 of 211 : Starting to process the Gerôncio Henrique Neto_others_5
# 76 of 211 : Starting to process the H9HzZV6pW7g_happy_1
# 77 of 211 : Starting to process the H9HzZV6pW7g_happy_2
# 78 of 211 : Starting to process the H9HzZV6pW7g_happy_3
# 79 of 211 : Starting to process the H9HzZV6pW7g_neutral_1
# 80 of 211 : Starting to process the H9HzZV6pW7g_neutral_2
# 81 of 211 : Starting to process the H9HzZV6pW7g_neutral_3
# 82 of 211 : Starting to process the H9HzZV6pW7g_others_1
# 83 of 211 : Starting to process the H9HzZV6pW7g_others_2
# 84 of 211 : Starting to process the JrdZ63GIL8k_happy_1
# 85 of 211 : Starting to process the JrdZ63GIL8k_happy_2
# 86 of 211 : Starting to process the JrdZ63GIL8k_happy_3
# 87 of 211 : Starting to process the JrdZ63GIL8k_neutral_1
# 88 of 211 : Starting to process the JrdZ63GIL8k_neutral_2
# 89 of 211 : Starting to process the JrdZ63GIL8k_neutral_3
# 90 of 211 : Starting to process the JrdZ63GIL8k_others_1
# 91 of 211 : Starting to process the JrdZ63GIL8k_others_2
# 92 of 211 : Starting to process the Ka19xzJ_DQw_neutral_1
# 93 of 211 : Starting to process the Ka19xzJ_DQw_neutral_2
# 94 of 211 : Starting to process the Ka19xzJ_DQw_neutral_3
# 95 of 211 : Starting to process the Ka19xzJ_DQw_others_1
# 96 of 211 : Starting to process the Ka19xzJ_DQw_others_2
# 97 of 211 : Starting to process the Ka19xzJ_DQw_others_3
# 98 of 211 : Starting to process the Ka19xzJ_DQw_others_4
# 99 of 211 : Starting to process the Ka19xzJ_DQw_others_5
# 100 of 211 : Starting to process the Kfp0e9qlVyc_neutral_1
# 101 of 211 : Starting to process the Kfp0e9qlVyc_neutral_2
# 102 of 211 : Starting to process the Kfp0e9qlVyc_neutral_3
# 103 of 211 : Starting to process the Kfp0e9qlVyc_others_1
# 104 of 211 : Starting to process the MwHKnkuzM3c_happy_1
# 105 of 211 : Starting to process the MwHKnkuzM3c_happy_2
# 106 of 211 : Starting to process the MwHKnkuzM3c_neutral_1
# 107 of 211 : Starting to process the MwHKnkuzM3c_neutral_2
# 108 of 211 : Starting to process the MwHKnkuzM3c_neutral_3
# 109 of 211 : Starting to process the MwHWKnkuzM3c_others_1
# 110 of 211 : Starting to process the SBVFwCGW8_A_happy_1
# 111 of 211 : Starting to process the SBVFwCGW8_A_happy_2
# 112 of 211 : Starting to process the SBVFwCGW8_A_happy_3
# 113 of 211 : Starting to process the SBVFwCGW8_A_neutral_1
# 114 of 211 : Starting to process the SBVFwCGW8_A_neutral_2
# 115 of 211 : Starting to process the SBVFwCGW8_A_neutral_3
# 116 of 211 : Starting to process the WUs_B1G4564_happy_1
# 117 of 211 : Starting to process the WUs_B1G4564_happy_2
# 118 of 211 : Starting to process the WUs_B1G4564_happy_3
# 119 of 211 : Starting to process the WUs_B1G4564_neutral_1
# 120 of 211 : Starting to process the WUs_B1G4564_neutral_2
# 121 of 211 : Starting to process the WUs_B1G4564_neutral_3
# 122 of 211 : Starting to process the caX-uN1uCqY_neutral_1
# 123 of 211 : Starting to process the caX-uN1uCqY_neutral_2
# 124 of 211 : Starting to process the caX-uN1uCqY_neutral_3
# 125 of 211 : Starting to process the caX-uN1uCqY_others_1
# 126 of 211 : Starting to process the caX-uN1uCqY_others_2
# 127 of 211 : Starting to process the hBdjcicU78E_happy_1
# 128 of 211 : Starting to process the hBdjcicU78E_neutral_1
# 129 of 211 : Starting to process the hBdjcicU78E_neutral_2
# 130 of 211 : Starting to process the hBdjcicU78E_neutral_3
# 131 of 211 : Starting to process the hBdjcicU78E_others_1
# 132 of 211 : Starting to process the hBdjcicU78E_others_2
# 133 of 211 : Starting to process the hBdjcicU78E_others_3
# 134 of 211 : Starting to process the hBdjcicU78E_others_4
# 135 of 211 : Starting to process the museu_da_pessoa_1_happy_1
# 136 of 211 : Starting to process the museu_da_pessoa_1_happy_2
# 137 of 211 : Starting to process the museu_da_pessoa_1_happy_3
# 138 of 211 : Starting to process the museu_da_pessoa_1_neutral_1
# 139 of 211 : Starting to process the museu_da_pessoa_1_neutral_2
# 140 of 211 : Starting to process the museu_da_pessoa_1_neutral_3
# 141 of 211 : Starting to process the museu_da_pessoa_1_others_1
# 142 of 211 : Starting to process the museu_da_pessoa_1_others_2
# 143 of 211 : Starting to process the museu_da_pessoa_2_happy_1
# 144 of 211 : Starting to process the museu_da_pessoa_2_happy_2
# 145 of 211 : Starting to process the museu_da_pessoa_2_happy_3
# 146 of 211 : Starting to process the museu_da_pessoa_2_neutral_1
# 147 of 211 : Starting to process the museu_da_pessoa_2_neutral_2
# 148 of 211 : Starting to process the museu_da_pessoa_2_neutral_3
# 149 of 211 : Starting to process the museu_da_pessoa_2_others_1
# 150 of 211 : Starting to process the museu_da_pessoa_2_others_2
# 151 of 211 : Starting to process the museu_da_pessoa_2_others_3
# 152 of 211 : Starting to process the museu_da_pessoa_2_others_4
# 153 of 211 : Starting to process the museu_da_pessoa_2_others_5
# 154 of 211 : Starting to process the museu_da_pessoa_2_others_6
# 155 of 211 : Starting to process the museu_da_pessoa_3_happy_1
# 156 of 211 : Starting to process the museu_da_pessoa_3_happy_2
# 157 of 211 : Starting to process the museu_da_pessoa_3_neutral_1
# 158 of 211 : Starting to process the museu_da_pessoa_3_neutral_2
# 159 of 211 : Starting to process the museu_da_pessoa_3_neutral_3
# 160 of 211 : Starting to process the museu_da_pessoa_3_others_1
# 161 of 211 : Starting to process the museu_da_pessoa_3_others_2
# 162 of 211 : Starting to process the museu_da_pessoa_3_others_3
# 163 of 211 : Starting to process the museu_da_pessoa_3_others_4
# 164 of 211 : Starting to process the museu_da_pessoa_3_others_5
# 165 of 211 : Starting to process the museu_da_pessoa_4_happy_1
# 166 of 211 : Starting to process the museu_da_pessoa_4_happy_2
# 167 of 211 : Starting to process the museu_da_pessoa_4_neutral_1
# 168 of 211 : Starting to process the museu_da_pessoa_4_neutral_2
# 169 of 211 : Starting to process the museu_da_pessoa_4_neutral_3
# 170 of 211 : Starting to process the museu_da_pessoa_4_others_1
# 171 of 211 : Starting to process the museu_da_pessoa_4_others_2
# 172 of 211 : Starting to process the museu_da_pessoa_4_others_3
# 173 of 211 : Starting to process the museu_da_pessoa_4_others_4
# 174 of 211 : Starting to process the museu_da_pessoa_5_happy_1
# 175 of 211 : Starting to process the museu_da_pessoa_5_happy_2
# 176 of 211 : Starting to process the museu_da_pessoa_5_neutral_1
# 177 of 211 : Starting to process the museu_da_pessoa_5_neutral_2
# 178 of 211 : Starting to process the museu_da_pessoa_5_neutral_3
# 179 of 211 : Starting to process the museu_da_pessoa_5_others_1
# 180 of 211 : Starting to process the museu_da_pessoa_5_others_2
# 181 of 211 : Starting to process the museu_da_pessoa_5_others_3
# 182 of 211 : Starting to process the museu_da_pessoa_6_happy_1
# 183 of 211 : Starting to process the museu_da_pessoa_6_happy_2
# 184 of 211 : Starting to process the museu_da_pessoa_6_happy_3
# 185 of 211 : Starting to process the museu_da_pessoa_6_neutral_1
# 186 of 211 : Starting to process the museu_da_pessoa_6_neutral_2
# 187 of 211 : Starting to process the museu_da_pessoa_6_neutral_3
# 188 of 211 : Starting to process the museu_da_pessoa_6_others_1
# 189 of 211 : Starting to process the museu_da_pessoa_7_happy_1
# 190 of 211 : Starting to process the museu_da_pessoa_7_happy_2
# 191 of 211 : Starting to process the museu_da_pessoa_7_neutral_1
# 192 of 211 : Starting to process the museu_da_pessoa_7_neutral_2
# 193 of 211 : Starting to process the museu_da_pessoa_7_neutral_3
# 194 of 211 : Starting to process the museu_da_pessoa_7_others_1
# 195 of 211 : Starting to process the museu_da_pessoa_7_others_2
# 196 of 211 : Starting to process the p9cvrKEFUhc_neutral_1
# 197 of 211 : Starting to process the p9cvrKEFUhc_neutral_2
# 198 of 211 : Starting to process the p9cvrKEFUhc_neutral_3
# 199 of 211 : Starting to process the p9cvrKEFUhc_others_1
# 200 of 211 : Starting to process the p9cvrKEFUhc_others_2
# 201 of 211 : Starting to process the rL3MTusPLu4_happy_1
# 202 of 211 : Starting to process the rL3MTusPLu4_happy_2
# 203 of 211 : Starting to process the rL3MTusPLu4_happy_3
# 204 of 211 : Starting to process the rL3MTusPLu4_neutral_1
# 205 of 211 : Starting to process the rL3MTusPLu4_neutral_2
# 206 of 211 : Starting to process the rL3MTusPLu4_neutral_3
# 207 of 211 : Starting to process the rL3MTusPLu4_others_1
# 208 of 211 : Starting to process the zKoqa_MyYtw_happy_1
# 209 of 211 : Starting to process the zKoqa_MyYtw_neutral_1
# 210 of 211 : Starting to process the zKoqa_MyYtw_neutral_2
# 211 of 211 : Starting to process the zKoqa_MyYtw_neutral_3
