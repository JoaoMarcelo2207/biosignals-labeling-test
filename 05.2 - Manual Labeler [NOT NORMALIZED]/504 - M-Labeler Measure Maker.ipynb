# %%
import os
import sys
import pandas as pd

# Import library with current code functions
sys.path.append(os.path.join("..", "lib"))
import measure_maker_functions as meas_mak_fun, files_paths as fp, general_functions as gf

# %% [markdown]
# ## Filtering the list of files to be measured

# %%
FILE_LIST_FEATURE_L3 = gf.find_files_in_all_subdirectories([fp.DATASET_SEED_NOT_NORMALIZED], fp.VD_FEATURES_L1)
FILE_LIST_FEATURE_L3_FILTERED = [path for path in FILE_LIST_FEATURE_L3 if not os.path.exists(os.path.join(os.path.dirname(path), fp.VD_MEASURE_L0))]

# %% [markdown]
# ## Measure points

# %%
# Iterate over the filtered feature list
for i, vd_feature_L2_path in enumerate(FILE_LIST_FEATURE_L3_FILTERED):

    # Internal mouth 1 vertical 63 and 67
    m1 = meas_mak_fun.measure_two_points_from_csv(vd_feature_L2_path, 63-1, 67-1, 'm1')
    
    # External mouth horizontal 49 and 55
    m3 = meas_mak_fun.measure_two_points_from_csv(vd_feature_L2_path, 49-1, 55-1, 'm3')

    # Upper lips 1 vertical 52 and 63
    m4 = meas_mak_fun.measure_two_points_from_csv(vd_feature_L2_path, 52-1, 63-1, 'm4')
    
    # Lower lips 1 vertical 67 and 58
    m5 = meas_mak_fun.measure_two_points_from_csv(vd_feature_L2_path, 67-1, 58-1, 'm5')
    
    # Upper lips horizontal 62 and 64
    m6 = meas_mak_fun.measure_two_points_from_csv(vd_feature_L2_path, 62-1, 64-1, 'm6')
    
    # Lower lips horizontal 59 and 57
    m7 = meas_mak_fun.measure_two_points_from_csv(vd_feature_L2_path, 59-1, 57-1, 'm7')
    
    # Upper lip and nose 34 and 52
    m8 = meas_mak_fun.measure_two_points_from_csv(vd_feature_L2_path, 34-1, 52-1, 'm8')
    
    # Lower lip and nose 34 and 58
    m9 = meas_mak_fun.measure_two_points_from_csv(vd_feature_L2_path, 34-1, 58-1, 'm9')
    
    # Internal lower lip and nose 34 and 67
    m10 = meas_mak_fun.measure_two_points_from_csv(vd_feature_L2_path, 34-1, 67-1, 'm10')
    
    # Mouth: Draw average between 63 and 67 and measure vertical parallel with 34
    m11 = meas_mak_fun.measure_vertical_two_arrays_mean(vd_feature_L2_path, [63-1, 67-1], [34-1], 'm11')
    
    # Mouth-Nose: Measure vertical parallel between 34 and 49
    m12 = meas_mak_fun.measure_vertical_two_arrays_mean(vd_feature_L2_path, [34-1], [49-1], 'm12')
    
    # Mouth-Nose: Measure right vertical parallel between 34 and 55
    m13 = meas_mak_fun.measure_vertical_two_arrays_mean(vd_feature_L2_path, [34-1], [55-1], 'm13')
    
    # Mouth: Draw average between 49 and 55 and measure vertical parallel with 52
    m14 = meas_mak_fun.measure_vertical_two_arrays_mean(vd_feature_L2_path, [49-1, 55-1], [52-1], 'm14')
    
    # Mouth: Draw average between 49 and 55 and measure vertical parallel with 58
    m15 = meas_mak_fun.measure_vertical_two_arrays_mean(vd_feature_L2_path, [49-1, 55-1], [58-1], 'm15')
    
    # Mouth: Draw average between 49 and 55 and measure vertical parallel with 67
    m16 = meas_mak_fun.measure_vertical_two_arrays_mean(vd_feature_L2_path, [49-1, 55-1], [67], 'm16')
    
    # Mouth: Draw average between 49 and 55 and measure vertical parallel with 63
    m17 = meas_mak_fun.measure_vertical_two_arrays_mean(vd_feature_L2_path, [49-1, 55-1], [63], 'm17')
    
    # Left eye vertical 38 and 42
    e1 = meas_mak_fun.measure_two_points_from_csv(vd_feature_L2_path, 38-1, 42-1, 'e1')
    
    # Right eye vertical 44 and 48
    e2 = meas_mak_fun.measure_two_points_from_csv(vd_feature_L2_path, 44-1, 48-1, 'e2')
    
    # Eye: Vertical distance right eye 2 with average between points 45-44 and 47-48
    e3 = meas_mak_fun.measure_vertical_two_arrays_mean(vd_feature_L2_path, [45-1, 44-1], [47-1, 48-1], 'e3')
    
    # Eyebrow-Nose: Measure left vertical parallel between 28 and 20
    b1 = meas_mak_fun.measure_vertical_two_arrays_mean(vd_feature_L2_path, [28-1], [20-1], 'b1')
    
    # Eyebrow-Nose: Measure right vertical parallel between 28 and 25
    b2 = meas_mak_fun.measure_vertical_two_arrays_mean(vd_feature_L2_path, [28-1], [25-1], 'b2')
    
    # Eyebrows horizontal 22 and 23
    b3 = meas_mak_fun.measure_two_points_from_csv(vd_feature_L2_path, 22-1, 23-1, 'b3')
    
    # Join the dataframes
    MEASURE_DATA_FRAME_CURRENT = pd.concat([m1, m3, m4, m5, m6, m7, m8, m9, m10, m11, m12, m13, m14, m15, m16, m17, 
                                           e1, e2, e3,
                                          b1, b2, b3], axis=1)
    
    # Save frame_seq column on MEASURE_DATA_FRAME
    csv_data_frame_in = pd.read_csv(vd_feature_L2_path)

    MEASURE_DATA_FRAME_CURRENT.insert(0, 'video_id',  csv_data_frame_in['video_id'])
    MEASURE_DATA_FRAME_CURRENT.insert(1, 'frame_seq',  csv_data_frame_in['frame_seq'])
    MEASURE_DATA_FRAME_CURRENT.insert(2, 'time_seconds',  csv_data_frame_in['time_seconds'])
    
    # Collect the current path
    base_path_folder_output = os.path.join(os.path.dirname(vd_feature_L2_path), fp.VD_MEASURE_L0)
    
    # Count Process
    print(str(i+1) + " of " + str(len(FILE_LIST_FEATURE_L3_FILTERED)) + ": " + base_path_folder_output)
    
    # Generate the OUTPUT CSV in the current folder
    MEASURE_DATA_FRAME_CURRENT.to_csv(base_path_folder_output)
# Out:
# 1 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000001\VD_MEASURE_L0.CSV
# 2 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000002\VD_MEASURE_L0.CSV
# 3 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000003\VD_MEASURE_L0.CSV
# 4 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000004\VD_MEASURE_L0.CSV
# 5 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000005\VD_MEASURE_L0.CSV
# 6 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000006\VD_MEASURE_L0.CSV
# 7 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000007\VD_MEASURE_L0.CSV
# 8 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000008\VD_MEASURE_L0.CSV
# 9 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000009\VD_MEASURE_L0.CSV
# 10 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000010\VD_MEASURE_L0.CSV
# 11 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000011\VD_MEASURE_L0.CSV
# 12 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000012\VD_MEASURE_L0.CSV
# 13 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000013\VD_MEASURE_L0.CSV
# 14 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000014\VD_MEASURE_L0.CSV
# 15 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000015\VD_MEASURE_L0.CSV
# 16 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000016\VD_MEASURE_L0.CSV
# 17 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000017\VD_MEASURE_L0.CSV
# 18 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000018\VD_MEASURE_L0.CSV
# 19 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000019\VD_MEASURE_L0.CSV
# 20 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000020\VD_MEASURE_L0.CSV
# 21 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000021\VD_MEASURE_L0.CSV
# 22 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000022\VD_MEASURE_L0.CSV
# 23 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000023\VD_MEASURE_L0.CSV
# 24 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000024\VD_MEASURE_L0.CSV
# 25 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000025\VD_MEASURE_L0.CSV
# 26 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000026\VD_MEASURE_L0.CSV
# 27 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000027\VD_MEASURE_L0.CSV
# 28 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000028\VD_MEASURE_L0.CSV
# 29 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000029\VD_MEASURE_L0.CSV
# 30 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000030\VD_MEASURE_L0.CSV
# 31 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000031\VD_MEASURE_L0.CSV
# 32 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000032\VD_MEASURE_L0.CSV
# 33 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000033\VD_MEASURE_L0.CSV
# 34 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000034\VD_MEASURE_L0.CSV
# 35 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000035\VD_MEASURE_L0.CSV
# 36 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000036\VD_MEASURE_L0.CSV
# 37 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000037\VD_MEASURE_L0.CSV
# 38 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000038\VD_MEASURE_L0.CSV
# 39 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000039\VD_MEASURE_L0.CSV
# 40 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000040\VD_MEASURE_L0.CSV
# 41 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000041\VD_MEASURE_L0.CSV
# 42 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000042\VD_MEASURE_L0.CSV
# 43 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000043\VD_MEASURE_L0.CSV
# 44 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000044\VD_MEASURE_L0.CSV
# 45 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000045\VD_MEASURE_L0.CSV
# 46 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000046\VD_MEASURE_L0.CSV
# 47 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000047\VD_MEASURE_L0.CSV
# 48 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000048\VD_MEASURE_L0.CSV
# 49 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000049\VD_MEASURE_L0.CSV
# 50 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000050\VD_MEASURE_L0.CSV
# 51 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000051\VD_MEASURE_L0.CSV
# 52 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000052\VD_MEASURE_L0.CSV
# 53 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000053\VD_MEASURE_L0.CSV
# 54 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000054\VD_MEASURE_L0.CSV
# 55 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000055\VD_MEASURE_L0.CSV
# 56 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000056\VD_MEASURE_L0.CSV
# 57 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000057\VD_MEASURE_L0.CSV
# 58 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000058\VD_MEASURE_L0.CSV
# 59 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000059\VD_MEASURE_L0.CSV
# 60 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000060\VD_MEASURE_L0.CSV
# 61 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000061\VD_MEASURE_L0.CSV
# 62 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000062\VD_MEASURE_L0.CSV
# 63 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000063\VD_MEASURE_L0.CSV
# 64 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000064\VD_MEASURE_L0.CSV
# 65 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000065\VD_MEASURE_L0.CSV
# 66 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000066\VD_MEASURE_L0.CSV
# 67 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000067\VD_MEASURE_L0.CSV
# 68 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000068\VD_MEASURE_L0.CSV
# 69 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000069\VD_MEASURE_L0.CSV
# 70 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000070\VD_MEASURE_L0.CSV
# 71 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000071\VD_MEASURE_L0.CSV
# 72 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000072\VD_MEASURE_L0.CSV
# 73 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000073\VD_MEASURE_L0.CSV
# 74 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000074\VD_MEASURE_L0.CSV
# 75 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000075\VD_MEASURE_L0.CSV
# 76 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000076\VD_MEASURE_L0.CSV
# 77 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000077\VD_MEASURE_L0.CSV
# 78 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000078\VD_MEASURE_L0.CSV
# 79 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000079\VD_MEASURE_L0.CSV
# 80 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000080\VD_MEASURE_L0.CSV
# 81 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000081\VD_MEASURE_L0.CSV
# 82 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000082\VD_MEASURE_L0.CSV
# 83 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000083\VD_MEASURE_L0.CSV
# 84 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000084\VD_MEASURE_L0.CSV
# 85 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000085\VD_MEASURE_L0.CSV
# 86 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000086\VD_MEASURE_L0.CSV
# 87 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000087\VD_MEASURE_L0.CSV
# 88 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000088\VD_MEASURE_L0.CSV
# 89 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000089\VD_MEASURE_L0.CSV
# 90 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000090\VD_MEASURE_L0.CSV
# 91 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000091\VD_MEASURE_L0.CSV
# 92 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000092\VD_MEASURE_L0.CSV
# 93 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000093\VD_MEASURE_L0.CSV
# 94 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000094\VD_MEASURE_L0.CSV
# 95 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000095\VD_MEASURE_L0.CSV
# 96 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000096\VD_MEASURE_L0.CSV
# 97 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000097\VD_MEASURE_L0.CSV
# 98 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000098\VD_MEASURE_L0.CSV
# 99 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000099\VD_MEASURE_L0.CSV
# 100 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000100\VD_MEASURE_L0.CSV
# 101 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000101\VD_MEASURE_L0.CSV
# 102 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000102\VD_MEASURE_L0.CSV
# 103 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000103\VD_MEASURE_L0.CSV
# 104 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000104\VD_MEASURE_L0.CSV
# 105 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000105\VD_MEASURE_L0.CSV
# 106 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000106\VD_MEASURE_L0.CSV
# 107 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000107\VD_MEASURE_L0.CSV
# 108 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000108\VD_MEASURE_L0.CSV
# 109 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000109\VD_MEASURE_L0.CSV
# 110 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000110\VD_MEASURE_L0.CSV
# 111 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000111\VD_MEASURE_L0.CSV
# 112 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000112\VD_MEASURE_L0.CSV
# 113 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000113\VD_MEASURE_L0.CSV
# 114 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000114\VD_MEASURE_L0.CSV
# 115 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000115\VD_MEASURE_L0.CSV
# 116 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000116\VD_MEASURE_L0.CSV
# 117 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000117\VD_MEASURE_L0.CSV
# 118 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000118\VD_MEASURE_L0.CSV
# 119 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000119\VD_MEASURE_L0.CSV
# 120 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000120\VD_MEASURE_L0.CSV
# 121 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000121\VD_MEASURE_L0.CSV
# 122 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000122\VD_MEASURE_L0.CSV
# 123 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000123\VD_MEASURE_L0.CSV
# 124 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000124\VD_MEASURE_L0.CSV
# 125 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000125\VD_MEASURE_L0.CSV
# 126 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000126\VD_MEASURE_L0.CSV
# 127 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000127\VD_MEASURE_L0.CSV
# 128 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000128\VD_MEASURE_L0.CSV
# 129 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000129\VD_MEASURE_L0.CSV
# 130 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000130\VD_MEASURE_L0.CSV
# 131 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000131\VD_MEASURE_L0.CSV
# 132 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000132\VD_MEASURE_L0.CSV
# 133 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000133\VD_MEASURE_L0.CSV
# 134 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000134\VD_MEASURE_L0.CSV
# 135 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000135\VD_MEASURE_L0.CSV
# 136 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000136\VD_MEASURE_L0.CSV
# 137 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000137\VD_MEASURE_L0.CSV
# 138 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000138\VD_MEASURE_L0.CSV
# 139 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000139\VD_MEASURE_L0.CSV
# 140 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000140\VD_MEASURE_L0.CSV
# 141 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000141\VD_MEASURE_L0.CSV
# 142 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000142\VD_MEASURE_L0.CSV
# 143 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000143\VD_MEASURE_L0.CSV
# 144 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000144\VD_MEASURE_L0.CSV
# 145 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000145\VD_MEASURE_L0.CSV
# 146 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000146\VD_MEASURE_L0.CSV
# 147 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000147\VD_MEASURE_L0.CSV
# 148 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000148\VD_MEASURE_L0.CSV
# 149 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000149\VD_MEASURE_L0.CSV
# 150 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000150\VD_MEASURE_L0.CSV
# 151 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000151\VD_MEASURE_L0.CSV
# 152 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000152\VD_MEASURE_L0.CSV
# 153 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000153\VD_MEASURE_L0.CSV
# 154 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000154\VD_MEASURE_L0.CSV
# 155 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000155\VD_MEASURE_L0.CSV
# 156 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000156\VD_MEASURE_L0.CSV
# 157 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000157\VD_MEASURE_L0.CSV
# 158 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000158\VD_MEASURE_L0.CSV
# 159 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000159\VD_MEASURE_L0.CSV
# 160 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000160\VD_MEASURE_L0.CSV
# 161 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000161\VD_MEASURE_L0.CSV
# 162 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000162\VD_MEASURE_L0.CSV
# 163 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000163\VD_MEASURE_L0.CSV
# 164 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000164\VD_MEASURE_L0.CSV
# 165 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000165\VD_MEASURE_L0.CSV
# 166 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000166\VD_MEASURE_L0.CSV
# 167 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000167\VD_MEASURE_L0.CSV
# 168 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000168\VD_MEASURE_L0.CSV
# 169 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000169\VD_MEASURE_L0.CSV
# 170 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000170\VD_MEASURE_L0.CSV
# 171 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000171\VD_MEASURE_L0.CSV
# 172 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000172\VD_MEASURE_L0.CSV
# 173 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000173\VD_MEASURE_L0.CSV
# 174 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000174\VD_MEASURE_L0.CSV
# 175 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000175\VD_MEASURE_L0.CSV
# 176 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000176\VD_MEASURE_L0.CSV
# 177 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000177\VD_MEASURE_L0.CSV
# 178 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000178\VD_MEASURE_L0.CSV
# 179 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000179\VD_MEASURE_L0.CSV
# 180 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000180\VD_MEASURE_L0.CSV
# 181 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000181\VD_MEASURE_L0.CSV
# 182 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000182\VD_MEASURE_L0.CSV
# 183 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000183\VD_MEASURE_L0.CSV
# 184 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000184\VD_MEASURE_L0.CSV
# 185 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000185\VD_MEASURE_L0.CSV
# 186 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000186\VD_MEASURE_L0.CSV
# 187 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000187\VD_MEASURE_L0.CSV
# 188 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000188\VD_MEASURE_L0.CSV
# 189 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000189\VD_MEASURE_L0.CSV
# 190 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000190\VD_MEASURE_L0.CSV
# 191 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000191\VD_MEASURE_L0.CSV
# 192 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000192\VD_MEASURE_L0.CSV
# 193 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000193\VD_MEASURE_L0.CSV
# 194 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000194\VD_MEASURE_L0.CSV
# 195 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000195\VD_MEASURE_L0.CSV
# 196 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000196\VD_MEASURE_L0.CSV
# 197 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000197\VD_MEASURE_L0.CSV
# 198 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000198\VD_MEASURE_L0.CSV
# 199 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000199\VD_MEASURE_L0.CSV
# 200 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000200\VD_MEASURE_L0.CSV
# 201 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000201\VD_MEASURE_L0.CSV
# 202 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000202\VD_MEASURE_L0.CSV
# 203 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000203\VD_MEASURE_L0.CSV
# 204 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000204\VD_MEASURE_L0.CSV
# 205 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000205\VD_MEASURE_L0.CSV
# 206 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000206\VD_MEASURE_L0.CSV
# 207 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000207\VD_MEASURE_L0.CSV
# 208 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000208\VD_MEASURE_L0.CSV
# 209 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000209\VD_MEASURE_L0.CSV
# 210 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000210\VD_MEASURE_L0.CSV
# 211 of 211: ..\Dataset_not_normalized\REF-Gold-Label_not_normalized\VD_R_0000000211\VD_MEASURE_L0.CSV
