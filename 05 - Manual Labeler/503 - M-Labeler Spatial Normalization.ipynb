# %%
import os
import sys
import pandas as pd
import ast

# Import library with current code functions
sys.path.append(os.path.join("..", "lib"))
import video_adjuster_functions as vid_adj_fun, files_paths as fp, general_functions as gf

# %% [markdown]
# ## Filtering the list of files to be measured

# %%
FILE_LIST_FEATURE_L1 = gf.find_files_in_all_subdirectories([fp.DATASET_SEED], fp.VD_FEATURES_L1)
FILE_LIST_FEATURE_L1_FILTERED = [path for path in FILE_LIST_FEATURE_L1 if not os.path.exists(os.path.join(os.path.dirname(path), fp.VD_FEATURES_L3))]

# %% [markdown]
# ## Normalize each frame of each video

# %%
features_start = '0'
features_end = '67'
normalization_parameter = [[0, 16], 400]

# %%
for i, current_path_location in enumerate(FILE_LIST_FEATURE_L1):

    print(f"{i+1} of {len(FILE_LIST_FEATURE_L1_FILTERED)}: Starting to process {current_path_location}")

    landmarks_CSV = pd.read_csv(current_path_location)
    landmarks_0_to_66 = landmarks_CSV.loc[:, features_start:features_end]
    
    normalized_landmarks = []
    for _, row in landmarks_0_to_66.iterrows():
        landmarks_list = [list(ast.literal_eval(coord)) for coord in row]
        
        # Apply normalizations
        scale_factor, z_normalized = vid_adj_fun.z_normalization(landmarks_list, normalization_parameter[0], normalization_parameter[1])
        roll_normalized = vid_adj_fun.roll_normalization(z_normalized)
        normalized_landmarks.append(z_normalized)
    
    # Convert each landmark position into a tuple
    normalized_landmarks_to_tuple = [[tuple(inner) for inner in outer] for outer in normalized_landmarks]
    df_normalized_landmarks = pd.DataFrame(normalized_landmarks_to_tuple)
    
    # Concatenate left_columns with df_normalized_landmarks along the columns
    left_columns = landmarks_CSV.loc[:, 'video_id':'instance_ref']
    df_result = pd.concat([left_columns, df_normalized_landmarks], axis=1)
    
    output_path = os.path.join(os.path.dirname(current_path_location), "VD_FEATURES_L3.CSV")

    df_result.to_csv(output_path, index=False)
# Out:
# 1 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000001\VD_FEATURES_L1.CSV
# 2 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000002\VD_FEATURES_L1.CSV
# 3 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000003\VD_FEATURES_L1.CSV
# 4 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000004\VD_FEATURES_L1.CSV
# 5 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000005\VD_FEATURES_L1.CSV
# 6 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000006\VD_FEATURES_L1.CSV
# 7 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000007\VD_FEATURES_L1.CSV
# 8 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000008\VD_FEATURES_L1.CSV
# 9 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000009\VD_FEATURES_L1.CSV
# 10 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000010\VD_FEATURES_L1.CSV
# 11 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000011\VD_FEATURES_L1.CSV
# 12 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000012\VD_FEATURES_L1.CSV
# 13 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000013\VD_FEATURES_L1.CSV
# 14 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000014\VD_FEATURES_L1.CSV
# 15 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000015\VD_FEATURES_L1.CSV
# 16 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000016\VD_FEATURES_L1.CSV
# 17 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000017\VD_FEATURES_L1.CSV
# 18 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000018\VD_FEATURES_L1.CSV
# 19 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000019\VD_FEATURES_L1.CSV
# 20 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000020\VD_FEATURES_L1.CSV
# 21 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000021\VD_FEATURES_L1.CSV
# 22 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000022\VD_FEATURES_L1.CSV
# 23 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000023\VD_FEATURES_L1.CSV
# 24 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000024\VD_FEATURES_L1.CSV
# 25 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000025\VD_FEATURES_L1.CSV
# 26 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000026\VD_FEATURES_L1.CSV
# 27 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000027\VD_FEATURES_L1.CSV
# 28 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000028\VD_FEATURES_L1.CSV
# 29 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000029\VD_FEATURES_L1.CSV
# 30 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000030\VD_FEATURES_L1.CSV
# 31 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000031\VD_FEATURES_L1.CSV
# 32 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000032\VD_FEATURES_L1.CSV
# 33 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000033\VD_FEATURES_L1.CSV
# 34 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000034\VD_FEATURES_L1.CSV
# 35 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000035\VD_FEATURES_L1.CSV
# 36 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000036\VD_FEATURES_L1.CSV
# 37 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000037\VD_FEATURES_L1.CSV
# 38 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000038\VD_FEATURES_L1.CSV
# 39 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000039\VD_FEATURES_L1.CSV
# 40 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000040\VD_FEATURES_L1.CSV
# 41 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000041\VD_FEATURES_L1.CSV
# 42 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000042\VD_FEATURES_L1.CSV
# 43 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000043\VD_FEATURES_L1.CSV
# 44 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000044\VD_FEATURES_L1.CSV
# 45 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000045\VD_FEATURES_L1.CSV
# 46 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000046\VD_FEATURES_L1.CSV
# 47 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000047\VD_FEATURES_L1.CSV
# 48 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000048\VD_FEATURES_L1.CSV
# 49 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000049\VD_FEATURES_L1.CSV
# 50 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000050\VD_FEATURES_L1.CSV
# 51 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000051\VD_FEATURES_L1.CSV
# 52 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000052\VD_FEATURES_L1.CSV
# 53 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000053\VD_FEATURES_L1.CSV
# 54 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000054\VD_FEATURES_L1.CSV
# 55 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000055\VD_FEATURES_L1.CSV
# 56 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000056\VD_FEATURES_L1.CSV
# 57 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000057\VD_FEATURES_L1.CSV
# 58 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000058\VD_FEATURES_L1.CSV
# 59 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000059\VD_FEATURES_L1.CSV
# 60 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000060\VD_FEATURES_L1.CSV
# 61 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000061\VD_FEATURES_L1.CSV
# 62 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000062\VD_FEATURES_L1.CSV
# 63 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000063\VD_FEATURES_L1.CSV
# 64 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000064\VD_FEATURES_L1.CSV
# 65 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000065\VD_FEATURES_L1.CSV
# 66 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000066\VD_FEATURES_L1.CSV
# 67 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000067\VD_FEATURES_L1.CSV
# 68 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000068\VD_FEATURES_L1.CSV
# 69 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000069\VD_FEATURES_L1.CSV
# 70 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000070\VD_FEATURES_L1.CSV
# 71 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000071\VD_FEATURES_L1.CSV
# 72 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000072\VD_FEATURES_L1.CSV
# 73 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000073\VD_FEATURES_L1.CSV
# 74 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000074\VD_FEATURES_L1.CSV
# 75 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000075\VD_FEATURES_L1.CSV
# 76 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000076\VD_FEATURES_L1.CSV
# 77 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000077\VD_FEATURES_L1.CSV
# 78 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000078\VD_FEATURES_L1.CSV
# 79 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000079\VD_FEATURES_L1.CSV
# 80 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000080\VD_FEATURES_L1.CSV
# 81 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000081\VD_FEATURES_L1.CSV
# 82 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000082\VD_FEATURES_L1.CSV
# 83 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000083\VD_FEATURES_L1.CSV
# 84 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000084\VD_FEATURES_L1.CSV
# 85 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000085\VD_FEATURES_L1.CSV
# 86 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000086\VD_FEATURES_L1.CSV
# 87 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000087\VD_FEATURES_L1.CSV
# 88 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000088\VD_FEATURES_L1.CSV
# 89 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000089\VD_FEATURES_L1.CSV
# 90 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000090\VD_FEATURES_L1.CSV
# 91 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000091\VD_FEATURES_L1.CSV
# 92 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000092\VD_FEATURES_L1.CSV
# 93 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000093\VD_FEATURES_L1.CSV
# 94 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000094\VD_FEATURES_L1.CSV
# 95 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000095\VD_FEATURES_L1.CSV
# 96 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000096\VD_FEATURES_L1.CSV
# 97 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000097\VD_FEATURES_L1.CSV
# 98 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000098\VD_FEATURES_L1.CSV
# 99 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000099\VD_FEATURES_L1.CSV
# 100 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000100\VD_FEATURES_L1.CSV
# 101 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000101\VD_FEATURES_L1.CSV
# 102 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000102\VD_FEATURES_L1.CSV
# 103 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000103\VD_FEATURES_L1.CSV
# 104 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000104\VD_FEATURES_L1.CSV
# 105 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000105\VD_FEATURES_L1.CSV
# 106 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000106\VD_FEATURES_L1.CSV
# 107 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000107\VD_FEATURES_L1.CSV
# 108 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000108\VD_FEATURES_L1.CSV
# 109 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000109\VD_FEATURES_L1.CSV
# 110 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000110\VD_FEATURES_L1.CSV
# 111 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000111\VD_FEATURES_L1.CSV
# 112 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000112\VD_FEATURES_L1.CSV
# 113 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000113\VD_FEATURES_L1.CSV
# 114 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000114\VD_FEATURES_L1.CSV
# 115 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000115\VD_FEATURES_L1.CSV
# 116 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000116\VD_FEATURES_L1.CSV
# 117 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000117\VD_FEATURES_L1.CSV
# 118 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000118\VD_FEATURES_L1.CSV
# 119 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000119\VD_FEATURES_L1.CSV
# 120 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000120\VD_FEATURES_L1.CSV
# 121 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000121\VD_FEATURES_L1.CSV
# 122 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000122\VD_FEATURES_L1.CSV
# 123 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000123\VD_FEATURES_L1.CSV
# 124 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000124\VD_FEATURES_L1.CSV
# 125 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000125\VD_FEATURES_L1.CSV
# 126 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000126\VD_FEATURES_L1.CSV
# 127 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000127\VD_FEATURES_L1.CSV
# 128 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000128\VD_FEATURES_L1.CSV
# 129 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000129\VD_FEATURES_L1.CSV
# 130 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000130\VD_FEATURES_L1.CSV
# 131 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000131\VD_FEATURES_L1.CSV
# 132 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000132\VD_FEATURES_L1.CSV
# 133 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000133\VD_FEATURES_L1.CSV
# 134 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000134\VD_FEATURES_L1.CSV
# 135 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000135\VD_FEATURES_L1.CSV
# 136 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000136\VD_FEATURES_L1.CSV
# 137 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000137\VD_FEATURES_L1.CSV
# 138 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000138\VD_FEATURES_L1.CSV
# 139 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000139\VD_FEATURES_L1.CSV
# 140 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000140\VD_FEATURES_L1.CSV
# 141 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000141\VD_FEATURES_L1.CSV
# 142 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000142\VD_FEATURES_L1.CSV
# 143 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000143\VD_FEATURES_L1.CSV
# 144 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000144\VD_FEATURES_L1.CSV
# 145 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000145\VD_FEATURES_L1.CSV
# 146 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000146\VD_FEATURES_L1.CSV
# 147 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000147\VD_FEATURES_L1.CSV
# 148 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000148\VD_FEATURES_L1.CSV
# 149 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000149\VD_FEATURES_L1.CSV
# 150 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000150\VD_FEATURES_L1.CSV
# 151 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000151\VD_FEATURES_L1.CSV
# 152 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000152\VD_FEATURES_L1.CSV
# 153 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000153\VD_FEATURES_L1.CSV
# 154 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000154\VD_FEATURES_L1.CSV
# 155 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000155\VD_FEATURES_L1.CSV
# 156 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000156\VD_FEATURES_L1.CSV
# 157 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000157\VD_FEATURES_L1.CSV
# 158 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000158\VD_FEATURES_L1.CSV
# 159 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000159\VD_FEATURES_L1.CSV
# 160 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000160\VD_FEATURES_L1.CSV
# 161 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000161\VD_FEATURES_L1.CSV
# 162 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000162\VD_FEATURES_L1.CSV
# 163 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000163\VD_FEATURES_L1.CSV
# 164 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000164\VD_FEATURES_L1.CSV
# 165 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000165\VD_FEATURES_L1.CSV
# 166 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000166\VD_FEATURES_L1.CSV
# 167 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000167\VD_FEATURES_L1.CSV
# 168 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000168\VD_FEATURES_L1.CSV
# 169 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000169\VD_FEATURES_L1.CSV
# 170 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000170\VD_FEATURES_L1.CSV
# 171 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000171\VD_FEATURES_L1.CSV
# 172 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000172\VD_FEATURES_L1.CSV
# 173 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000173\VD_FEATURES_L1.CSV
# 174 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000174\VD_FEATURES_L1.CSV
# 175 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000175\VD_FEATURES_L1.CSV
# 176 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000176\VD_FEATURES_L1.CSV
# 177 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000177\VD_FEATURES_L1.CSV
# 178 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000178\VD_FEATURES_L1.CSV
# 179 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000179\VD_FEATURES_L1.CSV
# 180 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000180\VD_FEATURES_L1.CSV
# 181 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000181\VD_FEATURES_L1.CSV
# 182 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000182\VD_FEATURES_L1.CSV
# 183 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000183\VD_FEATURES_L1.CSV
# 184 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000184\VD_FEATURES_L1.CSV
# 185 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000185\VD_FEATURES_L1.CSV
# 186 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000186\VD_FEATURES_L1.CSV
# 187 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000187\VD_FEATURES_L1.CSV
# 188 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000188\VD_FEATURES_L1.CSV
# 189 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000189\VD_FEATURES_L1.CSV
# 190 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000190\VD_FEATURES_L1.CSV
# 191 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000191\VD_FEATURES_L1.CSV
# 192 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000192\VD_FEATURES_L1.CSV
# 193 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000193\VD_FEATURES_L1.CSV
# 194 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000194\VD_FEATURES_L1.CSV
# 195 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000195\VD_FEATURES_L1.CSV
# 196 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000196\VD_FEATURES_L1.CSV
# 197 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000197\VD_FEATURES_L1.CSV
# 198 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000198\VD_FEATURES_L1.CSV
# 199 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000199\VD_FEATURES_L1.CSV
# 200 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000200\VD_FEATURES_L1.CSV
# 201 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000201\VD_FEATURES_L1.CSV
# 202 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000202\VD_FEATURES_L1.CSV
# 203 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000203\VD_FEATURES_L1.CSV
# 204 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000204\VD_FEATURES_L1.CSV
# 205 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000205\VD_FEATURES_L1.CSV
# 206 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000206\VD_FEATURES_L1.CSV
# 207 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000207\VD_FEATURES_L1.CSV
# 208 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000208\VD_FEATURES_L1.CSV
# 209 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000209\VD_FEATURES_L1.CSV
# 210 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000210\VD_FEATURES_L1.CSV
# 211 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000211\VD_FEATURES_L1.CSV
# 212 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000212\VD_FEATURES_L1.CSV
# 213 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000213\VD_FEATURES_L1.CSV
# 214 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000214\VD_FEATURES_L1.CSV
# 215 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000215\VD_FEATURES_L1.CSV
# 216 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000216\VD_FEATURES_L1.CSV
# 217 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000217\VD_FEATURES_L1.CSV
# 218 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000218\VD_FEATURES_L1.CSV
# 219 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000219\VD_FEATURES_L1.CSV
# 220 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000220\VD_FEATURES_L1.CSV
# 221 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000221\VD_FEATURES_L1.CSV
# 222 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000222\VD_FEATURES_L1.CSV
# 223 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000223\VD_FEATURES_L1.CSV
# 224 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000224\VD_FEATURES_L1.CSV
# 225 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000225\VD_FEATURES_L1.CSV
# 226 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000226\VD_FEATURES_L1.CSV
# 227 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000227\VD_FEATURES_L1.CSV
# 228 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000228\VD_FEATURES_L1.CSV
# 229 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000229\VD_FEATURES_L1.CSV
# 230 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000230\VD_FEATURES_L1.CSV
# 231 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000231\VD_FEATURES_L1.CSV
# 232 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000232\VD_FEATURES_L1.CSV
# 233 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000233\VD_FEATURES_L1.CSV
# 234 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000234\VD_FEATURES_L1.CSV
# 235 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000235\VD_FEATURES_L1.CSV
# 236 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000236\VD_FEATURES_L1.CSV
# 237 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000237\VD_FEATURES_L1.CSV
# 238 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000238\VD_FEATURES_L1.CSV
# 239 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000239\VD_FEATURES_L1.CSV
# 240 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000240\VD_FEATURES_L1.CSV
# 241 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000241\VD_FEATURES_L1.CSV
# 242 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000242\VD_FEATURES_L1.CSV
# 243 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000243\VD_FEATURES_L1.CSV
# 244 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000244\VD_FEATURES_L1.CSV
# 245 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000245\VD_FEATURES_L1.CSV
# 246 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000246\VD_FEATURES_L1.CSV
# 247 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000247\VD_FEATURES_L1.CSV
# 248 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000248\VD_FEATURES_L1.CSV
# 249 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000249\VD_FEATURES_L1.CSV
# 250 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000250\VD_FEATURES_L1.CSV
# 251 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000251\VD_FEATURES_L1.CSV
# 252 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000252\VD_FEATURES_L1.CSV
# 253 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000253\VD_FEATURES_L1.CSV
# 254 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000254\VD_FEATURES_L1.CSV
# 255 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000255\VD_FEATURES_L1.CSV
# 256 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000256\VD_FEATURES_L1.CSV
# 257 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000257\VD_FEATURES_L1.CSV
# 258 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000258\VD_FEATURES_L1.CSV
# 259 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000259\VD_FEATURES_L1.CSV
# 260 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000260\VD_FEATURES_L1.CSV
# 261 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000261\VD_FEATURES_L1.CSV
# 262 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000262\VD_FEATURES_L1.CSV
# 263 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000263\VD_FEATURES_L1.CSV
# 264 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000264\VD_FEATURES_L1.CSV
# 265 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000265\VD_FEATURES_L1.CSV
# 266 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000266\VD_FEATURES_L1.CSV
# 267 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000267\VD_FEATURES_L1.CSV
# 268 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000268\VD_FEATURES_L1.CSV
# 269 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000269\VD_FEATURES_L1.CSV
# 270 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000270\VD_FEATURES_L1.CSV
# 271 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000271\VD_FEATURES_L1.CSV
# 272 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000272\VD_FEATURES_L1.CSV
# 273 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000273\VD_FEATURES_L1.CSV
# 274 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000274\VD_FEATURES_L1.CSV
# 275 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000275\VD_FEATURES_L1.CSV
# 276 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000276\VD_FEATURES_L1.CSV
# 277 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000277\VD_FEATURES_L1.CSV
# 278 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000278\VD_FEATURES_L1.CSV
# 279 of 68: Starting to process ..\Dataset\REF-Gold-Label\VD_R_0000000279\VD_FEATURES_L1.CSV
