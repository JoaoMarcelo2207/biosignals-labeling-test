# %%
import cv2
import os
import sys
import numpy as np
import pandas as pd

# Import library with current code functions
sys.path.append(os.path.join("..", "lib"))
import general_functions as gf, video_adjuster_functions as vid_adj_fun, files_paths as fp

# %%
MAIN_LIST_INFO =  gf.find_files_in_all_subdirectories([fp.DATASET_YT, fp.DATASET_LOCAL], fp.VD_INFO)

FILE_TO_INSERT_ANGLES = fp.VD_FEATURES_L2

# %% [markdown]
# ## Extracting the X Y and Z angles for each pose of each frames and inserting at the last columns of the CSV

# %%
for i, current_path_location in enumerate(MAIN_LIST_INFO):

    path_dir = os.path.dirname(current_path_location)
    vd_feature_path = os.path.join(path_dir, FILE_TO_INSERT_ANGLES)
    video_feature_rest = pd.read_csv(vd_feature_path)

    print (str(i+1) + " of " + str(len(MAIN_LIST_INFO)) + ": " + vd_feature_path)

    # Remove the Unnamed columns
    if 'Unnamed: 0' in video_feature_rest.columns:
        video_feature_rest.drop(columns=['Unnamed: 0'], inplace=True)

    # Remove Rows with Nan Values
    video_feature_rest_drop_na = video_feature_rest.fillna(0)      
    
    POSE_FEATURE = pd.DataFrame()
    tvec = np.array([[0.0], [0.0], [0.0]])
    rvec = np.array([[0.0], [0.0], [0.0]])
    
    for row, row_data in video_feature_rest_drop_na.iterrows():
        if row_data.iloc[6]==0: 
            shape = {'rot_x': np.nan, 'rot_y': np.nan, 'rot_z': np.nan}
            video_extractor_pose = pd.DataFrame([shape])
            
        else:
            shape = vid_adj_fun.tuple_to_np(row_data[6:74])
            video_extractor_pose = pd.DataFrame()
            new_shape = vid_adj_fun.shape_normalizer(shape)
            
            refImgPts = vid_adj_fun.ref2dImagePoints(new_shape)
            image_width = (new_shape[16] - new_shape[0])[0]
            image_height = (new_shape[8] - new_shape[27])[1]
            angles, rvec, tvec = vid_adj_fun.get_angles(image_height, image_width, refImgPts, rotationVector = rvec, translationVector = tvec)
            video_extractor_pose['rot_x'] = [round(-angles[0],2)]
            video_extractor_pose['rot_y'] = [round(angles[1],2)]
            video_extractor_pose['rot_z'] = [round(-angles[2],2)]
            
        POSE_FEATURE = pd.concat([POSE_FEATURE, video_extractor_pose]).reset_index(drop=True)
    POSE_FEATURE = pd.concat([video_feature_rest, POSE_FEATURE], axis=1)

    base_path_folder_output = os.path.join(path_dir, FILE_TO_INSERT_ANGLES)
    POSE_FEATURE.to_csv(base_path_folder_output, na_rep='NaN')
# Out:
# 1 of 100: ..\Dataset\DD-Local\VD_D_0000000043\VD_FEATURES_L2.CSV
# 2 of 100: ..\Dataset\DD-Local\VD_D_0000000044\VD_FEATURES_L2.CSV
# 3 of 100: ..\Dataset\DD-Local\VD_D_0000000045\VD_FEATURES_L2.CSV
# 4 of 100: ..\Dataset\DD-Local\VD_D_0000000046\VD_FEATURES_L2.CSV
# 5 of 100: ..\Dataset\DD-Local\VD_D_0000000047\VD_FEATURES_L2.CSV
# 6 of 100: ..\Dataset\DD-Local\VD_D_0000000048\VD_FEATURES_L2.CSV
# 7 of 100: ..\Dataset\DD-Local\VD_D_0000000049\VD_FEATURES_L2.CSV
# 8 of 100: ..\Dataset\DD-Local\VD_D_0000000050\VD_FEATURES_L2.CSV
# 9 of 100: ..\Dataset\DD-Local\VD_D_0000000051\VD_FEATURES_L2.CSV
# 10 of 100: ..\Dataset\DD-Local\VD_D_0000000052\VD_FEATURES_L2.CSV
# 11 of 100: ..\Dataset\DD-Local\VD_D_0000000053\VD_FEATURES_L2.CSV
# 12 of 100: ..\Dataset\DD-Local\VD_D_0000000054\VD_FEATURES_L2.CSV
# 13 of 100: ..\Dataset\DD-Local\VD_D_0000000055\VD_FEATURES_L2.CSV
# 14 of 100: ..\Dataset\DD-Local\VD_D_0000000056\VD_FEATURES_L2.CSV
# 15 of 100: ..\Dataset\DD-Local\VD_D_0000000057\VD_FEATURES_L2.CSV
# 16 of 100: ..\Dataset\DD-Local\VD_D_0000000058\VD_FEATURES_L2.CSV
# 17 of 100: ..\Dataset\DD-Local\VD_D_0000000059\VD_FEATURES_L2.CSV
# 18 of 100: ..\Dataset\DD-Local\VD_D_0000000060\VD_FEATURES_L2.CSV
# 19 of 100: ..\Dataset\DD-Local\VD_D_0000000061\VD_FEATURES_L2.CSV
# 20 of 100: ..\Dataset\DD-Local\VD_D_0000000062\VD_FEATURES_L2.CSV
# 21 of 100: ..\Dataset\DD-Local\VD_D_0000000063\VD_FEATURES_L2.CSV
# 22 of 100: ..\Dataset\DD-Local\VD_D_0000000064\VD_FEATURES_L2.CSV
# 23 of 100: ..\Dataset\DD-Local\VD_D_0000000065\VD_FEATURES_L2.CSV
# 24 of 100: ..\Dataset\DD-Local\VD_D_0000000066\VD_FEATURES_L2.CSV
# 25 of 100: ..\Dataset\DD-Local\VD_D_0000000067\VD_FEATURES_L2.CSV
# 26 of 100: ..\Dataset\DD-Local\VD_D_0000000068\VD_FEATURES_L2.CSV
# 27 of 100: ..\Dataset\DD-Local\VD_D_0000000069\VD_FEATURES_L2.CSV
# 28 of 100: ..\Dataset\DD-Local\VD_D_0000000070\VD_FEATURES_L2.CSV
# 29 of 100: ..\Dataset\DD-Local\VD_D_0000000071\VD_FEATURES_L2.CSV
# 30 of 100: ..\Dataset\DD-Local\VD_D_0000000072\VD_FEATURES_L2.CSV
# 31 of 100: ..\Dataset\DD-Local\VD_D_0000000073\VD_FEATURES_L2.CSV
# 32 of 100: ..\Dataset\DD-Local\VD_D_0000000074\VD_FEATURES_L2.CSV
# 33 of 100: ..\Dataset\DD-Local\VD_D_0000000075\VD_FEATURES_L2.CSV
# 34 of 100: ..\Dataset\DD-Local\VD_D_0000000076\VD_FEATURES_L2.CSV
# 35 of 100: ..\Dataset\DD-Local\VD_D_0000000077\VD_FEATURES_L2.CSV
# 36 of 100: ..\Dataset\DD-Local\VD_D_0000000078\VD_FEATURES_L2.CSV
# 37 of 100: ..\Dataset\DD-Local\VD_D_0000000079\VD_FEATURES_L2.CSV
# 38 of 100: ..\Dataset\DD-Local\VD_D_0000000080\VD_FEATURES_L2.CSV
# 39 of 100: ..\Dataset\DD-Local\VD_D_0000000081\VD_FEATURES_L2.CSV
# 40 of 100: ..\Dataset\DD-Local\VD_D_0000000082\VD_FEATURES_L2.CSV
# 41 of 100: ..\Dataset\DD-Local\VD_D_0000000083\VD_FEATURES_L2.CSV
# 42 of 100: ..\Dataset\DD-Local\VD_D_0000000084\VD_FEATURES_L2.CSV
# 43 of 100: ..\Dataset\DD-Local\VD_D_0000000085\VD_FEATURES_L2.CSV
# 44 of 100: ..\Dataset\DD-Local\VD_D_0000000086\VD_FEATURES_L2.CSV
# 45 of 100: ..\Dataset\DD-Local\VD_D_0000000087\VD_FEATURES_L2.CSV
# 46 of 100: ..\Dataset\DD-Local\VD_D_0000000088\VD_FEATURES_L2.CSV
# 47 of 100: ..\Dataset\DD-Local\VD_D_0000000089\VD_FEATURES_L2.CSV
# 48 of 100: ..\Dataset\DD-Local\VD_D_0000000090\VD_FEATURES_L2.CSV
# 49 of 100: ..\Dataset\DD-Local\VD_D_0000000091\VD_FEATURES_L2.CSV
# 50 of 100: ..\Dataset\DD-Local\VD_D_0000000092\VD_FEATURES_L2.CSV
# 51 of 100: ..\Dataset\DD-Local\VD_D_0000000093\VD_FEATURES_L2.CSV
# 52 of 100: ..\Dataset\DD-Local\VD_D_0000000094\VD_FEATURES_L2.CSV
# 53 of 100: ..\Dataset\DD-Local\VD_D_0000000095\VD_FEATURES_L2.CSV
# 54 of 100: ..\Dataset\DD-Local\VD_D_0000000096\VD_FEATURES_L2.CSV
# 55 of 100: ..\Dataset\DD-Local\VD_D_0000000097\VD_FEATURES_L2.CSV
# 56 of 100: ..\Dataset\DD-Local\VD_D_0000000098\VD_FEATURES_L2.CSV
# 57 of 100: ..\Dataset\DD-Local\VD_D_0000000099\VD_FEATURES_L2.CSV
# 58 of 100: ..\Dataset\DD-Local\VD_D_0000000100\VD_FEATURES_L2.CSV
# 59 of 100: ..\Dataset\YT-Online\VD_Y_0000000001\VD_FEATURES_L2.CSV
# 60 of 100: ..\Dataset\YT-Online\VD_Y_0000000002\VD_FEATURES_L2.CSV
# 61 of 100: ..\Dataset\YT-Online\VD_Y_0000000003\VD_FEATURES_L2.CSV
# 62 of 100: ..\Dataset\YT-Online\VD_Y_0000000004\VD_FEATURES_L2.CSV
# 63 of 100: ..\Dataset\YT-Online\VD_Y_0000000005\VD_FEATURES_L2.CSV
# 64 of 100: ..\Dataset\YT-Online\VD_Y_0000000006\VD_FEATURES_L2.CSV
# 65 of 100: ..\Dataset\YT-Online\VD_Y_0000000007\VD_FEATURES_L2.CSV
# 66 of 100: ..\Dataset\YT-Online\VD_Y_0000000008\VD_FEATURES_L2.CSV
# 67 of 100: ..\Dataset\YT-Online\VD_Y_0000000009\VD_FEATURES_L2.CSV
# 68 of 100: ..\Dataset\YT-Online\VD_Y_0000000010\VD_FEATURES_L2.CSV
# 69 of 100: ..\Dataset\YT-Online\VD_Y_0000000011\VD_FEATURES_L2.CSV
# 70 of 100: ..\Dataset\YT-Online\VD_Y_0000000012\VD_FEATURES_L2.CSV
# 71 of 100: ..\Dataset\YT-Online\VD_Y_0000000013\VD_FEATURES_L2.CSV
# 72 of 100: ..\Dataset\YT-Online\VD_Y_0000000014\VD_FEATURES_L2.CSV
# 73 of 100: ..\Dataset\YT-Online\VD_Y_0000000015\VD_FEATURES_L2.CSV
# 74 of 100: ..\Dataset\YT-Online\VD_Y_0000000016\VD_FEATURES_L2.CSV
# 75 of 100: ..\Dataset\YT-Online\VD_Y_0000000017\VD_FEATURES_L2.CSV
# 76 of 100: ..\Dataset\YT-Online\VD_Y_0000000018\VD_FEATURES_L2.CSV
# 77 of 100: ..\Dataset\YT-Online\VD_Y_0000000019\VD_FEATURES_L2.CSV
# 78 of 100: ..\Dataset\YT-Online\VD_Y_0000000020\VD_FEATURES_L2.CSV
# 79 of 100: ..\Dataset\YT-Online\VD_Y_0000000021\VD_FEATURES_L2.CSV
# 80 of 100: ..\Dataset\YT-Online\VD_Y_0000000022\VD_FEATURES_L2.CSV
# 81 of 100: ..\Dataset\YT-Online\VD_Y_0000000023\VD_FEATURES_L2.CSV
# 82 of 100: ..\Dataset\YT-Online\VD_Y_0000000024\VD_FEATURES_L2.CSV
# 83 of 100: ..\Dataset\YT-Online\VD_Y_0000000025\VD_FEATURES_L2.CSV
# 84 of 100: ..\Dataset\YT-Online\VD_Y_0000000026\VD_FEATURES_L2.CSV
# 85 of 100: ..\Dataset\YT-Online\VD_Y_0000000027\VD_FEATURES_L2.CSV
# 86 of 100: ..\Dataset\YT-Online\VD_Y_0000000028\VD_FEATURES_L2.CSV
# 87 of 100: ..\Dataset\YT-Online\VD_Y_0000000029\VD_FEATURES_L2.CSV
# 88 of 100: ..\Dataset\YT-Online\VD_Y_0000000030\VD_FEATURES_L2.CSV
# 89 of 100: ..\Dataset\YT-Online\VD_Y_0000000031\VD_FEATURES_L2.CSV
# 90 of 100: ..\Dataset\YT-Online\VD_Y_0000000032\VD_FEATURES_L2.CSV
# 91 of 100: ..\Dataset\YT-Online\VD_Y_0000000033\VD_FEATURES_L2.CSV
# 92 of 100: ..\Dataset\YT-Online\VD_Y_0000000034\VD_FEATURES_L2.CSV
# 93 of 100: ..\Dataset\YT-Online\VD_Y_0000000035\VD_FEATURES_L2.CSV
# 94 of 100: ..\Dataset\YT-Online\VD_Y_0000000036\VD_FEATURES_L2.CSV
# 95 of 100: ..\Dataset\YT-Online\VD_Y_0000000037\VD_FEATURES_L2.CSV
# 96 of 100: ..\Dataset\YT-Online\VD_Y_0000000038\VD_FEATURES_L2.CSV
# 97 of 100: ..\Dataset\YT-Online\VD_Y_0000000039\VD_FEATURES_L2.CSV
# 98 of 100: ..\Dataset\YT-Online\VD_Y_0000000040\VD_FEATURES_L2.CSV
# 99 of 100: ..\Dataset\YT-Online\VD_Y_0000000041\VD_FEATURES_L2.CSV
# 100 of 100: ..\Dataset\YT-Online\VD_Y_0000000042\VD_FEATURES_L2.CSV
