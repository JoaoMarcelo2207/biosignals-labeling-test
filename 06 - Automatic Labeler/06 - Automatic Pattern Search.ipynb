# %% [markdown]
# # Import dependencies

# %%
import os
import sys
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

import time

# Import library with current code functions
sys.path.append(os.path.join("..", "lib"))
import manual_labeler_functions as man_lab_fun, automatic_labeler_functions as aut_lab_fun, general_functions as gf, files_paths as fp

# %% [markdown]
# ## Getting the list of measure files to be labeled and the list of seed available

# %%
FILE_LIST_VD_MEASURE = gf.find_files_in_all_subdirectories([fp.DATASET_YT_NOT_NORMALIZED, fp.DATASET_LOCAL_NOT_NORMALIZED], fp.VD_MEASURE_L0)
FILE_LIST_LABELED_SEED = gf.find_files_in_all_subdirectories([fp.DATASET_SEED_NOT_NORMALIZED], fp.VD_LABELED_L0)

# %% [markdown]
# ## Remove all VD_LABELED_L0 file

# %%
def remove_file(FILE_LIST_PATH, file_name):
    for current_path in FILE_LIST_PATH:
        vd_labeled_path = os.path.join(os.path.dirname(current_path), file_name)
        if os.path.exists(vd_labeled_path):
            os.remove(vd_labeled_path)
            print(f"The file was removed: {vd_labeled_path}")
        else:
            print("File not found.")

# %%
remove_file(FILE_LIST_VD_MEASURE, fp.VD_LABELED_L0)
# Out:
# File not found.
# File not found.
# File not found.
# File not found.
# File not found.
# File not found.
# File not found.
# File not found.
# File not found.
# File not found.
# File not found.
# File not found.
# File not found.
# File not found.
# File not found.
# File not found.
# File not found.
# File not found.
# File not found.
# File not found.
# File not found.
# File not found.
# File not found.
# File not found.
# File not found.
# File not found.
# File not found.
# File not found.

# %% [markdown]
# ## Select reference SEED

# %%
FILE_LIST_SEED_VD_INFO = gf.find_files_in_all_subdirectories([fp.DATASET_SEED_NOT_NORMALIZED], fp.VD_INFO)

# %% [markdown]
# ## Verificar quantidade de uma classe

# %%
def count_class_totals_and_instances(FILE_LIST_PATH, file_name, column_name, conditions, length_threshold=30):
    class_totals = {condition: 0 for condition in conditions}  # Total de frames por classe
    class_instances = {condition: 0 for condition in conditions}  # Total de instâncias por classe
    short_instances = {condition: 0 for condition in conditions}  # Total de instâncias menores que o limite
    results_per_folder = {condition: [] for condition in conditions}

    for current_path in FILE_LIST_PATH:
        vd_labeled_path = os.path.join(os.path.dirname(current_path), file_name)

        # Verifica se o arquivo VD_LABELED_L0 existe
        if os.path.exists(vd_labeled_path):
            try:
                # Lê o arquivo VD_LABELED_L0
                df = pd.read_csv(vd_labeled_path)
                
                # Verifica se a coluna existe
                if column_name in df.columns:
                    folder_name = os.path.basename(os.path.dirname(current_path))

                    for condition in conditions:
                        # Conta o total de frames com a classe
                        mask = df[column_name].str.contains(condition, case=False, na=False)
                        total_frames = mask.sum()

                        # Conta o total de instâncias consecutivas
                        mask_diff = mask & ~mask.shift(fill_value=False)
                        total_instances = mask_diff.sum()

                        # Conta instâncias menores que o limite de comprimento
                        short_instance_count = 0
                        if total_instances > 0:
                            current_length = 0
                            for val in mask:
                                if val:
                                    current_length += 1
                                elif current_length > 0:
                                    if current_length < length_threshold:
                                        short_instance_count += 1
                                    current_length = 0
                            # Verifica a última instância
                            if current_length > 0 and current_length < length_threshold:
                                short_instance_count += 1

                        # Armazena resultados
                        results_per_folder[condition].append(
                            (folder_name, total_frames, total_instances, short_instance_count)
                        )
                        class_totals[condition] += total_frames
                        class_instances[condition] += total_instances
                        short_instances[condition] += short_instance_count
            except Exception as e:
                print(f"Erro ao processar o arquivo {vd_labeled_path}: {e}")
        else:
            print(f"Arquivo não encontrado: {vd_labeled_path}")

    # Imprime os resultados
    for condition in conditions:
        print(f"\nResultados para '{condition}':")
        for folder_name, total_frames, total_instances, short_count in results_per_folder[condition]:
            print(
                f"{folder_name} - {total_frames} frames, {total_instances} instâncias, "
                f"{short_count} instâncias com tamanho < {length_threshold}"
            )
        print(
            f"Total geral: {class_totals[condition]} frames, {class_instances[condition]} instâncias, "
            f"{short_instances[condition]} instâncias com tamanho < {length_threshold}"
        )

# Configuração dos caminhos
FILE_LIST_VD_MEASURE = gf.find_files_in_all_subdirectories([fp.DATASET_YT, fp.DATASET_LOCAL], fp.VD_MEASURE_L0)

# Executa a função
count_class_totals_and_instances(
    FILE_LIST_PATH=FILE_LIST_VD_MEASURE,
    file_name=fp.VD_LABELED_L0,
    column_name="label_measures",
    conditions=["OTHERS", "HAPPY", "NEUTRAL"]
)
# Out:
# Resultados para 'OTHERS':
# VD_D_0000000043 - 133 frames, 4 instâncias, 0 instâncias com tamanho < 30
# VD_D_0000000044 - 244 frames, 8 instâncias, 1 instâncias com tamanho < 30
# VD_D_0000000045 - 200 frames, 7 instâncias, 2 instâncias com tamanho < 30
# VD_D_0000000046 - 854 frames, 28 instâncias, 8 instâncias com tamanho < 30
# VD_D_0000000047 - 196 frames, 7 instâncias, 2 instâncias com tamanho < 30
# VD_D_0000000048 - 348 frames, 11 instâncias, 2 instâncias com tamanho < 30
# VD_D_0000000049 - 283 frames, 9 instâncias, 1 instâncias com tamanho < 30
# VD_D_0000000050 - 239 frames, 8 instâncias, 2 instâncias com tamanho < 30
# VD_D_0000000051 - 794 frames, 28 instâncias, 10 instâncias com tamanho < 30
# VD_D_0000000052 - 536 frames, 18 instâncias, 5 instâncias com tamanho < 30
# VD_D_0000000053 - 60 frames, 2 instâncias, 0 instâncias com tamanho < 30
# VD_D_0000000054 - 281 frames, 10 instâncias, 3 instâncias com tamanho < 30
# VD_D_0000000055 - 91 frames, 3 instâncias, 0 instâncias com tamanho < 30
# VD_D_0000000056 - 846 frames, 30 instâncias, 11 instâncias com tamanho < 30
# VD_D_0000000057 - 121 frames, 4 instâncias, 0 instâncias com tamanho < 30
# VD_D_0000000058 - 266 frames, 9 instâncias, 1 instâncias com tamanho < 30
# VD_D_0000000059 - 715 frames, 25 instâncias, 9 instâncias com tamanho < 30
# VD_D_0000000060 - 101 frames, 4 instâncias, 2 instâncias com tamanho < 30
# VD_D_0000000061 - 771 frames, 27 instâncias, 8 instâncias com tamanho < 30
# VD_D_0000000062 - 440 frames, 16 instâncias, 6 instâncias com tamanho < 30
# VD_D_0000000063 - 379 frames, 12 instâncias, 2 instâncias com tamanho < 30
# VD_D_0000000064 - 394 frames, 13 instâncias, 3 instâncias com tamanho < 30
# VD_D_0000000065 - 91 frames, 3 instâncias, 0 instâncias com tamanho < 30
# VD_D_0000000066 - 454 frames, 15 instâncias, 4 instâncias com tamanho < 30
# VD_D_0000000067 - 319 frames, 11 instâncias, 5 instâncias com tamanho < 30
# VD_D_0000000068 - 238 frames, 8 instâncias, 2 instâncias com tamanho < 30
# VD_D_0000000069 - 301 frames, 10 instâncias, 2 instâncias com tamanho < 30
# VD_D_0000000070 - 508 frames, 17 instâncias, 3 instâncias com tamanho < 30
# VD_Y_0000000001 - 92 frames, 3 instâncias, 0 instâncias com tamanho < 30
# VD_Y_0000000002 - 552 frames, 18 instâncias, 4 instâncias com tamanho < 30
# VD_Y_0000000003 - 439 frames, 15 instâncias, 7 instâncias com tamanho < 30
# VD_Y_0000000004 - 202 frames, 7 instâncias, 1 instâncias com tamanho < 30
# VD_Y_0000000005 - 87 frames, 3 instâncias, 1 instâncias com tamanho < 30
# VD_Y_0000000006 - 523 frames, 18 instâncias, 6 instâncias com tamanho < 30
# VD_Y_0000000007 - 517 frames, 17 instâncias, 3 instâncias com tamanho < 30
# VD_Y_0000000008 - 1314 frames, 43 instâncias, 9 instâncias com tamanho < 30
# VD_Y_0000000009 - 120 frames, 4 instâncias, 1 instâncias com tamanho < 30
# VD_Y_0000000010 - 307 frames, 10 instâncias, 2 instâncias com tamanho < 30
# VD_Y_0000000011 - 394 frames, 14 instâncias, 4 instâncias com tamanho < 30
# VD_Y_0000000012 - 107 frames, 3 instâncias, 0 instâncias com tamanho < 30
# VD_Y_0000000013 - 150 frames, 5 instâncias, 0 instâncias com tamanho < 30
# VD_Y_0000000014 - 147 frames, 5 instâncias, 1 instâncias com tamanho < 30
# VD_Y_0000000015 - 268 frames, 9 instâncias, 2 instâncias com tamanho < 30
# VD_Y_0000000016 - 266 frames, 9 instâncias, 2 instâncias com tamanho < 30
# VD_Y_0000000017 - 81 frames, 3 instâncias, 2 instâncias com tamanho < 30
# VD_Y_0000000018 - 121 frames, 4 instâncias, 0 instâncias com tamanho < 30
# VD_Y_0000000019 - 145 frames, 5 instâncias, 2 instâncias com tamanho < 30
# VD_Y_0000000020 - 575 frames, 18 instâncias, 1 instâncias com tamanho < 30
# VD_Y_0000000021 - 374 frames, 13 instâncias, 5 instâncias com tamanho < 30
# VD_Y_0000000022 - 0 frames, 0 instâncias, 0 instâncias com tamanho < 30
# VD_Y_0000000023 - 117 frames, 4 instâncias, 1 instâncias com tamanho < 30
# VD_Y_0000000024 - 25 frames, 1 instâncias, 1 instâncias com tamanho < 30
# VD_Y_0000000025 - 142 frames, 5 instâncias, 2 instâncias com tamanho < 30
# VD_Y_0000000026 - 122 frames, 4 instâncias, 0 instâncias com tamanho < 30
# VD_Y_0000000027 - 107 frames, 4 instâncias, 2 instâncias com tamanho < 30
# VD_Y_0000000028 - 60 frames, 2 instâncias, 0 instâncias com tamanho < 30
# VD_Y_0000000029 - 171 frames, 6 instâncias, 2 instâncias com tamanho < 30
# VD_Y_0000000030 - 252 frames, 9 instâncias, 3 instâncias com tamanho < 30
# VD_Y_0000000031 - 518 frames, 18 instâncias, 6 instâncias com tamanho < 30
# VD_Y_0000000032 - 107 frames, 4 instâncias, 2 instâncias com tamanho < 30
# VD_Y_0000000033 - 114 frames, 4 instâncias, 2 instâncias com tamanho < 30
# VD_Y_0000000034 - 117 frames, 4 instâncias, 1 instâncias com tamanho < 30
# VD_Y_0000000035 - 152 frames, 5 instâncias, 1 instâncias com tamanho < 30
# VD_Y_0000000036 - 366 frames, 12 instâncias, 4 instâncias com tamanho < 30
# VD_Y_0000000037 - 327 frames, 11 instâncias, 2 instâncias com tamanho < 30
# VD_Y_0000000038 - 570 frames, 20 instâncias, 6 instâncias com tamanho < 30
# VD_Y_0000000039 - 110 frames, 4 instâncias, 1 instâncias com tamanho < 30
# VD_Y_0000000040 - 115 frames, 4 instâncias, 1 instâncias com tamanho < 30
# VD_Y_0000000041 - 88 frames, 3 instâncias, 1 instâncias com tamanho < 30
# VD_Y_0000000042 - 146 frames, 5 instâncias, 2 instâncias com tamanho < 30
# Total geral: 20710 frames, 702 instâncias, 187 instâncias com tamanho < 30
#
# Resultados para 'HAPPY':
# VD_D_0000000043 - 95 frames, 5 instâncias, 4 instâncias com tamanho < 30
# VD_D_0000000044 - 171 frames, 5 instâncias, 3 instâncias com tamanho < 30
# VD_D_0000000045 - 64 frames, 4 instâncias, 4 instâncias com tamanho < 30
# VD_D_0000000046 - 367 frames, 20 instâncias, 17 instâncias com tamanho < 30
# VD_D_0000000047 - 173 frames, 9 instâncias, 7 instâncias com tamanho < 30
# VD_D_0000000048 - 323 frames, 14 instâncias, 7 instâncias com tamanho < 30
# VD_D_0000000049 - 259 frames, 12 instâncias, 8 instâncias com tamanho < 30
# VD_D_0000000050 - 209 frames, 10 instâncias, 6 instâncias com tamanho < 30
# VD_D_0000000051 - 718 frames, 36 instâncias, 29 instâncias com tamanho < 30
# VD_D_0000000052 - 588 frames, 28 instâncias, 22 instâncias com tamanho < 30
# VD_D_0000000053 - 267 frames, 10 instâncias, 2 instâncias com tamanho < 30
# VD_D_0000000054 - 323 frames, 16 instâncias, 12 instâncias com tamanho < 30
# VD_D_0000000055 - 162 frames, 9 instâncias, 9 instâncias com tamanho < 30
# VD_D_0000000056 - 716 frames, 42 instâncias, 36 instâncias com tamanho < 30
# VD_D_0000000057 - 127 frames, 5 instâncias, 2 instâncias com tamanho < 30
# VD_D_0000000058 - 525 frames, 22 instâncias, 10 instâncias com tamanho < 30
# VD_D_0000000059 - 435 frames, 19 instâncias, 10 instâncias com tamanho < 30
# VD_D_0000000060 - 122 frames, 6 instâncias, 6 instâncias com tamanho < 30
# VD_D_0000000061 - 647 frames, 32 instâncias, 23 instâncias com tamanho < 30
# VD_D_0000000062 - 366 frames, 20 instâncias, 17 instâncias com tamanho < 30
# VD_D_0000000063 - 498 frames, 25 instâncias, 20 instâncias com tamanho < 30
# VD_D_0000000064 - 673 frames, 31 instâncias, 21 instâncias com tamanho < 30
# VD_D_0000000065 - 89 frames, 5 instâncias, 5 instâncias com tamanho < 30
# VD_D_0000000066 - 672 frames, 27 instâncias, 15 instâncias com tamanho < 30
# VD_D_0000000067 - 565 frames, 24 instâncias, 13 instâncias com tamanho < 30
# VD_D_0000000068 - 85 frames, 3 instâncias, 1 instâncias com tamanho < 30
# VD_D_0000000069 - 470 frames, 18 instâncias, 10 instâncias com tamanho < 30
# VD_D_0000000070 - 440 frames, 22 instâncias, 17 instâncias com tamanho < 30
# VD_Y_0000000001 - 124 frames, 6 instâncias, 4 instâncias com tamanho < 30
# VD_Y_0000000002 - 563 frames, 25 instâncias, 13 instâncias com tamanho < 30
# VD_Y_0000000003 - 290 frames, 14 instâncias, 9 instâncias com tamanho < 30
# VD_Y_0000000004 - 221 frames, 10 instâncias, 6 instâncias com tamanho < 30
# VD_Y_0000000005 - 172 frames, 8 instâncias, 6 instâncias com tamanho < 30
# VD_Y_0000000006 - 702 frames, 34 instâncias, 24 instâncias com tamanho < 30
# VD_Y_0000000007 - 554 frames, 22 instâncias, 13 instâncias com tamanho < 30
# VD_Y_0000000008 - 1449 frames, 59 instâncias, 33 instâncias com tamanho < 30
# VD_Y_0000000009 - 129 frames, 6 instâncias, 5 instâncias com tamanho < 30
# VD_Y_0000000010 - 221 frames, 10 instâncias, 8 instâncias com tamanho < 30
# VD_Y_0000000011 - 550 frames, 27 instâncias, 20 instâncias com tamanho < 30
# VD_Y_0000000012 - 26 frames, 2 instâncias, 2 instâncias com tamanho < 30
# VD_Y_0000000013 - 366 frames, 15 instâncias, 9 instâncias com tamanho < 30
# VD_Y_0000000014 - 242 frames, 9 instâncias, 3 instâncias com tamanho < 30
# VD_Y_0000000015 - 272 frames, 13 instâncias, 9 instâncias com tamanho < 30
# VD_Y_0000000016 - 319 frames, 14 instâncias, 8 instâncias com tamanho < 30
# VD_Y_0000000017 - 364 frames, 18 instâncias, 13 instâncias com tamanho < 30
# VD_Y_0000000018 - 131 frames, 7 instâncias, 6 instâncias com tamanho < 30
# VD_Y_0000000019 - 125 frames, 7 instâncias, 7 instâncias com tamanho < 30
# VD_Y_0000000020 - 547 frames, 23 instâncias, 11 instâncias com tamanho < 30
# VD_Y_0000000021 - 385 frames, 19 instâncias, 15 instâncias com tamanho < 30
# VD_Y_0000000022 - 90 frames, 3 instâncias, 0 instâncias com tamanho < 30
# VD_Y_0000000023 - 170 frames, 7 instâncias, 3 instâncias com tamanho < 30
# VD_Y_0000000024 - 13 frames, 1 instâncias, 1 instâncias com tamanho < 30
# VD_Y_0000000025 - 241 frames, 12 instâncias, 7 instâncias com tamanho < 30
# VD_Y_0000000026 - 163 frames, 6 instâncias, 3 instâncias com tamanho < 30
# VD_Y_0000000027 - 141 frames, 6 instâncias, 3 instâncias com tamanho < 30
# VD_Y_0000000028 - 201 frames, 9 instâncias, 6 instâncias com tamanho < 30
# VD_Y_0000000029 - 275 frames, 11 instâncias, 4 instâncias com tamanho < 30
# VD_Y_0000000030 - 303 frames, 12 instâncias, 8 instâncias com tamanho < 30
# VD_Y_0000000031 - 928 frames, 35 instâncias, 17 instâncias com tamanho < 30
# VD_Y_0000000032 - 130 frames, 7 instâncias, 6 instâncias com tamanho < 30
# VD_Y_0000000033 - 221 frames, 10 instâncias, 6 instâncias com tamanho < 30
# VD_Y_0000000034 - 98 frames, 5 instâncias, 5 instâncias com tamanho < 30
# VD_Y_0000000035 - 271 frames, 10 instâncias, 5 instâncias com tamanho < 30
# VD_Y_0000000036 - 362 frames, 15 instâncias, 10 instâncias com tamanho < 30
# VD_Y_0000000037 - 377 frames, 16 instâncias, 10 instâncias com tamanho < 30
# VD_Y_0000000038 - 576 frames, 26 instâncias, 16 instâncias com tamanho < 30
# VD_Y_0000000039 - 179 frames, 9 instâncias, 6 instâncias com tamanho < 30
# VD_Y_0000000040 - 158 frames, 7 instâncias, 5 instâncias com tamanho < 30
# VD_Y_0000000041 - 144 frames, 5 instâncias, 1 instâncias com tamanho < 30
# VD_Y_0000000042 - 284 frames, 11 instâncias, 4 instâncias com tamanho < 30
# Total geral: 23226 frames, 1050 instâncias, 686 instâncias com tamanho < 30
#
# Resultados para 'NEUTRAL':
# VD_D_0000000043 - 295 frames, 15 instâncias, 12 instâncias com tamanho < 30
# VD_D_0000000044 - 174 frames, 9 instâncias, 7 instâncias com tamanho < 30
# VD_D_0000000045 - 240 frames, 14 instâncias, 11 instâncias com tamanho < 30
# VD_D_0000000046 - 807 frames, 40 instâncias, 26 instâncias com tamanho < 30
# VD_D_0000000047 - 725 frames, 38 instâncias, 30 instâncias com tamanho < 30
# VD_D_0000000048 - 843 frames, 44 instâncias, 35 instâncias com tamanho < 30
# VD_D_0000000049 - 527 frames, 30 instâncias, 24 instâncias com tamanho < 30
# VD_D_0000000050 - 456 frames, 23 instâncias, 16 instâncias com tamanho < 30
# VD_D_0000000051 - 1141 frames, 58 instâncias, 46 instâncias com tamanho < 30
# VD_D_0000000052 - 1204 frames, 61 instâncias, 47 instâncias com tamanho < 30
# VD_D_0000000053 - 331 frames, 15 instâncias, 9 instâncias com tamanho < 30
# VD_D_0000000054 - 687 frames, 37 instâncias, 26 instâncias com tamanho < 30
# VD_D_0000000055 - 302 frames, 14 instâncias, 10 instâncias com tamanho < 30
# VD_D_0000000056 - 1168 frames, 63 instâncias, 49 instâncias com tamanho < 30
# VD_D_0000000057 - 183 frames, 8 instâncias, 3 instâncias com tamanho < 30
# VD_D_0000000058 - 703 frames, 33 instâncias, 20 instâncias com tamanho < 30
# VD_D_0000000059 - 770 frames, 35 instâncias, 21 instâncias com tamanho < 30
# VD_D_0000000060 - 235 frames, 12 instâncias, 7 instâncias com tamanho < 30
# VD_D_0000000061 - 1235 frames, 61 instâncias, 47 instâncias com tamanho < 30
# VD_D_0000000062 - 902 frames, 47 instâncias, 33 instâncias com tamanho < 30
# VD_D_0000000063 - 645 frames, 35 instâncias, 29 instâncias com tamanho < 30
# VD_D_0000000064 - 1201 frames, 56 instâncias, 34 instâncias com tamanho < 30
# VD_D_0000000065 - 320 frames, 19 instâncias, 17 instâncias com tamanho < 30
# VD_D_0000000066 - 902 frames, 44 instâncias, 30 instâncias com tamanho < 30
# VD_D_0000000067 - 612 frames, 33 instâncias, 25 instâncias com tamanho < 30
# VD_D_0000000068 - 350 frames, 13 instâncias, 6 instâncias com tamanho < 30
# VD_D_0000000069 - 660 frames, 33 instâncias, 23 instâncias com tamanho < 30
# VD_D_0000000070 - 743 frames, 38 instâncias, 29 instâncias com tamanho < 30
# VD_Y_0000000001 - 222 frames, 6 instâncias, 1 instâncias com tamanho < 30
# VD_Y_0000000002 - 598 frames, 29 instâncias, 21 instâncias com tamanho < 30
# VD_Y_0000000003 - 552 frames, 25 instâncias, 16 instâncias com tamanho < 30
# VD_Y_0000000004 - 205 frames, 10 instâncias, 7 instâncias com tamanho < 30
# VD_Y_0000000005 - 439 frames, 19 instâncias, 13 instâncias com tamanho < 30
# VD_Y_0000000006 - 1110 frames, 58 instâncias, 45 instâncias com tamanho < 30
# VD_Y_0000000007 - 1037 frames, 43 instâncias, 34 instâncias com tamanho < 30
# VD_Y_0000000008 - 1553 frames, 71 instâncias, 50 instâncias com tamanho < 30
# VD_Y_0000000009 - 161 frames, 6 instâncias, 4 instâncias com tamanho < 30
# VD_Y_0000000010 - 458 frames, 21 instâncias, 14 instâncias com tamanho < 30
# VD_Y_0000000011 - 790 frames, 36 instâncias, 26 instâncias com tamanho < 30
# VD_Y_0000000012 - 259 frames, 11 instâncias, 6 instâncias com tamanho < 30
# VD_Y_0000000013 - 372 frames, 16 instâncias, 11 instâncias com tamanho < 30
# VD_Y_0000000014 - 148 frames, 8 instâncias, 6 instâncias com tamanho < 30
# VD_Y_0000000015 - 339 frames, 17 instâncias, 12 instâncias com tamanho < 30
# VD_Y_0000000016 - 282 frames, 13 instâncias, 8 instâncias com tamanho < 30
# VD_Y_0000000017 - 417 frames, 15 instâncias, 6 instâncias com tamanho < 30
# VD_Y_0000000018 - 335 frames, 16 instâncias, 11 instâncias com tamanho < 30
# VD_Y_0000000019 - 234 frames, 11 instâncias, 7 instâncias com tamanho < 30
# VD_Y_0000000020 - 709 frames, 36 instâncias, 26 instâncias com tamanho < 30
# VD_Y_0000000021 - 685 frames, 31 instâncias, 21 instâncias com tamanho < 30
# VD_Y_0000000022 - 137 frames, 5 instâncias, 3 instâncias com tamanho < 30
# VD_Y_0000000023 - 391 frames, 15 instâncias, 5 instâncias com tamanho < 30
# VD_Y_0000000024 - 149 frames, 6 instâncias, 3 instâncias com tamanho < 30
# VD_Y_0000000025 - 282 frames, 16 instâncias, 13 instâncias com tamanho < 30
# VD_Y_0000000026 - 156 frames, 7 instâncias, 4 instâncias com tamanho < 30
# VD_Y_0000000027 - 147 frames, 7 instâncias, 5 instâncias com tamanho < 30
# VD_Y_0000000028 - 260 frames, 11 instâncias, 6 instâncias com tamanho < 30
# VD_Y_0000000029 - 724 frames, 34 instâncias, 21 instâncias com tamanho < 30
# VD_Y_0000000030 - 500 frames, 23 instâncias, 16 instâncias com tamanho < 30
# VD_Y_0000000031 - 908 frames, 40 instâncias, 24 instâncias com tamanho < 30
# VD_Y_0000000032 - 144 frames, 6 instâncias, 2 instâncias com tamanho < 30
# VD_Y_0000000033 - 178 frames, 9 instâncias, 7 instâncias com tamanho < 30
# VD_Y_0000000034 - 86 frames, 5 instâncias, 4 instâncias com tamanho < 30
# VD_Y_0000000035 - 341 frames, 13 instâncias, 6 instâncias com tamanho < 30
# VD_Y_0000000036 - 385 frames, 17 instâncias, 11 instâncias com tamanho < 30
# VD_Y_0000000037 - 692 frames, 32 instâncias, 25 instâncias com tamanho < 30
# VD_Y_0000000038 - 940 frames, 49 instâncias, 37 instâncias com tamanho < 30
# VD_Y_0000000039 - 212 frames, 10 instâncias, 9 instâncias com tamanho < 30
# VD_Y_0000000040 - 237 frames, 9 instâncias, 4 instâncias com tamanho < 30
# VD_Y_0000000041 - 229 frames, 11 instâncias, 7 instâncias com tamanho < 30
# VD_Y_0000000042 - 243 frames, 11 instâncias, 8 instâncias com tamanho < 30
# Total geral: 36607 frames, 1762 instâncias, 1237 instâncias com tamanho < 30

# %%
count_happy = count_neutral = count_others = 0

for vd_info_file in FILE_LIST_SEED_VD_INFO:
    vd_info_df = pd.read_csv(vd_info_file)
    #print("vd_info_df", vd_info_df['link_video'])

    count_happy += len([emotion for emotion in vd_info_df['link_video'] if 'happy' in str(vd_info_df['link_video'])])
    count_neutral += len([emotion for emotion in vd_info_df['link_video'] if 'neutral' in str(vd_info_df['link_video'])])
    count_others += len([emotion for emotion in vd_info_df['link_video']if 'others' in str(vd_info_df['link_video'])])

print("Number of happy seeds:", count_happy)
print("Number of neutral seeds:", count_neutral)
print("Number of other seeds:", count_others)
# Out:
# Number of happy seeds: 54
# Number of neutral seeds: 84
# Number of other seeds: 73

# %%
FILE_LIST_LABELED_SEED
# Out:
# ['..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000001\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000002\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000003\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000004\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000005\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000006\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000007\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000008\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000009\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000010\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000011\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000012\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000013\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000014\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000015\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000016\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000017\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000018\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000019\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000020\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000021\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000022\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000023\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000024\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000025\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000026\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000027\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000028\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000029\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000030\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000031\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000032\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000033\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000034\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000035\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000036\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000037\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000038\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000039\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000040\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000041\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000042\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000043\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000044\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000045\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000046\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000047\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000048\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000049\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000050\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000051\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000052\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000053\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000054\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000055\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000056\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000057\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000058\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000059\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000060\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000061\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000062\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000063\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000064\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000065\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000066\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000067\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000068\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000069\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000070\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000071\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000072\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000073\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000074\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000075\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000076\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000077\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000078\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000079\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000080\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000081\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000082\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000083\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000084\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000085\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000086\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000087\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000088\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000089\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000090\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000091\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000092\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000093\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000094\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000095\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000096\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000097\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000098\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000099\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000100\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000101\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000102\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000103\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000104\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000105\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000106\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000107\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000108\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000109\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000110\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000111\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000112\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000113\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000114\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000115\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000116\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000117\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000118\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000119\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000120\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000121\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000122\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000123\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000124\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000125\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000126\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000127\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000128\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000129\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000130\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000131\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000132\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000133\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000134\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000135\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000136\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000137\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000138\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000139\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000140\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000141\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000142\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000143\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000144\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000145\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000146\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000147\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000148\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000149\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000150\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000151\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000152\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000153\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000154\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000155\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000156\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000157\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000158\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000159\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000160\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000161\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000162\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000163\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000164\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000165\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000166\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000167\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000168\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000169\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000170\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000171\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000172\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000173\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000174\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000175\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000176\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000177\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000178\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000179\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000180\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000181\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000182\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000183\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000184\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000185\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000186\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000187\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000188\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000189\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000190\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000191\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000192\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000193\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000194\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000195\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000196\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000197\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000198\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000199\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000200\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000201\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000202\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000203\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000204\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000205\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000206\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000207\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000208\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000209\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000210\\VD_LABELED_L0.CSV',
#  '..\\Dataset_not_normalized\\REF-Gold-Label_not_normalized\\VD_R_0000000211\\VD_LABELED_L0.CSV']

# %% [markdown]
# ## Automatic Labeler

# %%
current_labeling_class = 0 # Change for the correspondent number of your labeling class
frame_distance_threshold = 2
euclidean_distance_threshold = 1.2
current_total_saved_series = 0

matches_memory = []
all_matches_memory = []
all_mass_memory = []
all_idxs_match_frame_seq_memory = []
all_seeds_occurrences_len = []

all_data_memory = []

for j, labeled_file in enumerate(FILE_LIST_LABELED_SEED[:]):
    RESUME_DT = pd.DataFrame()
    print(f'\nSearch with seed: {os.path.basename(os.path.dirname(labeled_file))}\n')

    current_seed_matches_memory = []
    current_seed_all_matches_memory = []
    current_seed_all_mass_memory = []

    current_seed_data_memory = []
    
    for i, current_path_location in enumerate(FILE_LIST_VD_MEASURE):

        path_dir = os.path.dirname(labeled_file)
        vd_labeled_path = os.path.join(path_dir, fp.VD_LABELED_L0)
        vd_labeled = pd.read_csv(vd_labeled_path)
        vd_labeled.drop(columns=['Unnamed: 0'], inplace=True)

        all_class = man_lab_fun.GET_ALL_CLASSES(vd_labeled)
        label_name = all_class[current_labeling_class]

        reference_measures = man_lab_fun.GET_MEASURES_FROM_CLASS(vd_labeled, label_name)

        frames = man_lab_fun.GET_FRAMES_FROM_CLASS(vd_labeled, label_name)

        all_measures_in_frame_interval = vd_labeled.loc[0:len(frames)]

        selected_measures_in_frame_interval = all_measures_in_frame_interval[reference_measures]

        dict_label_parameters = {'label_name': label_name, 'reference_measures': reference_measures}

        RESUME_DT, matches, all_matches, all_mass, idxs_match_frame_seq, occurrences_len = aut_lab_fun.label_current_series(current_path_location, RESUME_DT, selected_measures_in_frame_interval, dict_label_parameters, os.path.dirname(labeled_file), LABELED_FILE_NAME=fp.VD_LABELED_L0, distance_threshold=euclidean_distance_threshold, frame_threshold=frame_distance_threshold)  

        current_seed_data_memory.append([])

        for k, (frame, dist) in enumerate(idxs_match_frame_seq):
            frame_dist_len_data = []
            frame_dist_len_data.append(frame)
            frame_dist_len_data.append(dist)
            frame_dist_len_data.append(occurrences_len[k])

            current_seed_data_memory[i].append(frame_dist_len_data)

    all_data_memory.append(current_seed_data_memory)

    final_sum = RESUME_DT['final'].sum()
    current_total_saved_series += final_sum
    print(f'Number of occurrences found for the current seed: {final_sum}') 
    print(f'Total of occurrences: {current_total_saved_series}')
# Out:
# Search with seed: VD_R_0000000001
#
# Number of occurrences found for the current seed: 4
# Total of occurrences: 4
#
# Search with seed: VD_R_0000000002
#
# Number of occurrences found for the current seed: 2
# Total of occurrences: 6
#
# Search with seed: VD_R_0000000003
#
# Number of occurrences found for the current seed: 2
# Total of occurrences: 8
#
# Search with seed: VD_R_0000000004
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 44
#      40 selected_measures_in_frame_interval = all_measures_in_frame_interval[reference_measures]
#      42 dict_label_parameters = {'label_name': label_name, 'reference_measures': reference_measures}
# ---> 44 RESUME_DT, matches, all_matches, all_mass, idxs_match_frame_seq, occurrences_len = aut_lab_fun.label_current_series(current_path_location, RESUME_DT, selected_measures_in_frame_interval, dict_label_parameters, os.path.dirname(labeled_file), LABELED_FILE_NAME=fp.VD_LABELED_L0, distance_threshold=euclidean_distance_threshold, frame_threshold=frame_distance_threshold)
#      46 current_seed_data_memory.append([])
#      48 for k, (frame, dist) in enumerate(idxs_match_frame_seq):
#
# File d:\Estagio\biosignals-time-series-dataset\06 - Automatic Labeler\..\lib\automatic_labeler_functions.py:133, in label_current_series(current_path_location, RESUME_DT, selected_measures_in_frame_interval, dict_label_parameters, seed_name, LABELED_FILE_NAME, distance_threshold, frame_threshold)
#     131 # Save CSV file
#     132 VD_LABELED_DT.reset_index(drop=True, inplace=True)
# --> 133 VD_LABELED_DT.to_csv(VD_LABEL_PATH)
#     135 return RESUME_DT, matches_memory, all_matches_memory, all_mass_memory, idxs_match_frame_seq, occurrences_len
#
# File d:\miniconda3\envs\biosignals-dataset_env\lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File d:\miniconda3\envs\biosignals-dataset_env\lib\site-packages\pandas\core\generic.py:3967, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3956 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3958 formatter = DataFrameFormatter(
#    3959     frame=df,
#    3960     header=header,
#    (...)
#    3964     decimal=decimal,
#    3965 )
# -> 3967 return DataFrameRenderer(formatter).to_csv(
#    3968     path_or_buf,
#    3969     lineterminator=lineterminator,
#    3970     sep=sep,
#    3971     encoding=encoding,
#    3972     errors=errors,
#    3973     compression=compression,
#    3974     quoting=quoting,
#    3975     columns=columns,
#    3976     index_label=index_label,
#    3977     mode=mode,
#    3978     chunksize=chunksize,
#    3979     quotechar=quotechar,
#    3980     date_format=date_format,
#    3981     doublequote=doublequote,
#    3982     escapechar=escapechar,
#    3983     storage_options=storage_options,
#    3984 )
#
# File d:\miniconda3\envs\biosignals-dataset_env\lib\site-packages\pandas\io\formats\format.py:1014, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#     993     created_buffer = False
#     995 csv_formatter = CSVFormatter(
#     996     path_or_buf=path_or_buf,
#     997     lineterminator=lineterminator,
#    (...)
#    1012     formatter=self.fmt,
#    1013 )
# -> 1014 csv_formatter.save()
#    1016 if created_buffer:
#    1017     assert isinstance(path_or_buf, StringIO)
#
# File d:\miniconda3\envs\biosignals-dataset_env\lib\site-packages\pandas\io\formats\csvs.py:270, in CSVFormatter.save(self)
#     251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#    (...)
#     258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     self.writer = csvlib.writer(
#     261         handles.handle,
#     262         lineterminator=self.lineterminator,
#    (...)
#     267         quotechar=self.quotechar,
#     268     )
# --> 270     self._save()
#
# File d:\miniconda3\envs\biosignals-dataset_env\lib\site-packages\pandas\io\formats\csvs.py:275, in CSVFormatter._save(self)
#     273 if self._need_to_save_header:
#     274     self._save_header()
# --> 275 self._save_body()
#
# File d:\miniconda3\envs\biosignals-dataset_env\lib\site-packages\pandas\io\formats\csvs.py:313, in CSVFormatter._save_body(self)
#     311 if start_i >= end_i:
#     312     break
# --> 313 self._save_chunk(start_i, end_i)
#
# File d:\miniconda3\envs\biosignals-dataset_env\lib\site-packages\pandas\io\formats\csvs.py:323, in CSVFormatter._save_chunk(self, start_i, end_i)
#     320 res = df._get_values_for_csv(**self._number_format)
#     321 data = list(res._iter_column_arrays())
# --> 323 ix = self.data_index[slicer]._get_values_for_csv(**self._number_format)
#     324 libwriters.write_csv_rows(
#     325     data,
#     326     ix,
#    (...)
#     329     self.writer,
#     330 )
#
# File d:\miniconda3\envs\biosignals-dataset_env\lib\site-packages\pandas\core\indexes\base.py:1478, in Index._get_values_for_csv(self, na_rep, decimal, float_format, date_format, quoting)
#    1469 def _get_values_for_csv(
#    1470     self,
#    1471     *,
#    (...)
#    1476     quoting=None,
#    1477 ) -> npt.NDArray[np.object_]:
# -> 1478     return get_values_for_csv(
#    1479         self._values,
#    1480         na_rep=na_rep,
#    1481         decimal=decimal,
#    1482         float_format=float_format,
#    1483         date_format=date_format,
#    1484         quoting=quoting,
#    1485     )
#
# File d:\miniconda3\envs\biosignals-dataset_env\lib\site-packages\pandas\core\indexes\base.py:7873, in get_values_for_csv(values, date_format, na_rep, quoting, float_format, decimal)
#    7871         values = values.astype(f"<U{itemsize}")
#    7872 else:
# -> 7873     values = np.array(values, dtype="object")
#    7875 values[mask] = na_rep
#    7876 values = values.astype(object, copy=False)
#
# KeyboardInterrupt:

# %%
current_labeling_class_others = 0  # Este valor será ajustado dinamicamente com base na presença de "others"
frame_distance_threshold_others = 2
euclidean_distance_threshold_others = 1.2
current_total_saved_series_others = 0

matches_memory_others = []
all_matches_memory_others = []
all_mass_memory_others = []
all_idxs_match_frame_seq_memory_others = []
all_seeds_occurrences_len_others = []

all_data_memory_others = []

for j_others, labeled_file_others in enumerate(FILE_LIST_LABELED_SEED[:]):
    RESUME_DT_others = pd.DataFrame()

    # Carregar o DataFrame rotulado
    path_dir_others = os.path.dirname(labeled_file_others)
    vd_labeled_path_others = os.path.join(path_dir_others, fp.VD_LABELED_L0)
    vd_labeled_others = pd.read_csv(vd_labeled_path_others)
    vd_labeled_others.drop(columns=['Unnamed: 0'], inplace=True)

    # Obter todas as classes disponíveis na seed
    all_class_others = man_lab_fun.GET_ALL_CLASSES(vd_labeled_others)

    # Verificar se a classe "others" está presente
    if "others" not in all_class_others:
        print(f"Skipping seed: {os.path.basename(os.path.dirname(labeled_file_others))} (class 'others' not found)")
        continue

    # Ajustar o índice para a classe "others"
    current_labeling_class_others = all_class_others.index("others")
    label_name_others = all_class_others[current_labeling_class_others]

    print(f'\nProcessing seed: {os.path.basename(os.path.dirname(labeled_file_others))} with class "others"\n')

    current_seed_matches_memory_others = []
    current_seed_all_matches_memory_others = []
    current_seed_all_mass_memory_others = []
    current_seed_data_memory_others = []

    for i_others, current_path_location_others in enumerate(FILE_LIST_VD_MEASURE):
        # Obter as medidas e os frames associados à classe "others"
        reference_measures_others = man_lab_fun.GET_MEASURES_FROM_CLASS(vd_labeled_others, label_name_others)
        frames_others = man_lab_fun.GET_FRAMES_FROM_CLASS(vd_labeled_others, label_name_others)

        # Selecionar os frames de interesse e medidas correspondentes
        all_measures_in_frame_interval_others = vd_labeled_others.loc[0:len(frames_others)]
        selected_measures_in_frame_interval_others = all_measures_in_frame_interval_others[reference_measures_others]

        dict_label_parameters_others = {'label_name': label_name_others, 'reference_measures': reference_measures_others}

        # Processar a série atual
        RESUME_DT_others, matches_others, all_matches_others, all_mass_others, idxs_match_frame_seq_others, occurrences_len_others = aut_lab_fun.label_current_series(
            current_path_location_others, RESUME_DT_others, selected_measures_in_frame_interval_others, dict_label_parameters_others, 
            os.path.dirname(labeled_file_others), LABELED_FILE_NAME="VD_LABELED_L0_others",  # Nome do arquivo ajustado
            distance_threshold=euclidean_distance_threshold_others, frame_threshold=frame_distance_threshold_others
        )

        # Armazenar os resultados
        current_seed_data_memory_others.append([])

        for k_others, (frame_others, dist_others) in enumerate(idxs_match_frame_seq_others):
            frame_dist_len_data_others = []
            frame_dist_len_data_others.append(frame_others)
            frame_dist_len_data_others.append(dist_others)
            frame_dist_len_data_others.append(occurrences_len_others[k_others])

            current_seed_data_memory_others[i_others].append(frame_dist_len_data_others)

    all_data_memory_others.append(current_seed_data_memory_others)

    final_sum_others = RESUME_DT_others['final'].sum()
    current_total_saved_series_others += final_sum_others
    print(f'Number of occurrences found for the current seed: {final_sum_others}')
    print(f'Total of occurrences: {current_total_saved_series_others}')
# Out:
# Skipping seed: VD_R_0000000001 (class 'others' not found)
# Skipping seed: VD_R_0000000002 (class 'others' not found)
# Skipping seed: VD_R_0000000003 (class 'others' not found)
# Skipping seed: VD_R_0000000004 (class 'others' not found)
# Skipping seed: VD_R_0000000005 (class 'others' not found)
# Skipping seed: VD_R_0000000006 (class 'others' not found)
# Skipping seed: VD_R_0000000007 (class 'others' not found)
# Skipping seed: VD_R_0000000008 (class 'others' not found)
# Skipping seed: VD_R_0000000009 (class 'others' not found)
# Skipping seed: VD_R_0000000010 (class 'others' not found)
# Skipping seed: VD_R_0000000011 (class 'others' not found)
# Skipping seed: VD_R_0000000012 (class 'others' not found)
# Skipping seed: VD_R_0000000013 (class 'others' not found)
# Skipping seed: VD_R_0000000014 (class 'others' not found)
# Skipping seed: VD_R_0000000015 (class 'others' not found)
# Skipping seed: VD_R_0000000016 (class 'others' not found)
# Skipping seed: VD_R_0000000017 (class 'others' not found)
# Skipping seed: VD_R_0000000018 (class 'others' not found)
# Skipping seed: VD_R_0000000019 (class 'others' not found)
# Skipping seed: VD_R_0000000020 (class 'others' not found)
# Skipping seed: VD_R_0000000021 (class 'others' not found)
# Skipping seed: VD_R_0000000022 (class 'others' not found)
# Skipping seed: VD_R_0000000023 (class 'others' not found)
# Skipping seed: VD_R_0000000024 (class 'others' not found)
# Skipping seed: VD_R_0000000025 (class 'others' not found)
# Skipping seed: VD_R_0000000026 (class 'others' not found)
# Skipping seed: VD_R_0000000027 (class 'others' not found)
# Skipping seed: VD_R_0000000028 (class 'others' not found)
# Skipping seed: VD_R_0000000029 (class 'others' not found)
# Skipping seed: VD_R_0000000030 (class 'others' not found)
# Skipping seed: VD_R_0000000031 (class 'others' not found)
# Skipping seed: VD_R_0000000032 (class 'others' not found)
# Skipping seed: VD_R_0000000033 (class 'others' not found)
# Skipping seed: VD_R_0000000034 (class 'others' not found)
# Skipping seed: VD_R_0000000035 (class 'others' not found)
# Skipping seed: VD_R_0000000036 (class 'others' not found)
# Skipping seed: VD_R_0000000037 (class 'others' not found)
# Skipping seed: VD_R_0000000038 (class 'others' not found)
# Skipping seed: VD_R_0000000039 (class 'others' not found)
# Skipping seed: VD_R_0000000040 (class 'others' not found)
# Skipping seed: VD_R_0000000041 (class 'others' not found)
# Skipping seed: VD_R_0000000042 (class 'others' not found)
# Skipping seed: VD_R_0000000043 (class 'others' not found)
# Skipping seed: VD_R_0000000044 (class 'others' not found)
# Skipping seed: VD_R_0000000045 (class 'others' not found)
# Skipping seed: VD_R_0000000046 (class 'others' not found)
# Skipping seed: VD_R_0000000047 (class 'others' not found)
# Skipping seed: VD_R_0000000048 (class 'others' not found)
# Skipping seed: VD_R_0000000049 (class 'others' not found)
# Skipping seed: VD_R_0000000050 (class 'others' not found)
# Skipping seed: VD_R_0000000051 (class 'others' not found)
# Skipping seed: VD_R_0000000052 (class 'others' not found)
# Skipping seed: VD_R_0000000053 (class 'others' not found)
# Skipping seed: VD_R_0000000054 (class 'others' not found)
# Skipping seed: VD_R_0000000055 (class 'others' not found)
# Skipping seed: VD_R_0000000056 (class 'others' not found)
# Skipping seed: VD_R_0000000057 (class 'others' not found)
# Skipping seed: VD_R_0000000058 (class 'others' not found)
# Skipping seed: VD_R_0000000059 (class 'others' not found)
# Skipping seed: VD_R_0000000060 (class 'others' not found)
# Skipping seed: VD_R_0000000061 (class 'others' not found)
# Skipping seed: VD_R_0000000062 (class 'others' not found)
# Skipping seed: VD_R_0000000063 (class 'others' not found)
# Skipping seed: VD_R_0000000064 (class 'others' not found)
# Skipping seed: VD_R_0000000065 (class 'others' not found)
# Skipping seed: VD_R_0000000066 (class 'others' not found)
# Skipping seed: VD_R_0000000067 (class 'others' not found)
# Skipping seed: VD_R_0000000068 (class 'others' not found)
# Skipping seed: VD_R_0000000069 (class 'others' not found)
# Skipping seed: VD_R_0000000070 (class 'others' not found)
# Skipping seed: VD_R_0000000071 (class 'others' not found)
# Skipping seed: VD_R_0000000072 (class 'others' not found)
# Skipping seed: VD_R_0000000073 (class 'others' not found)
# Skipping seed: VD_R_0000000074 (class 'others' not found)
# Skipping seed: VD_R_0000000075 (class 'others' not found)
# Skipping seed: VD_R_0000000076 (class 'others' not found)
# Skipping seed: VD_R_0000000077 (class 'others' not found)
# Skipping seed: VD_R_0000000078 (class 'others' not found)
# Skipping seed: VD_R_0000000079 (class 'others' not found)
# Skipping seed: VD_R_0000000080 (class 'others' not found)
# Skipping seed: VD_R_0000000081 (class 'others' not found)
# Skipping seed: VD_R_0000000082 (class 'others' not found)
# Skipping seed: VD_R_0000000083 (class 'others' not found)
# Skipping seed: VD_R_0000000084 (class 'others' not found)
# Skipping seed: VD_R_0000000085 (class 'others' not found)
# Skipping seed: VD_R_0000000086 (class 'others' not found)
# Skipping seed: VD_R_0000000087 (class 'others' not found)
# Skipping seed: VD_R_0000000088 (class 'others' not found)
# Skipping seed: VD_R_0000000089 (class 'others' not found)
# Skipping seed: VD_R_0000000090 (class 'others' not found)
# Skipping seed: VD_R_0000000091 (class 'others' not found)
# Skipping seed: VD_R_0000000092 (class 'others' not found)
# Skipping seed: VD_R_0000000093 (class 'others' not found)
# Skipping seed: VD_R_0000000094 (class 'others' not found)
# Skipping seed: VD_R_0000000095 (class 'others' not found)
# Skipping seed: VD_R_0000000096 (class 'others' not found)
# Skipping seed: VD_R_0000000097 (class 'others' not found)
# Skipping seed: VD_R_0000000098 (class 'others' not found)
# Skipping seed: VD_R_0000000099 (class 'others' not found)
# Skipping seed: VD_R_0000000100 (class 'others' not found)
# Skipping seed: VD_R_0000000101 (class 'others' not found)
# Skipping seed: VD_R_0000000102 (class 'others' not found)
# Skipping seed: VD_R_0000000103 (class 'others' not found)
# Skipping seed: VD_R_0000000104 (class 'others' not found)
# Skipping seed: VD_R_0000000105 (class 'others' not found)
# Skipping seed: VD_R_0000000106 (class 'others' not found)
# Skipping seed: VD_R_0000000107 (class 'others' not found)
# Skipping seed: VD_R_0000000108 (class 'others' not found)
# Skipping seed: VD_R_0000000109 (class 'others' not found)
# Skipping seed: VD_R_0000000110 (class 'others' not found)
# Skipping seed: VD_R_0000000111 (class 'others' not found)
# Skipping seed: VD_R_0000000112 (class 'others' not found)
# Skipping seed: VD_R_0000000113 (class 'others' not found)
# Skipping seed: VD_R_0000000114 (class 'others' not found)
# Skipping seed: VD_R_0000000115 (class 'others' not found)
# Skipping seed: VD_R_0000000116 (class 'others' not found)
# Skipping seed: VD_R_0000000117 (class 'others' not found)
# Skipping seed: VD_R_0000000118 (class 'others' not found)
# Skipping seed: VD_R_0000000119 (class 'others' not found)
# Skipping seed: VD_R_0000000120 (class 'others' not found)
# Skipping seed: VD_R_0000000121 (class 'others' not found)
# Skipping seed: VD_R_0000000122 (class 'others' not found)
# Skipping seed: VD_R_0000000123 (class 'others' not found)
# Skipping seed: VD_R_0000000124 (class 'others' not found)
# Skipping seed: VD_R_0000000125 (class 'others' not found)
# Skipping seed: VD_R_0000000126 (class 'others' not found)
# Skipping seed: VD_R_0000000127 (class 'others' not found)
# Skipping seed: VD_R_0000000128 (class 'others' not found)
# Skipping seed: VD_R_0000000129 (class 'others' not found)
# Skipping seed: VD_R_0000000130 (class 'others' not found)
# Skipping seed: VD_R_0000000131 (class 'others' not found)
# Skipping seed: VD_R_0000000132 (class 'others' not found)
# Skipping seed: VD_R_0000000133 (class 'others' not found)
# Skipping seed: VD_R_0000000134 (class 'others' not found)
# Skipping seed: VD_R_0000000135 (class 'others' not found)
# Skipping seed: VD_R_0000000136 (class 'others' not found)
# Skipping seed: VD_R_0000000137 (class 'others' not found)
# Skipping seed: VD_R_0000000138 (class 'others' not found)
#
# Processing seed: VD_R_0000000139 with class "others"
#
# Number of occurrences found for the current seed: 30
# Total of occurrences: 30
#
# Processing seed: VD_R_0000000140 with class "others"
#
# Number of occurrences found for the current seed: 30
# Total of occurrences: 60
#
# Processing seed: VD_R_0000000141 with class "others"
#
# Number of occurrences found for the current seed: 61
# Total of occurrences: 121
#
# Processing seed: VD_R_0000000142 with class "others"
#
# Number of occurrences found for the current seed: 11
# Total of occurrences: 132
#
# Processing seed: VD_R_0000000143 with class "others"
#
# Number of occurrences found for the current seed: 11
# Total of occurrences: 143
#
# Processing seed: VD_R_0000000144 with class "others"
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[55], line 54
#      51 dict_label_parameters_2 = {'label_name': label_name_2, 'reference_measures': reference_measures_2}
#      53 # Processar a série atual
# ---> 54 RESUME_DT_2, matches_2, all_matches_2, all_mass_2, idxs_match_frame_seq_2, occurrences_len_2 = aut_lab_fun.label_current_series(
#      55     current_path_location_2, RESUME_DT_2, selected_measures_in_frame_interval_2, dict_label_parameters_2,
#      56     os.path.dirname(labeled_file_2), LABELED_FILE_NAME="VD_LABELED_L0_others",  # Nome do arquivo ajustado
#      57     distance_threshold=euclidean_distance_threshold_2, frame_threshold=frame_distance_threshold_2
#      58 )
#      60 # Armazenar os resultados
#      61 current_seed_data_memory_2.append([])
#
# File d:\Estagio\biosignals-time-series-dataset\06 - Automatic Labeler\..\lib\automatic_labeler_functions.py:133, in label_current_series(current_path_location, RESUME_DT, selected_measures_in_frame_interval, dict_label_parameters, seed_name, LABELED_FILE_NAME, distance_threshold, frame_threshold)
#     131 # Save CSV file
#     132 VD_LABELED_DT.reset_index(drop=True, inplace=True)
# --> 133 VD_LABELED_DT.to_csv(VD_LABEL_PATH)
#     135 return RESUME_DT, matches_memory, all_matches_memory, all_mass_memory, idxs_match_frame_seq, occurrences_len
#
# File d:\miniconda3\envs\biosignals-dataset_env\lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File d:\miniconda3\envs\biosignals-dataset_env\lib\site-packages\pandas\core\generic.py:3967, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3956 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3958 formatter = DataFrameFormatter(
#    3959     frame=df,
#    3960     header=header,
#    (...)
#    3964     decimal=decimal,
#    3965 )
# -> 3967 return DataFrameRenderer(formatter).to_csv(
#    3968     path_or_buf,
#    3969     lineterminator=lineterminator,
#    3970     sep=sep,
#    3971     encoding=encoding,
#    3972     errors=errors,
#    3973     compression=compression,
#    3974     quoting=quoting,
#    3975     columns=columns,
#    3976     index_label=index_label,
#    3977     mode=mode,
#    3978     chunksize=chunksize,
#    3979     quotechar=quotechar,
#    3980     date_format=date_format,
#    3981     doublequote=doublequote,
#    3982     escapechar=escapechar,
#    3983     storage_options=storage_options,
#    3984 )
#
# File d:\miniconda3\envs\biosignals-dataset_env\lib\site-packages\pandas\io\formats\format.py:1014, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#     993     created_buffer = False
#     995 csv_formatter = CSVFormatter(
#     996     path_or_buf=path_or_buf,
#     997     lineterminator=lineterminator,
#    (...)
#    1012     formatter=self.fmt,
#    1013 )
# -> 1014 csv_formatter.save()
#    1016 if created_buffer:
#    1017     assert isinstance(path_or_buf, StringIO)
#
# File d:\miniconda3\envs\biosignals-dataset_env\lib\site-packages\pandas\io\formats\csvs.py:270, in CSVFormatter.save(self)
#     251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#    (...)
#     258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     self.writer = csvlib.writer(
#     261         handles.handle,
#     262         lineterminator=self.lineterminator,
#    (...)
#     267         quotechar=self.quotechar,
#     268     )
# --> 270     self._save()
#
# File d:\miniconda3\envs\biosignals-dataset_env\lib\site-packages\pandas\io\formats\csvs.py:275, in CSVFormatter._save(self)
#     273 if self._need_to_save_header:
#     274     self._save_header()
# --> 275 self._save_body()
#
# File d:\miniconda3\envs\biosignals-dataset_env\lib\site-packages\pandas\io\formats\csvs.py:313, in CSVFormatter._save_body(self)
#     311 if start_i >= end_i:
#     312     break
# --> 313 self._save_chunk(start_i, end_i)
#
# File d:\miniconda3\envs\biosignals-dataset_env\lib\site-packages\pandas\io\formats\csvs.py:320, in CSVFormatter._save_chunk(self, start_i, end_i)
#     317 slicer = slice(start_i, end_i)
#     318 df = self.obj.iloc[slicer]
# --> 320 res = df._get_values_for_csv(**self._number_format)
#     321 data = list(res._iter_column_arrays())
#     323 ix = self.data_index[slicer]._get_values_for_csv(**self._number_format)
#
# File d:\miniconda3\envs\biosignals-dataset_env\lib\site-packages\pandas\core\frame.py:1410, in DataFrame._get_values_for_csv(self, float_format, date_format, decimal, na_rep, quoting)
#    1400 def _get_values_for_csv(
#    1401     self,
#    1402     *,
#    (...)
#    1408 ) -> Self:
#    1409     # helper used by to_csv
# -> 1410     mgr = self._mgr.get_values_for_csv(
#    1411         float_format=float_format,
#    1412         date_format=date_format,
#    1413         decimal=decimal,
#    1414         na_rep=na_rep,
#    1415         quoting=quoting,
#    1416     )
#    1417     # error: Incompatible return value type (got "DataFrame", expected "Self")
#    1418     return self._constructor_from_mgr(mgr, axes=mgr.axes)
#
# File d:\miniconda3\envs\biosignals-dataset_env\lib\site-packages\pandas\core\internals\managers.py:466, in BaseBlockManager.get_values_for_csv(self, float_format, date_format, decimal, na_rep, quoting)
#     459 def get_values_for_csv(
#     460     self, *, float_format, date_format, decimal, na_rep: str = "nan", quoting=None
#     461 ) -> Self:
#     462     """
#     463     Convert values to native types (strings / python objects) that are used
#     464     in formatting (repr / csv).
#     465     """
# --> 466     return self.apply(
#     467         "get_values_for_csv",
#     468         na_rep=na_rep,
#     469         quoting=quoting,
#     470         float_format=float_format,
#     471         date_format=date_format,
#     472         decimal=decimal,
#     473     )
#
# File d:\miniconda3\envs\biosignals-dataset_env\lib\site-packages\pandas\core\internals\managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File d:\miniconda3\envs\biosignals-dataset_env\lib\site-packages\pandas\core\internals\blocks.py:780, in Block.get_values_for_csv(self, float_format, date_format, decimal, na_rep, quoting)
#     775 @final
#     776 def get_values_for_csv(
#     777     self, *, float_format, date_format, decimal, na_rep: str = "nan", quoting=None
#     778 ) -> Block:
#     779     """convert to our native types format"""
# --> 780     result = get_values_for_csv(
#     781         self.values,
#     782         na_rep=na_rep,
#     783         quoting=quoting,
#     784         float_format=float_format,
#     785         date_format=date_format,
#     786         decimal=decimal,
#     787     )
#     788     return self.make_block(result)
#
# File d:\miniconda3\envs\biosignals-dataset_env\lib\site-packages\pandas\core\indexes\base.py:7838, in get_values_for_csv(values, date_format, na_rep, quoting, float_format, decimal)
#    7835 else:
#    7836     values = np.array(values, dtype="object")
# -> 7838 values[mask] = na_rep
#    7839 values = values.astype(object, copy=False)
#    7840 return values
#
# KeyboardInterrupt:

# %% [markdown]
# ## True matches

# %%
number_irregulars = 0
for i, seed in enumerate(all_data_memory):
    #print(f"=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-= Seed {i+1} =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=")
    for j, video in enumerate(seed):
        #print(f" =-=-=-=-=-= Video: {j+1}, number of occurrences: {len(video)} =-=-=-=-=-=")
        for occurrence in video:
            if occurrence[2] != 30:
                #print(f"Frame start: {occurrence[0]}, euclidean_dist: {occurrence[1]}, len occurrence: {occurrence[2]}")
                print(f"Seed: {i+1}, Video: {j+1}, Frame start: {occurrence[0]}, euclidean_dist: {occurrence[1]}, len occurrence: {occurrence[2]}")
                number_irregulars += 1
print("Number irregulars:", number_irregulars)
# Out:
# Seed: 5, Video: 3, Frame start: 325, euclidean_dist: 4.45922929946909, len occurrence: 16
# Seed: 5, Video: 14, Frame start: 6700, euclidean_dist: 1.9169064294619393, len occurrence: 24
# Seed: 7, Video: 57, Frame start: 2211, euclidean_dist: 2.101794128426182, len occurrence: 28
# Seed: 20, Video: 8, Frame start: 355, euclidean_dist: 5.0711307549862354, len occurrence: 18
# Seed: 20, Video: 14, Frame start: 6296, euclidean_dist: 5.808902011147796, len occurrence: 16
# Seed: 21, Video: 20, Frame start: 3488, euclidean_dist: 4.334903618668159, len occurrence: 21
# Seed: 21, Video: 34, Frame start: 4750, euclidean_dist: 3.7323127715735898, len occurrence: 12
# Seed: 22, Video: 5, Frame start: 1819, euclidean_dist: 4.355284369910563, len occurrence: 19
# Seed: 23, Video: 4, Frame start: 4858, euclidean_dist: 3.6295397083061522, len occurrence: 26
# Seed: 23, Video: 4, Frame start: 356, euclidean_dist: 5.469529143955719, len occurrence: 26
# Seed: 23, Video: 5, Frame start: 2435, euclidean_dist: 3.588142502231968, len occurrence: 26
# Seed: 23, Video: 5, Frame start: 1650, euclidean_dist: 3.836616916761408, len occurrence: 26
# Seed: 23, Video: 8, Frame start: 1672, euclidean_dist: 3.2100915993116117, len occurrence: 26
# Seed: 23, Video: 9, Frame start: 4762, euclidean_dist: 3.9704243961036965, len occurrence: 26
# Seed: 23, Video: 9, Frame start: 2508, euclidean_dist: 5.467530484288136, len occurrence: 26
# Seed: 23, Video: 13, Frame start: 2571, euclidean_dist: 3.757087083834355, len occurrence: 26
# Seed: 23, Video: 14, Frame start: 5954, euclidean_dist: 5.675221976850605, len occurrence: 26
# Seed: 23, Video: 17, Frame start: 1199, euclidean_dist: 4.430218540837509, len occurrence: 26
# Seed: 23, Video: 19, Frame start: 1298, euclidean_dist: 4.502438710350211, len occurrence: 26
# Seed: 23, Video: 21, Frame start: 2994, euclidean_dist: 5.4267966032316295, len occurrence: 26
# Seed: 23, Video: 26, Frame start: 1895, euclidean_dist: 2.510245887392521, len occurrence: 26
# Seed: 23, Video: 28, Frame start: 657, euclidean_dist: 5.0838385881637995, len occurrence: 26
# Seed: 23, Video: 30, Frame start: 4246, euclidean_dist: 2.8579670527290237, len occurrence: 26
# Seed: 23, Video: 31, Frame start: 1947, euclidean_dist: 4.714644845615566, len occurrence: 26
# Seed: 23, Video: 34, Frame start: 4303, euclidean_dist: 3.4756084807422147, len occurrence: 26
# Seed: 23, Video: 35, Frame start: 7022, euclidean_dist: 5.0990195135927845, len occurrence: 26
# Seed: 23, Video: 35, Frame start: 7014, euclidean_dist: 5.0990195135927845, len occurrence: 26
# Seed: 23, Video: 35, Frame start: 7006, euclidean_dist: 5.0990195135927845, len occurrence: 26
# Seed: 23, Video: 36, Frame start: 1405, euclidean_dist: 4.666790314846006, len occurrence: 26
# Seed: 23, Video: 39, Frame start: 3179, euclidean_dist: 5.2868489750653, len occurrence: 26
# Seed: 23, Video: 48, Frame start: 4895, euclidean_dist: 4.216897619613771, len occurrence: 26
# Seed: 23, Video: 59, Frame start: 5661, euclidean_dist: 5.014851883776639, len occurrence: 26
# Seed: 23, Video: 65, Frame start: 2488, euclidean_dist: 4.853493420297046, len occurrence: 26
# Seed: 23, Video: 66, Frame start: 1315, euclidean_dist: 4.381827804205529, len occurrence: 26
# Seed: 24, Video: 6, Frame start: 1984, euclidean_dist: 5.972595150317157, len occurrence: 22
# Seed: 27, Video: 16, Frame start: 5015, euclidean_dist: 6.477939995487711, len occurrence: 25
# Seed: 29, Video: 12, Frame start: 3536, euclidean_dist: 5.426112637573139, len occurrence: 18
# Seed: 29, Video: 34, Frame start: 5277, euclidean_dist: 3.790111788939907, len occurrence: 18
# Seed: 33, Video: 16, Frame start: 5699, euclidean_dist: 4.915373445393094, len occurrence: 21
# Seed: 35, Video: 5, Frame start: 401, euclidean_dist: 5.54988342519076, len occurrence: 16
# Seed: 36, Video: 6, Frame start: 357, euclidean_dist: 6.548303362718519, len occurrence: 16
# Seed: 36, Video: 12, Frame start: 2441, euclidean_dist: 6.735930719832952, len occurrence: 24
# Seed: 36, Video: 16, Frame start: 2621, euclidean_dist: 6.296414864613599, len occurrence: 10
# Seed: 36, Video: 16, Frame start: 3344, euclidean_dist: 5.5607789467552085, len occurrence: 22
# Seed: 37, Video: 6, Frame start: 4606, euclidean_dist: 5.691002871115025, len occurrence: 5
# Seed: 37, Video: 34, Frame start: 7543, euclidean_dist: 5.202239553533195, len occurrence: 20
# Seed: 38, Video: 16, Frame start: 3896, euclidean_dist: 4.19773148562325, len occurrence: 18
# Seed: 40, Video: 5, Frame start: 2643, euclidean_dist: 4.298910023069234, len occurrence: 5
# Seed: 43, Video: 12, Frame start: 354, euclidean_dist: 6.581548204185353, len occurrence: 20
# Seed: 45, Video: 15, Frame start: 1725, euclidean_dist: 5.486844652959328, len occurrence: 13
# Seed: 45, Video: 65, Frame start: 1607, euclidean_dist: 6.941862430138216, len occurrence: 26
# Seed: 46, Video: 36, Frame start: 9867, euclidean_dist: 4.219934668552787, len occurrence: 21
# Seed: 46, Video: 57, Frame start: 2234, euclidean_dist: 4.218045866279889, len occurrence: 20
# Seed: 48, Video: 8, Frame start: 396, euclidean_dist: 5.5483497601733704, len occurrence: 8
# Seed: 49, Video: 36, Frame start: 12491, euclidean_dist: 2.756532351462526, len occurrence: 19
# Seed: 50, Video: 5, Frame start: 2886, euclidean_dist: 4.487606783270998, len occurrence: 23
# Seed: 50, Video: 20, Frame start: 3780, euclidean_dist: 4.741041951550273, len occurrence: 21
# Seed: 52, Video: 36, Frame start: 5831, euclidean_dist: 3.7923649618634765, len occurrence: 22
# Seed: 60, Video: 1, Frame start: 861, euclidean_dist: 4.037383234239498, len occurrence: 14
# Seed: 60, Video: 1, Frame start: 1054, euclidean_dist: 4.368238141662258, len occurrence: 14
# Seed: 60, Video: 1, Frame start: 959, euclidean_dist: 3.826901028788709, len occurrence: 14
# Seed: 60, Video: 2, Frame start: 634, euclidean_dist: 4.091550420712656, len occurrence: 14
# Seed: 60, Video: 2, Frame start: 1513, euclidean_dist: 3.0597974966390837, len occurrence: 14
# Seed: 60, Video: 3, Frame start: 1059, euclidean_dist: 3.57224751796761, len occurrence: 14
# Seed: 60, Video: 3, Frame start: 779, euclidean_dist: 3.7262578534440225, len occurrence: 14
# Seed: 60, Video: 3, Frame start: 1327, euclidean_dist: 4.3060516858291145, len occurrence: 14
# Seed: 60, Video: 3, Frame start: 788, euclidean_dist: 3.8839694084065783, len occurrence: 14
# Seed: 60, Video: 3, Frame start: 985, euclidean_dist: 3.5405823492328072, len occurrence: 14
# Seed: 60, Video: 3, Frame start: 475, euclidean_dist: 3.737609994048534, len occurrence: 14
# Seed: 60, Video: 4, Frame start: 6033, euclidean_dist: 3.970732895089189, len occurrence: 14
# Seed: 60, Video: 4, Frame start: 969, euclidean_dist: 4.290630480490626, len occurrence: 14
# Seed: 60, Video: 4, Frame start: 3403, euclidean_dist: 4.078026166518135, len occurrence: 14
# Seed: 60, Video: 4, Frame start: 3310, euclidean_dist: 3.8436556872271455, len occurrence: 14
# Seed: 60, Video: 4, Frame start: 2992, euclidean_dist: 3.045865222593505, len occurrence: 14
# Seed: 60, Video: 4, Frame start: 5694, euclidean_dist: 4.039581769600775, len occurrence: 14
# Seed: 60, Video: 4, Frame start: 4568, euclidean_dist: 4.083601107547931, len occurrence: 14
# Seed: 60, Video: 4, Frame start: 4217, euclidean_dist: 4.110404812287242, len occurrence: 14
# Seed: 60, Video: 4, Frame start: 3161, euclidean_dist: 3.8978853986205633, len occurrence: 14
# Seed: 60, Video: 4, Frame start: 990, euclidean_dist: 4.048815371551749, len occurrence: 14
# Seed: 60, Video: 4, Frame start: 892, euclidean_dist: 3.9105417036811727, len occurrence: 14
# Seed: 60, Video: 4, Frame start: 318, euclidean_dist: 4.2580415269136695, len occurrence: 14
# Seed: 60, Video: 4, Frame start: 5513, euclidean_dist: 3.904805187997447, len occurrence: 14
# Seed: 60, Video: 4, Frame start: 3103, euclidean_dist: 3.5380090577888907, len occurrence: 14
# Seed: 60, Video: 4, Frame start: 3778, euclidean_dist: 3.36645187903399, len occurrence: 14
# Seed: 60, Video: 4, Frame start: 2883, euclidean_dist: 3.6961845663156625, len occurrence: 14
# Seed: 60, Video: 4, Frame start: 1861, euclidean_dist: 3.850138773215775, len occurrence: 14
# Seed: 60, Video: 5, Frame start: 3720, euclidean_dist: 3.4416389355626595, len occurrence: 14
# Seed: 60, Video: 5, Frame start: 1859, euclidean_dist: 4.035193214762345, len occurrence: 14
# Seed: 60, Video: 5, Frame start: 2300, euclidean_dist: 3.3096699667367164, len occurrence: 14
# Seed: 60, Video: 5, Frame start: 3030, euclidean_dist: 4.008413692066183, len occurrence: 14
# Seed: 60, Video: 5, Frame start: 2074, euclidean_dist: 3.8606598595704287, len occurrence: 14
# Seed: 60, Video: 5, Frame start: 998, euclidean_dist: 4.045875347027428, len occurrence: 14
# Seed: 60, Video: 5, Frame start: 2043, euclidean_dist: 4.153479472754803, len occurrence: 14
# Seed: 60, Video: 5, Frame start: 1094, euclidean_dist: 4.179218687172092, len occurrence: 14
# Seed: 60, Video: 5, Frame start: 2150, euclidean_dist: 3.8849460618790945, len occurrence: 14
# Seed: 60, Video: 6, Frame start: 2178, euclidean_dist: 3.324577721548688, len occurrence: 14
# Seed: 60, Video: 6, Frame start: 1293, euclidean_dist: 3.593521008568686, len occurrence: 14
# Seed: 60, Video: 6, Frame start: 3343, euclidean_dist: 3.7995511230545573, len occurrence: 14
# Seed: 60, Video: 6, Frame start: 664, euclidean_dist: 4.26175074950817, len occurrence: 14
# Seed: 60, Video: 6, Frame start: 2586, euclidean_dist: 3.9749955281719322, len occurrence: 14
# Seed: 60, Video: 6, Frame start: 1695, euclidean_dist: 3.5473856920658444, len occurrence: 14
# Seed: 60, Video: 6, Frame start: 3874, euclidean_dist: 3.8371883390518677, len occurrence: 14
# Seed: 60, Video: 6, Frame start: 2596, euclidean_dist: 4.218886473538956, len occurrence: 14
# Seed: 60, Video: 6, Frame start: 4395, euclidean_dist: 4.248393134075253, len occurrence: 14
# Seed: 60, Video: 6, Frame start: 2481, euclidean_dist: 3.9169229161261656, len occurrence: 14
# Seed: 60, Video: 6, Frame start: 1593, euclidean_dist: 3.7269732828841002, len occurrence: 14
# Seed: 60, Video: 6, Frame start: 4412, euclidean_dist: 3.4130799413088457, len occurrence: 14
# Seed: 60, Video: 6, Frame start: 3266, euclidean_dist: 2.6112351474883595, len occurrence: 14
# Seed: 60, Video: 6, Frame start: 1611, euclidean_dist: 2.98727934352323, len occurrence: 14
# Seed: 60, Video: 6, Frame start: 4040, euclidean_dist: 3.768774760662404, len occurrence: 14
# Seed: 60, Video: 6, Frame start: 1486, euclidean_dist: 3.9569585417508417, len occurrence: 14
# Seed: 60, Video: 6, Frame start: 1999, euclidean_dist: 2.5505475636105626, len occurrence: 7
# Seed: 60, Video: 6, Frame start: 2522, euclidean_dist: 4.178720024039921, len occurrence: 14
# Seed: 60, Video: 6, Frame start: 3938, euclidean_dist: 4.086047864430103, len occurrence: 14
# Seed: 60, Video: 6, Frame start: 1264, euclidean_dist: 4.06505097752278, len occurrence: 14
# Seed: 60, Video: 6, Frame start: 2798, euclidean_dist: 4.153918209222992, len occurrence: 14
# Seed: 60, Video: 6, Frame start: 3182, euclidean_dist: 3.433852749418872, len occurrence: 14
# Seed: 60, Video: 6, Frame start: 1905, euclidean_dist: 4.038475595835977, len occurrence: 14
# Seed: 60, Video: 7, Frame start: 1091, euclidean_dist: 3.7038867725880955, len occurrence: 14
# Seed: 60, Video: 7, Frame start: 2968, euclidean_dist: 3.742031027600853, len occurrence: 14
# Seed: 60, Video: 7, Frame start: 1189, euclidean_dist: 3.7091801268937736, len occurrence: 14
# Seed: 60, Video: 7, Frame start: 2573, euclidean_dist: 4.224606292785313, len occurrence: 14
# Seed: 60, Video: 7, Frame start: 2382, euclidean_dist: 3.7749990888107168, len occurrence: 14
# Seed: 60, Video: 7, Frame start: 1128, euclidean_dist: 4.118538576878531, len occurrence: 14
# Seed: 60, Video: 7, Frame start: 3366, euclidean_dist: 4.144552578155959, len occurrence: 14
# Seed: 60, Video: 7, Frame start: 1332, euclidean_dist: 3.8666328119070394, len occurrence: 14
# Seed: 60, Video: 7, Frame start: 2461, euclidean_dist: 3.8894082087495097, len occurrence: 14
# Seed: 60, Video: 7, Frame start: 3088, euclidean_dist: 3.8958965325256223, len occurrence: 14
# Seed: 60, Video: 7, Frame start: 3153, euclidean_dist: 3.647207793309263, len occurrence: 14
# Seed: 60, Video: 7, Frame start: 1829, euclidean_dist: 3.123459161087995, len occurrence: 14
# Seed: 60, Video: 8, Frame start: 543, euclidean_dist: 4.059660743938259, len occurrence: 14
# Seed: 60, Video: 8, Frame start: 1345, euclidean_dist: 2.469508059005081, len occurrence: 14
# Seed: 60, Video: 8, Frame start: 3525, euclidean_dist: 4.32633179182635, len occurrence: 14
# Seed: 60, Video: 8, Frame start: 3306, euclidean_dist: 3.343305414642102, len occurrence: 14
# Seed: 60, Video: 8, Frame start: 528, euclidean_dist: 3.5342187867994728, len occurrence: 14
# Seed: 60, Video: 8, Frame start: 1014, euclidean_dist: 3.5661946094148016, len occurrence: 14
# Seed: 60, Video: 9, Frame start: 1965, euclidean_dist: 2.1724411369888657, len occurrence: 14
# Seed: 60, Video: 9, Frame start: 5305, euclidean_dist: 3.773172005167999, len occurrence: 14
# Seed: 60, Video: 9, Frame start: 4290, euclidean_dist: 3.534175414476413, len occurrence: 14
# Seed: 60, Video: 9, Frame start: 4062, euclidean_dist: 4.21907706618795, len occurrence: 14
# Seed: 60, Video: 9, Frame start: 4777, euclidean_dist: 4.228132537595002, len occurrence: 14
# Seed: 60, Video: 9, Frame start: 4556, euclidean_dist: 3.5230074897166226, len occurrence: 14
# Seed: 60, Video: 9, Frame start: 9393, euclidean_dist: 3.5297819865617552, len occurrence: 14
# Seed: 60, Video: 9, Frame start: 5127, euclidean_dist: 4.085724592587545, len occurrence: 14
# Seed: 60, Video: 9, Frame start: 5448, euclidean_dist: 4.153194324135371, len occurrence: 14
# Seed: 60, Video: 9, Frame start: 1853, euclidean_dist: 3.4359510810278855, len occurrence: 14
# Seed: 60, Video: 9, Frame start: 5866, euclidean_dist: 4.264988370420852, len occurrence: 14
# Seed: 60, Video: 9, Frame start: 3652, euclidean_dist: 3.9626201148714038, len occurrence: 14
# Seed: 60, Video: 9, Frame start: 7096, euclidean_dist: 4.087028882704843, len occurrence: 14
# Seed: 60, Video: 9, Frame start: 5969, euclidean_dist: 3.8486873195370013, len occurrence: 14
# Seed: 60, Video: 10, Frame start: 6811, euclidean_dist: 4.395195494329622, len occurrence: 14
# Seed: 60, Video: 10, Frame start: 4603, euclidean_dist: 3.521972754849881, len occurrence: 14
# Seed: 60, Video: 10, Frame start: 7961, euclidean_dist: 3.826637160414457, len occurrence: 14
# Seed: 60, Video: 10, Frame start: 7332, euclidean_dist: 3.97294698961048, len occurrence: 14
# Seed: 60, Video: 10, Frame start: 6308, euclidean_dist: 4.28034772995533, len occurrence: 14
# Seed: 60, Video: 10, Frame start: 5028, euclidean_dist: 4.397453857140745, len occurrence: 14
# Seed: 60, Video: 10, Frame start: 5002, euclidean_dist: 3.4065907484842604, len occurrence: 14
# Seed: 60, Video: 11, Frame start: 1724, euclidean_dist: 2.929082301767918, len occurrence: 14
# Seed: 60, Video: 11, Frame start: 1189, euclidean_dist: 3.008962301441978, len occurrence: 14
# Seed: 60, Video: 12, Frame start: 1167, euclidean_dist: 4.020200206332608, len occurrence: 14
# Seed: 60, Video: 12, Frame start: 2451, euclidean_dist: 2.9440950282075624, len occurrence: 10
# Seed: 60, Video: 12, Frame start: 2589, euclidean_dist: 3.971391929090712, len occurrence: 14
# Seed: 60, Video: 12, Frame start: 2199, euclidean_dist: 3.7942013887424526, len occurrence: 14
# Seed: 60, Video: 12, Frame start: 2754, euclidean_dist: 4.089309174377914, len occurrence: 14
# Seed: 60, Video: 12, Frame start: 3986, euclidean_dist: 3.8061739279635924, len occurrence: 14
# Seed: 60, Video: 12, Frame start: 2729, euclidean_dist: 3.984814403466614, len occurrence: 14
# Seed: 60, Video: 12, Frame start: 2570, euclidean_dist: 3.6820860054666, len occurrence: 14
# Seed: 60, Video: 12, Frame start: 2057, euclidean_dist: 3.5821572403451363, len occurrence: 14
# Seed: 60, Video: 12, Frame start: 2381, euclidean_dist: 3.811829231073556, len occurrence: 14
# Seed: 60, Video: 12, Frame start: 2126, euclidean_dist: 3.044385045527826, len occurrence: 14
# Seed: 60, Video: 12, Frame start: 1068, euclidean_dist: 3.844693870516277, len occurrence: 14
# Seed: 60, Video: 13, Frame start: 821, euclidean_dist: 2.4792714334870034, len occurrence: 14
# Seed: 60, Video: 14, Frame start: 2810, euclidean_dist: 4.164832488581457, len occurrence: 14
# Seed: 60, Video: 14, Frame start: 2429, euclidean_dist: 3.745301695982012, len occurrence: 14
# Seed: 60, Video: 14, Frame start: 4236, euclidean_dist: 3.63031790725512, len occurrence: 14
# Seed: 60, Video: 14, Frame start: 6892, euclidean_dist: 4.271527458002259, len occurrence: 14
# Seed: 60, Video: 14, Frame start: 508, euclidean_dist: 3.9431095516829306, len occurrence: 14
# Seed: 60, Video: 14, Frame start: 2702, euclidean_dist: 4.108609865530529, len occurrence: 14
# Seed: 60, Video: 14, Frame start: 383, euclidean_dist: 3.2294475719006557, len occurrence: 14
# Seed: 60, Video: 14, Frame start: 6762, euclidean_dist: 4.068770533249523, len occurrence: 14
# Seed: 60, Video: 14, Frame start: 5549, euclidean_dist: 3.675944012258863, len occurrence: 14
# Seed: 60, Video: 14, Frame start: 6359, euclidean_dist: 4.017196472174966, len occurrence: 14
# Seed: 60, Video: 14, Frame start: 3495, euclidean_dist: 3.973937637222378, len occurrence: 14
# Seed: 60, Video: 14, Frame start: 8535, euclidean_dist: 3.4361893924359115, len occurrence: 14
# Seed: 60, Video: 14, Frame start: 7061, euclidean_dist: 4.144780561105176, len occurrence: 14
# Seed: 60, Video: 14, Frame start: 5842, euclidean_dist: 4.212950971648053, len occurrence: 14
# Seed: 60, Video: 14, Frame start: 6511, euclidean_dist: 4.3500631803136605, len occurrence: 14
# Seed: 60, Video: 14, Frame start: 2488, euclidean_dist: 3.8765063070517054, len occurrence: 14
# Seed: 60, Video: 14, Frame start: 4939, euclidean_dist: 3.6137543075142124, len occurrence: 14
# Seed: 60, Video: 14, Frame start: 1196, euclidean_dist: 2.893227071628744, len occurrence: 14
# Seed: 60, Video: 14, Frame start: 7614, euclidean_dist: 4.12933468051263, len occurrence: 8
# Seed: 60, Video: 14, Frame start: 7486, euclidean_dist: 3.668843166454375, len occurrence: 14
# Seed: 60, Video: 14, Frame start: 2907, euclidean_dist: 3.622853422672811, len occurrence: 14
# Seed: 60, Video: 14, Frame start: 5238, euclidean_dist: 3.939004102817854, len occurrence: 14
# Seed: 60, Video: 14, Frame start: 3430, euclidean_dist: 3.1489243562226594, len occurrence: 14
# Seed: 60, Video: 14, Frame start: 5370, euclidean_dist: 3.5928594657132513, len occurrence: 14
# Seed: 60, Video: 14, Frame start: 597, euclidean_dist: 2.659076136475295, len occurrence: 14
# Seed: 60, Video: 14, Frame start: 8358, euclidean_dist: 3.2064972640950664, len occurrence: 14
# Seed: 60, Video: 14, Frame start: 2293, euclidean_dist: 4.300137584005034, len occurrence: 14
# Seed: 60, Video: 15, Frame start: 1719, euclidean_dist: 3.6478291557109648, len occurrence: 7
# Seed: 60, Video: 15, Frame start: 1592, euclidean_dist: 3.0392073547869414, len occurrence: 14
# Seed: 60, Video: 16, Frame start: 1791, euclidean_dist: 4.200939308960819, len occurrence: 14
# Seed: 60, Video: 16, Frame start: 3084, euclidean_dist: 4.22362586086335, len occurrence: 14
# Seed: 60, Video: 16, Frame start: 5743, euclidean_dist: 3.086797885245969, len occurrence: 14
# Seed: 60, Video: 16, Frame start: 5885, euclidean_dist: 3.7985710395176002, len occurrence: 14
# Seed: 60, Video: 16, Frame start: 648, euclidean_dist: 2.950028648238038, len occurrence: 14
# Seed: 60, Video: 16, Frame start: 3777, euclidean_dist: 3.5600388247230255, len occurrence: 14
# Seed: 60, Video: 17, Frame start: 5736, euclidean_dist: 3.994119786498711, len occurrence: 14
# Seed: 60, Video: 17, Frame start: 5931, euclidean_dist: 4.1299491984091565, len occurrence: 14
# Seed: 60, Video: 18, Frame start: 168, euclidean_dist: 3.953536237087877, len occurrence: 14
# Seed: 60, Video: 19, Frame start: 5801, euclidean_dist: 2.1668674186735464, len occurrence: 14
# Seed: 60, Video: 19, Frame start: 4233, euclidean_dist: 3.076461753114253, len occurrence: 14
# Seed: 60, Video: 19, Frame start: 8110, euclidean_dist: 3.294043125980646, len occurrence: 14
# Seed: 60, Video: 19, Frame start: 3726, euclidean_dist: 4.137432714389186, len occurrence: 14
# Seed: 60, Video: 19, Frame start: 8052, euclidean_dist: 4.01568097237818, len occurrence: 14
# Seed: 60, Video: 19, Frame start: 1782, euclidean_dist: 3.450691915262441, len occurrence: 14
# Seed: 60, Video: 19, Frame start: 1656, euclidean_dist: 3.749522171367558, len occurrence: 14
# Seed: 60, Video: 19, Frame start: 3673, euclidean_dist: 3.9318430521820313, len occurrence: 14
# Seed: 60, Video: 19, Frame start: 7897, euclidean_dist: 3.6281089582143164, len occurrence: 14
# Seed: 60, Video: 19, Frame start: 6650, euclidean_dist: 3.6650395743296533, len occurrence: 14
# Seed: 60, Video: 19, Frame start: 6492, euclidean_dist: 4.2919849579927165, len occurrence: 14
# Seed: 60, Video: 19, Frame start: 2427, euclidean_dist: 3.82976544897376, len occurrence: 14
# Seed: 60, Video: 19, Frame start: 1149, euclidean_dist: 3.0819299461750513, len occurrence: 14
# Seed: 60, Video: 19, Frame start: 3297, euclidean_dist: 3.9224864349210558, len occurrence: 14
# Seed: 60, Video: 19, Frame start: 5186, euclidean_dist: 3.881488848488806, len occurrence: 14
# Seed: 60, Video: 19, Frame start: 8229, euclidean_dist: 3.32335134612635, len occurrence: 14
# Seed: 60, Video: 19, Frame start: 4550, euclidean_dist: 3.7642270403893368, len occurrence: 14
# Seed: 60, Video: 20, Frame start: 5723, euclidean_dist: 3.3280672447625648, len occurrence: 14
# Seed: 60, Video: 20, Frame start: 5757, euclidean_dist: 3.8926324143986952, len occurrence: 14
# Seed: 60, Video: 20, Frame start: 5855, euclidean_dist: 4.00050679758927, len occurrence: 14
# Seed: 60, Video: 20, Frame start: 3108, euclidean_dist: 4.061593172881869, len occurrence: 14
# Seed: 60, Video: 20, Frame start: 4131, euclidean_dist: 3.4583239016339276, len occurrence: 14
# Seed: 60, Video: 20, Frame start: 2206, euclidean_dist: 3.599189103488827, len occurrence: 14
# Seed: 60, Video: 20, Frame start: 959, euclidean_dist: 2.195491626127156, len occurrence: 14
# Seed: 60, Video: 20, Frame start: 3637, euclidean_dist: 4.2277048869529965, len occurrence: 14
# Seed: 60, Video: 20, Frame start: 2632, euclidean_dist: 3.0157533997169894, len occurrence: 14
# Seed: 60, Video: 20, Frame start: 3251, euclidean_dist: 3.0977570566672146, len occurrence: 9
# Seed: 60, Video: 20, Frame start: 3614, euclidean_dist: 4.290592649216916, len occurrence: 14
# Seed: 60, Video: 20, Frame start: 4653, euclidean_dist: 3.9830328014796956, len occurrence: 14
# Seed: 60, Video: 20, Frame start: 652, euclidean_dist: 4.2068712196439035, len occurrence: 14
# Seed: 60, Video: 20, Frame start: 4435, euclidean_dist: 3.743510126778362, len occurrence: 14
# Seed: 60, Video: 20, Frame start: 5495, euclidean_dist: 4.082120490502327, len occurrence: 14
# Seed: 60, Video: 20, Frame start: 1079, euclidean_dist: 3.7003137706320866, len occurrence: 14
# Seed: 60, Video: 21, Frame start: 2004, euclidean_dist: 3.713682907995055, len occurrence: 14
# Seed: 60, Video: 21, Frame start: 4277, euclidean_dist: 4.060007783571203, len occurrence: 14
# Seed: 60, Video: 21, Frame start: 3319, euclidean_dist: 4.089933021264587, len occurrence: 14
# Seed: 60, Video: 21, Frame start: 1191, euclidean_dist: 3.883539935592625, len occurrence: 14
# Seed: 60, Video: 21, Frame start: 2045, euclidean_dist: 2.7914262105573946, len occurrence: 14
# Seed: 60, Video: 21, Frame start: 3107, euclidean_dist: 3.3439372528206555, len occurrence: 14
# Seed: 60, Video: 21, Frame start: 914, euclidean_dist: 3.217704689535813, len occurrence: 14
# Seed: 60, Video: 22, Frame start: 6689, euclidean_dist: 4.119508408311404, len occurrence: 14
# Seed: 60, Video: 22, Frame start: 6754, euclidean_dist: 3.8752948145907986, len occurrence: 14
# Seed: 60, Video: 22, Frame start: 3236, euclidean_dist: 3.3675268288157385, len occurrence: 14
# Seed: 60, Video: 22, Frame start: 699, euclidean_dist: 3.7587279512362466, len occurrence: 14
# Seed: 60, Video: 22, Frame start: 6150, euclidean_dist: 3.8658244592464737, len occurrence: 14
# Seed: 60, Video: 22, Frame start: 4389, euclidean_dist: 3.883848466524684, len occurrence: 14
# Seed: 60, Video: 22, Frame start: 4465, euclidean_dist: 4.324052810986009, len occurrence: 14
# Seed: 60, Video: 22, Frame start: 813, euclidean_dist: 4.267682034275358, len occurrence: 14
# Seed: 60, Video: 22, Frame start: 7584, euclidean_dist: 3.0264465883676652, len occurrence: 14
# Seed: 60, Video: 23, Frame start: 1522, euclidean_dist: 3.641480185310895, len occurrence: 14
# Seed: 60, Video: 23, Frame start: 823, euclidean_dist: 2.295880750287114, len occurrence: 14
# Seed: 60, Video: 23, Frame start: 1086, euclidean_dist: 3.931738774746936, len occurrence: 14
# Seed: 60, Video: 23, Frame start: 495, euclidean_dist: 3.6402666152166305, len occurrence: 14
# Seed: 60, Video: 23, Frame start: 1027, euclidean_dist: 3.706995361455265, len occurrence: 14
# Seed: 60, Video: 23, Frame start: 1861, euclidean_dist: 3.661050595224849, len occurrence: 14
# Seed: 60, Video: 23, Frame start: 814, euclidean_dist: 3.666050234556271, len occurrence: 14
# Seed: 60, Video: 23, Frame start: 383, euclidean_dist: 3.6430992110181024, len occurrence: 14
# Seed: 60, Video: 23, Frame start: 1169, euclidean_dist: 3.954516445867615, len occurrence: 14
# Seed: 60, Video: 23, Frame start: 320, euclidean_dist: 4.0285552393945, len occurrence: 14
# Seed: 60, Video: 24, Frame start: 4921, euclidean_dist: 4.0987276014821665, len occurrence: 14
# Seed: 60, Video: 24, Frame start: 2746, euclidean_dist: 4.159377630444402, len occurrence: 14
# Seed: 60, Video: 24, Frame start: 3939, euclidean_dist: 3.9821472292726146, len occurrence: 14
# Seed: 60, Video: 24, Frame start: 812, euclidean_dist: 4.226123607184294, len occurrence: 14
# Seed: 60, Video: 25, Frame start: 2227, euclidean_dist: 3.488508622470808, len occurrence: 14
# Seed: 60, Video: 25, Frame start: 5326, euclidean_dist: 3.7402496400038223, len occurrence: 14
# Seed: 60, Video: 25, Frame start: 1427, euclidean_dist: 4.117883344183095, len occurrence: 14
# Seed: 60, Video: 25, Frame start: 1752, euclidean_dist: 3.6450152553678277, len occurrence: 14
# Seed: 60, Video: 25, Frame start: 1693, euclidean_dist: 4.139148397433768, len occurrence: 14
# Seed: 60, Video: 25, Frame start: 4347, euclidean_dist: 3.5821128748825783, len occurrence: 14
# Seed: 60, Video: 25, Frame start: 4191, euclidean_dist: 3.884323155666293, len occurrence: 14
# Seed: 60, Video: 25, Frame start: 3297, euclidean_dist: 4.0943610995049085, len occurrence: 14
# Seed: 60, Video: 25, Frame start: 360, euclidean_dist: 4.037431249669915, len occurrence: 14
# Seed: 60, Video: 25, Frame start: 1321, euclidean_dist: 3.70236277121445, len occurrence: 14
# Seed: 60, Video: 26, Frame start: 1109, euclidean_dist: 2.945959584749956, len occurrence: 14
# Seed: 60, Video: 27, Frame start: 2581, euclidean_dist: 3.2857341373405005, len occurrence: 14
# Seed: 60, Video: 27, Frame start: 3481, euclidean_dist: 4.108266237422987, len occurrence: 14
# Seed: 60, Video: 27, Frame start: 1119, euclidean_dist: 3.2406955216436377, len occurrence: 14
# Seed: 60, Video: 27, Frame start: 3998, euclidean_dist: 4.41809384496264, len occurrence: 14
# Seed: 60, Video: 27, Frame start: 2127, euclidean_dist: 4.026168529490303, len occurrence: 14
# Seed: 60, Video: 27, Frame start: 4321, euclidean_dist: 3.8844131890194697, len occurrence: 14
# Seed: 60, Video: 27, Frame start: 1060, euclidean_dist: 3.9624922202210127, len occurrence: 14
# Seed: 60, Video: 28, Frame start: 1424, euclidean_dist: 3.9434936987924716, len occurrence: 14
# Seed: 60, Video: 28, Frame start: 4369, euclidean_dist: 3.2541984762002136, len occurrence: 14
# Seed: 60, Video: 28, Frame start: 1303, euclidean_dist: 4.01192612132837, len occurrence: 14
# Seed: 60, Video: 28, Frame start: 121, euclidean_dist: 4.031268848779871, len occurrence: 14
# Seed: 60, Video: 28, Frame start: 2970, euclidean_dist: 4.021126105251414, len occurrence: 14
# Seed: 60, Video: 28, Frame start: 4666, euclidean_dist: 4.053263045982876, len occurrence: 14
# Seed: 60, Video: 28, Frame start: 602, euclidean_dist: 3.947006164950086, len occurrence: 14
# Seed: 60, Video: 28, Frame start: 768, euclidean_dist: 4.1373773774761355, len occurrence: 14
# Seed: 60, Video: 28, Frame start: 69, euclidean_dist: 4.282558053444271, len occurrence: 14
# Seed: 60, Video: 28, Frame start: 551, euclidean_dist: 4.235176558885322, len occurrence: 14
# Seed: 60, Video: 28, Frame start: 649, euclidean_dist: 2.1507562086467753, len occurrence: 14
# Seed: 60, Video: 28, Frame start: 1610, euclidean_dist: 4.2918153482297825, len occurrence: 14
# Seed: 60, Video: 30, Frame start: 4512, euclidean_dist: 3.711354599692331, len occurrence: 14
# Seed: 60, Video: 30, Frame start: 320, euclidean_dist: 3.9772468429303625, len occurrence: 14
# Seed: 60, Video: 30, Frame start: 169, euclidean_dist: 3.9468369065482705, len occurrence: 14
# Seed: 60, Video: 30, Frame start: 3245, euclidean_dist: 4.297528367231529, len occurrence: 14
# Seed: 60, Video: 30, Frame start: 658, euclidean_dist: 3.6235007820193057, len occurrence: 14
# Seed: 60, Video: 30, Frame start: 2485, euclidean_dist: 3.2499425411357836, len occurrence: 14
# Seed: 60, Video: 31, Frame start: 2818, euclidean_dist: 3.3513827079517853, len occurrence: 14
# Seed: 60, Video: 31, Frame start: 2053, euclidean_dist: 3.9671523033446023, len occurrence: 14
# Seed: 60, Video: 32, Frame start: 1625, euclidean_dist: 3.8971890589168865, len occurrence: 14
# Seed: 60, Video: 32, Frame start: 1572, euclidean_dist: 3.8922647360393214, len occurrence: 14
# Seed: 60, Video: 32, Frame start: 636, euclidean_dist: 3.7496959899716806, len occurrence: 14
# Seed: 60, Video: 32, Frame start: 1284, euclidean_dist: 3.4440773000610445, len occurrence: 14
# Seed: 60, Video: 33, Frame start: 1756, euclidean_dist: 4.2425584605451645, len occurrence: 14
# Seed: 60, Video: 34, Frame start: 3107, euclidean_dist: 4.057504734353954, len occurrence: 14
# Seed: 60, Video: 34, Frame start: 1301, euclidean_dist: 4.2677091538053675, len occurrence: 14
# Seed: 60, Video: 34, Frame start: 277, euclidean_dist: 3.765145955553218, len occurrence: 14
# Seed: 60, Video: 34, Frame start: 2210, euclidean_dist: 2.0947370399020713, len occurrence: 14
# Seed: 60, Video: 34, Frame start: 8218, euclidean_dist: 3.763129460063356, len occurrence: 14
# Seed: 60, Video: 34, Frame start: 8733, euclidean_dist: 3.4240243092370135, len occurrence: 14
# Seed: 60, Video: 34, Frame start: 7269, euclidean_dist: 2.848062674278873, len occurrence: 14
# Seed: 60, Video: 34, Frame start: 331, euclidean_dist: 3.8374782259174345, len occurrence: 14
# Seed: 60, Video: 34, Frame start: 4486, euclidean_dist: 4.191329864037012, len occurrence: 14
# Seed: 60, Video: 34, Frame start: 3446, euclidean_dist: 3.53234119247778, len occurrence: 14
# Seed: 60, Video: 34, Frame start: 7852, euclidean_dist: 4.138519969648302, len occurrence: 14
# Seed: 60, Video: 34, Frame start: 4622, euclidean_dist: 3.598642958509009, len occurrence: 14
# Seed: 60, Video: 34, Frame start: 8758, euclidean_dist: 3.789425406010649, len occurrence: 14
# Seed: 60, Video: 34, Frame start: 353, euclidean_dist: 3.64636581423747, len occurrence: 14
# Seed: 60, Video: 34, Frame start: 1125, euclidean_dist: 3.6376758744591635, len occurrence: 14
# Seed: 60, Video: 34, Frame start: 8514, euclidean_dist: 4.198713193358332, len occurrence: 14
# Seed: 60, Video: 34, Frame start: 2954, euclidean_dist: 3.831098335623748, len occurrence: 14
# Seed: 60, Video: 34, Frame start: 2829, euclidean_dist: 4.062290772379005, len occurrence: 14
# Seed: 60, Video: 34, Frame start: 5688, euclidean_dist: 4.422156190399511, len occurrence: 14
# Seed: 60, Video: 34, Frame start: 8013, euclidean_dist: 3.322880838064673, len occurrence: 14
# Seed: 60, Video: 34, Frame start: 3091, euclidean_dist: 4.008065885119156, len occurrence: 14
# Seed: 60, Video: 35, Frame start: 7011, euclidean_dist: 3.7416573867739413, len occurrence: 14
# Seed: 60, Video: 35, Frame start: 3704, euclidean_dist: 3.2677078188723097, len occurrence: 14
# Seed: 60, Video: 35, Frame start: 3299, euclidean_dist: 3.7953671360179886, len occurrence: 14
# Seed: 60, Video: 35, Frame start: 7016, euclidean_dist: 3.7416573867739413, len occurrence: 14
# Seed: 60, Video: 35, Frame start: 7021, euclidean_dist: 3.7416573867739413, len occurrence: 14
# Seed: 60, Video: 35, Frame start: 7026, euclidean_dist: 3.7416573867739413, len occurrence: 14
# Seed: 60, Video: 35, Frame start: 7031, euclidean_dist: 3.7416573867739413, len occurrence: 14
# Seed: 60, Video: 35, Frame start: 2904, euclidean_dist: 3.4905811953129176, len occurrence: 14
# Seed: 60, Video: 35, Frame start: 3993, euclidean_dist: 3.2131249747196424, len occurrence: 14
# Seed: 60, Video: 35, Frame start: 7036, euclidean_dist: 3.7416573867739413, len occurrence: 14
# Seed: 60, Video: 35, Frame start: 7006, euclidean_dist: 3.7416573867739413, len occurrence: 14
# Seed: 60, Video: 36, Frame start: 2531, euclidean_dist: 3.0504783836356877, len occurrence: 14
# Seed: 60, Video: 36, Frame start: 8364, euclidean_dist: 4.177927708113304, len occurrence: 14
# Seed: 60, Video: 36, Frame start: 10066, euclidean_dist: 3.3996788987122284, len occurrence: 14
# Seed: 60, Video: 36, Frame start: 3266, euclidean_dist: 3.280116229539166, len occurrence: 4
# Seed: 60, Video: 36, Frame start: 12464, euclidean_dist: 3.7416573867739413, len occurrence: 14
# Seed: 60, Video: 36, Frame start: 10113, euclidean_dist: 3.8963099111164143, len occurrence: 14
# Seed: 60, Video: 36, Frame start: 12065, euclidean_dist: 4.085016790380134, len occurrence: 14
# Seed: 60, Video: 36, Frame start: 1751, euclidean_dist: 4.057521237969927, len occurrence: 14
# Seed: 60, Video: 36, Frame start: 2425, euclidean_dist: 3.361405571390177, len occurrence: 14
# Seed: 60, Video: 36, Frame start: 6364, euclidean_dist: 3.4315064411674108, len occurrence: 14
# Seed: 60, Video: 36, Frame start: 12424, euclidean_dist: 3.7416573867739413, len occurrence: 14
# Seed: 60, Video: 36, Frame start: 4500, euclidean_dist: 3.0277773599200875, len occurrence: 14
# Seed: 60, Video: 36, Frame start: 1312, euclidean_dist: 4.280488715930653, len occurrence: 14
# Seed: 60, Video: 36, Frame start: 5464, euclidean_dist: 2.8020498616719096, len occurrence: 14
# Seed: 60, Video: 38, Frame start: 520, euclidean_dist: 4.300091892816285, len occurrence: 14
# Seed: 60, Video: 38, Frame start: 75, euclidean_dist: 3.156818637128625, len occurrence: 14
# Seed: 60, Video: 39, Frame start: 3805, euclidean_dist: 3.100641718637204, len occurrence: 14
# Seed: 60, Video: 39, Frame start: 3516, euclidean_dist: 3.1027726815027297, len occurrence: 14
# Seed: 60, Video: 39, Frame start: 3912, euclidean_dist: 4.25418790124143, len occurrence: 14
# Seed: 60, Video: 39, Frame start: 4074, euclidean_dist: 3.7786877946288606, len occurrence: 14
# Seed: 60, Video: 39, Frame start: 2923, euclidean_dist: 2.1864120407694365, len occurrence: 14
# Seed: 60, Video: 39, Frame start: 1531, euclidean_dist: 3.356634268852687, len occurrence: 14
# Seed: 60, Video: 39, Frame start: 2780, euclidean_dist: 3.9833864337253346, len occurrence: 14
# Seed: 60, Video: 40, Frame start: 694, euclidean_dist: 3.879072259315372, len occurrence: 14
# Seed: 60, Video: 40, Frame start: 407, euclidean_dist: 4.150080708633433, len occurrence: 14
# Seed: 60, Video: 41, Frame start: 10, euclidean_dist: 3.990814195982957, len occurrence: 14
# Seed: 60, Video: 41, Frame start: 1067, euclidean_dist: 3.8626426460820906, len occurrence: 14
# Seed: 60, Video: 42, Frame start: 1280, euclidean_dist: 3.967308661282926, len occurrence: 14
# Seed: 60, Video: 42, Frame start: 533, euclidean_dist: 3.8052460038592026, len occurrence: 14
# Seed: 60, Video: 42, Frame start: 1350, euclidean_dist: 3.922513189469584, len occurrence: 14
# Seed: 60, Video: 43, Frame start: 2471, euclidean_dist: 3.9154085387813735, len occurrence: 14
# Seed: 60, Video: 43, Frame start: 331, euclidean_dist: 4.239026274431898, len occurrence: 14
# Seed: 60, Video: 43, Frame start: 619, euclidean_dist: 3.880858677825864, len occurrence: 14
# Seed: 60, Video: 43, Frame start: 2745, euclidean_dist: 4.076141923760787, len occurrence: 14
# Seed: 60, Video: 43, Frame start: 1526, euclidean_dist: 3.139740668091382, len occurrence: 14
# Seed: 60, Video: 43, Frame start: 2231, euclidean_dist: 4.381381901069831, len occurrence: 14
# Seed: 60, Video: 43, Frame start: 2392, euclidean_dist: 4.3075871802272205, len occurrence: 14
# Seed: 60, Video: 43, Frame start: 1402, euclidean_dist: 3.249302157079484, len occurrence: 14
# Seed: 60, Video: 44, Frame start: 2187, euclidean_dist: 4.066733641872254, len occurrence: 14
# Seed: 60, Video: 46, Frame start: 454, euclidean_dist: 4.2515022006558, len occurrence: 14
# Seed: 60, Video: 46, Frame start: 167, euclidean_dist: 3.619172333447011, len occurrence: 14
# Seed: 60, Video: 46, Frame start: 139, euclidean_dist: 4.171119689264806, len occurrence: 14
# Seed: 60, Video: 46, Frame start: 1868, euclidean_dist: 2.2952434179134587, len occurrence: 14
# Seed: 60, Video: 46, Frame start: 720, euclidean_dist: 3.2375675232968946, len occurrence: 14
# Seed: 60, Video: 46, Frame start: 1311, euclidean_dist: 3.3818963293346687, len occurrence: 14
# Seed: 60, Video: 47, Frame start: 951, euclidean_dist: 3.886688630405035, len occurrence: 14
# Seed: 60, Video: 47, Frame start: 342, euclidean_dist: 4.0826906333553055, len occurrence: 14
# Seed: 60, Video: 47, Frame start: 2326, euclidean_dist: 3.8166102919705, len occurrence: 14
# Seed: 60, Video: 47, Frame start: 479, euclidean_dist: 4.16663413234711, len occurrence: 14
# Seed: 60, Video: 48, Frame start: 0, euclidean_dist: 3.9576520058365663, len occurrence: 14
# Seed: 60, Video: 48, Frame start: 954, euclidean_dist: 3.4337848900668733, len occurrence: 14
# Seed: 60, Video: 48, Frame start: 1352, euclidean_dist: 4.085986144234298, len occurrence: 14
# Seed: 60, Video: 48, Frame start: 3500, euclidean_dist: 4.355196834069119, len occurrence: 14
# Seed: 60, Video: 48, Frame start: 4465, euclidean_dist: 3.5755155099394744, len occurrence: 14
# Seed: 60, Video: 48, Frame start: 1970, euclidean_dist: 4.290665362531363, len occurrence: 14
# Seed: 60, Video: 48, Frame start: 693, euclidean_dist: 3.9869427114124583, len occurrence: 14
# Seed: 60, Video: 48, Frame start: 1749, euclidean_dist: 3.2662807371157787, len occurrence: 14
# Seed: 60, Video: 48, Frame start: 2550, euclidean_dist: 4.254008612997327, len occurrence: 14
# Seed: 60, Video: 48, Frame start: 3514, euclidean_dist: 4.110874645950267, len occurrence: 14
# Seed: 60, Video: 48, Frame start: 2364, euclidean_dist: 3.6435864264283464, len occurrence: 14
# Seed: 60, Video: 48, Frame start: 5053, euclidean_dist: 3.3180544253914794, len occurrence: 14
# Seed: 60, Video: 49, Frame start: 2856, euclidean_dist: 4.304645842007395, len occurrence: 14
# Seed: 60, Video: 49, Frame start: 3123, euclidean_dist: 4.245830301184258, len occurrence: 14
# Seed: 60, Video: 49, Frame start: 1688, euclidean_dist: 3.904983448914523, len occurrence: 14
# Seed: 60, Video: 49, Frame start: 287, euclidean_dist: 4.234616640343849, len occurrence: 14
# Seed: 60, Video: 50, Frame start: 344, euclidean_dist: 4.055882822365771, len occurrence: 14
# Seed: 60, Video: 50, Frame start: 2, euclidean_dist: 3.6504767421352553, len occurrence: 14
# Seed: 60, Video: 53, Frame start: 228, euclidean_dist: 4.23151581254325, len occurrence: 14
# Seed: 60, Video: 53, Frame start: 2409, euclidean_dist: 4.294443769659751, len occurrence: 14
# Seed: 60, Video: 53, Frame start: 749, euclidean_dist: 4.264700289903035, len occurrence: 14
# Seed: 60, Video: 53, Frame start: 1811, euclidean_dist: 4.133147219198834, len occurrence: 14
# Seed: 60, Video: 53, Frame start: 493, euclidean_dist: 3.5623869820133898, len occurrence: 14
# Seed: 60, Video: 53, Frame start: 1781, euclidean_dist: 3.446923129993055, len occurrence: 14
# Seed: 60, Video: 53, Frame start: 2184, euclidean_dist: 3.8004718596335287, len occurrence: 14
# Seed: 60, Video: 53, Frame start: 1059, euclidean_dist: 4.452583158905854, len occurrence: 14
# Seed: 60, Video: 55, Frame start: 465, euclidean_dist: 3.7328772133006853, len occurrence: 14
# Seed: 60, Video: 55, Frame start: 669, euclidean_dist: 4.239415048370898, len occurrence: 14
# Seed: 60, Video: 55, Frame start: 806, euclidean_dist: 4.111987245587132, len occurrence: 14
# Seed: 60, Video: 56, Frame start: 152, euclidean_dist: 4.169256357780196, len occurrence: 14
# Seed: 60, Video: 56, Frame start: 265, euclidean_dist: 4.0407210603273755, len occurrence: 14
# Seed: 60, Video: 56, Frame start: 684, euclidean_dist: 3.4774665778465, len occurrence: 14
# Seed: 60, Video: 57, Frame start: 2783, euclidean_dist: 3.80644871268648, len occurrence: 14
# Seed: 60, Video: 57, Frame start: 2982, euclidean_dist: 4.206396607404059, len occurrence: 14
# Seed: 60, Video: 58, Frame start: 2329, euclidean_dist: 3.9775539662843493, len occurrence: 14
# Seed: 60, Video: 58, Frame start: 2, euclidean_dist: 3.4107832331759735, len occurrence: 14
# Seed: 60, Video: 58, Frame start: 29, euclidean_dist: 4.314186796100228, len occurrence: 14
# Seed: 60, Video: 58, Frame start: 1567, euclidean_dist: 4.106758636936035, len occurrence: 14
# Seed: 60, Video: 59, Frame start: 4638, euclidean_dist: 4.0413662349508455, len occurrence: 14
# Seed: 60, Video: 59, Frame start: 3586, euclidean_dist: 4.104821300521197, len occurrence: 14
# Seed: 60, Video: 59, Frame start: 544, euclidean_dist: 3.5987039820445608, len occurrence: 14
# Seed: 60, Video: 59, Frame start: 3113, euclidean_dist: 3.481941174498342, len occurrence: 14
# Seed: 60, Video: 59, Frame start: 5770, euclidean_dist: 3.0940712799864305, len occurrence: 14
# Seed: 60, Video: 59, Frame start: 3986, euclidean_dist: 3.528561120523648, len occurrence: 14
# Seed: 60, Video: 59, Frame start: 529, euclidean_dist: 3.9996059748035453, len occurrence: 14
# Seed: 60, Video: 59, Frame start: 5083, euclidean_dist: 4.069069186128401, len occurrence: 14
# Seed: 60, Video: 60, Frame start: 647, euclidean_dist: 3.404366573775118, len occurrence: 14
# Seed: 60, Video: 61, Frame start: 707, euclidean_dist: 3.914878021861632, len occurrence: 14
# Seed: 60, Video: 61, Frame start: 1077, euclidean_dist: 3.6051839331746676, len occurrence: 14
# Seed: 60, Video: 62, Frame start: 519, euclidean_dist: 3.914332706750178, len occurrence: 14
# Seed: 60, Video: 64, Frame start: 281, euclidean_dist: 3.7020192373391256, len occurrence: 14
# Seed: 60, Video: 64, Frame start: 1003, euclidean_dist: 3.56895288688187, len occurrence: 14
# Seed: 60, Video: 64, Frame start: 518, euclidean_dist: 2.9105256818193808, len occurrence: 14
# Seed: 60, Video: 64, Frame start: 2811, euclidean_dist: 3.7089046493081685, len occurrence: 14
# Seed: 60, Video: 65, Frame start: 3437, euclidean_dist: 4.293934856097248, len occurrence: 14
# Seed: 60, Video: 65, Frame start: 1173, euclidean_dist: 3.8838203157292144, len occurrence: 14
# Seed: 60, Video: 65, Frame start: 2689, euclidean_dist: 3.9321937063882317, len occurrence: 14
# Seed: 60, Video: 65, Frame start: 1917, euclidean_dist: 4.216935975052219, len occurrence: 14
# Seed: 60, Video: 66, Frame start: 5504, euclidean_dist: 4.384020641687245, len occurrence: 14
# Seed: 60, Video: 66, Frame start: 5088, euclidean_dist: 3.7217170555476558, len occurrence: 14
# Seed: 60, Video: 66, Frame start: 5991, euclidean_dist: 3.6279486418076834, len occurrence: 14
# Seed: 60, Video: 66, Frame start: 5288, euclidean_dist: 4.126425127145061, len occurrence: 14
# Seed: 60, Video: 66, Frame start: 1385, euclidean_dist: 3.8185494308314625, len occurrence: 14
# Seed: 60, Video: 66, Frame start: 2122, euclidean_dist: 3.195327974865096, len occurrence: 14
# Seed: 60, Video: 66, Frame start: 1484, euclidean_dist: 4.027757549456619, len occurrence: 14
# Seed: 60, Video: 66, Frame start: 5677, euclidean_dist: 4.355792706847254, len occurrence: 14
# Seed: 60, Video: 66, Frame start: 911, euclidean_dist: 3.3904194037649504, len occurrence: 14
# Seed: 60, Video: 66, Frame start: 3637, euclidean_dist: 4.058128929943504, len occurrence: 14
# Seed: 60, Video: 66, Frame start: 2359, euclidean_dist: 3.64580078566925, len occurrence: 14
# Seed: 60, Video: 66, Frame start: 4024, euclidean_dist: 3.9009397743090894, len occurrence: 14
# Seed: 60, Video: 66, Frame start: 2394, euclidean_dist: 4.370488691450988, len occurrence: 14
# Seed: 60, Video: 66, Frame start: 1883, euclidean_dist: 3.8158756632346984, len occurrence: 14
# Seed: 60, Video: 67, Frame start: 724, euclidean_dist: 3.7258975354491657, len occurrence: 14
# Seed: 60, Video: 67, Frame start: 1108, euclidean_dist: 4.297365073913804, len occurrence: 14
# Seed: 60, Video: 68, Frame start: 1309, euclidean_dist: 3.7769115615601465, len occurrence: 14
# Seed: 60, Video: 70, Frame start: 1374, euclidean_dist: 3.9061868265322386, len occurrence: 14
# Seed: 64, Video: 16, Frame start: 5034, euclidean_dist: 3.9682109935216223, len occurrence: 14
# Seed: 64, Video: 16, Frame start: 4824, euclidean_dist: 5.759081396444503, len occurrence: 18
# Seed: 65, Video: 14, Frame start: 8315, euclidean_dist: 5.739819359883067, len occurrence: 20
# Seed: 66, Video: 13, Frame start: 362, euclidean_dist: 6.618678095636983, len occurrence: 5
# Seed: 66, Video: 16, Frame start: 3633, euclidean_dist: 4.590815700791068, len occurrence: 10
# Seed: 71, Video: 12, Frame start: 1261, euclidean_dist: 5.42077927090179, len occurrence: 9
# Seed: 76, Video: 16, Frame start: 1069, euclidean_dist: 5.3443474721941975, len occurrence: 27
# Seed: 76, Video: 23, Frame start: 1372, euclidean_dist: 6.077352570321461, len occurrence: 29
# Seed: 80, Video: 1, Frame start: 1716, euclidean_dist: 2.4728667186862694, len occurrence: 9
# Seed: 80, Video: 1, Frame start: 2141, euclidean_dist: 2.16863552562687, len occurrence: 9
# Seed: 80, Video: 1, Frame start: 1845, euclidean_dist: 2.992217569024712, len occurrence: 9
# Seed: 80, Video: 1, Frame start: 2013, euclidean_dist: 3.0967974576692328, len occurrence: 9
# Seed: 80, Video: 2, Frame start: 808, euclidean_dist: 2.76414522689065, len occurrence: 9
# Seed: 80, Video: 2, Frame start: 641, euclidean_dist: 2.1747684890334247, len occurrence: 9
# Seed: 80, Video: 2, Frame start: 1771, euclidean_dist: 2.0001058552325603, len occurrence: 9
# Seed: 80, Video: 2, Frame start: 1469, euclidean_dist: 2.8479588348118043, len occurrence: 9
# Seed: 80, Video: 3, Frame start: 1994, euclidean_dist: 2.0188718183362306, len occurrence: 9
# Seed: 80, Video: 3, Frame start: 1110, euclidean_dist: 2.706467225890344, len occurrence: 9
# Seed: 80, Video: 3, Frame start: 1912, euclidean_dist: 2.9927971483307334, len occurrence: 9
# Seed: 80, Video: 3, Frame start: 1534, euclidean_dist: 3.0419426703650307, len occurrence: 9
# Seed: 80, Video: 3, Frame start: 1634, euclidean_dist: 2.791555121168314, len occurrence: 9
# Seed: 80, Video: 4, Frame start: 4425, euclidean_dist: 2.5555505712463207, len occurrence: 9
# Seed: 80, Video: 4, Frame start: 236, euclidean_dist: 2.2209034885580134, len occurrence: 9
# Seed: 80, Video: 4, Frame start: 844, euclidean_dist: 2.6702636037664225, len occurrence: 9
# Seed: 80, Video: 4, Frame start: 4848, euclidean_dist: 2.699582361504011, len occurrence: 9
# Seed: 80, Video: 4, Frame start: 1840, euclidean_dist: 2.9240557147217636, len occurrence: 9
# Seed: 80, Video: 4, Frame start: 2578, euclidean_dist: 3.237131853381935, len occurrence: 9
# Seed: 80, Video: 4, Frame start: 4692, euclidean_dist: 2.2918872383066526, len occurrence: 9
# Seed: 80, Video: 4, Frame start: 4213, euclidean_dist: 2.794184014881629, len occurrence: 9
# Seed: 80, Video: 4, Frame start: 2936, euclidean_dist: 2.5341006291618586, len occurrence: 9
# Seed: 80, Video: 4, Frame start: 5455, euclidean_dist: 2.6639018838878497, len occurrence: 9
# Seed: 80, Video: 5, Frame start: 823, euclidean_dist: 2.5831902205140844, len occurrence: 9
# Seed: 80, Video: 5, Frame start: 825, euclidean_dist: 2.2883517356060397, len occurrence: 9
# Seed: 80, Video: 5, Frame start: 3304, euclidean_dist: 2.5694609954028356, len occurrence: 9
# Seed: 80, Video: 5, Frame start: 3399, euclidean_dist: 2.7274423809336867, len occurrence: 9
# Seed: 80, Video: 5, Frame start: 2566, euclidean_dist: 2.160111296058935, len occurrence: 9
# Seed: 80, Video: 5, Frame start: 1960, euclidean_dist: 2.8340614708917187, len occurrence: 9
# Seed: 80, Video: 5, Frame start: 2963, euclidean_dist: 2.2675095302297117, len occurrence: 9
# ...
# Seed: 203, Video: 36, Frame start: 10141, euclidean_dist: 7.2301511586650635, len occurrence: 38
# Seed: 203, Video: 39, Frame start: 39, euclidean_dist: 7.200435976284855, len occurrence: 38
# Seed: 203, Video: 47, Frame start: 382, euclidean_dist: 4.106537326632832, len occurrence: 38
# Seed: 203, Video: 48, Frame start: 3913, euclidean_dist: 5.617078346107211, len occurrence: 38
# Seed: 203, Video: 58, Frame start: 1210, euclidean_dist: 4.281115550577709, len occurrence: 38
# Seed: 203, Video: 59, Frame start: 2931, euclidean_dist: 6.967163836766944, len occurrence: 38
# Seed: 203, Video: 61, Frame start: 689, euclidean_dist: 6.298667561698762, len occurrence: 38
# Seed: 203, Video: 64, Frame start: 2295, euclidean_dist: 6.233434425294608, len occurrence: 38
# Seed: 204, Video: 4, Frame start: 3804, euclidean_dist: 6.483823035426521, len occurrence: 38
# Seed: 204, Video: 10, Frame start: 7309, euclidean_dist: 5.59075243106436, len occurrence: 38
# Seed: 204, Video: 17, Frame start: 2114, euclidean_dist: 5.5914017532577605, len occurrence: 38
# Seed: 204, Video: 20, Frame start: 802, euclidean_dist: 7.44720288835893, len occurrence: 38
# Seed: 204, Video: 25, Frame start: 1174, euclidean_dist: 4.563474075434745, len occurrence: 38
# Seed: 204, Video: 27, Frame start: 2469, euclidean_dist: 7.316843961297407, len occurrence: 38
# Seed: 204, Video: 28, Frame start: 1470, euclidean_dist: 4.4369482808035965, len occurrence: 38
# Seed: 204, Video: 35, Frame start: 7004, euclidean_dist: 0.0, len occurrence: 38
# Seed: 204, Video: 35, Frame start: 7015, euclidean_dist: 6.164414002968976, len occurrence: 38
# Seed: 204, Video: 43, Frame start: 160, euclidean_dist: 5.765046475860935, len occurrence: 38
# Seed: 204, Video: 44, Frame start: 2065, euclidean_dist: 5.782097076297358, len occurrence: 38
# Seed: 204, Video: 45, Frame start: 2560, euclidean_dist: 6.091540771643066, len occurrence: 38
# Seed: 204, Video: 48, Frame start: 5307, euclidean_dist: 6.01772432958133, len occurrence: 38
# Seed: 204, Video: 59, Frame start: 192, euclidean_dist: 7.150539874147012, len occurrence: 38
# Seed: 204, Video: 61, Frame start: 41, euclidean_dist: 6.326688742987881, len occurrence: 38
# Seed: 204, Video: 63, Frame start: 1440, euclidean_dist: 4.670951508815235, len occurrence: 38
# Seed: 205, Video: 2, Frame start: 1212, euclidean_dist: 6.781788939323788, len occurrence: 37
# Seed: 205, Video: 4, Frame start: 2754, euclidean_dist: 5.499778904254449, len occurrence: 37
# Seed: 205, Video: 14, Frame start: 5959, euclidean_dist: 5.791239460609302, len occurrence: 37
# Seed: 205, Video: 22, Frame start: 1428, euclidean_dist: 6.214097306164754, len occurrence: 37
# Seed: 205, Video: 23, Frame start: 488, euclidean_dist: 6.587553890025585, len occurrence: 37
# Seed: 205, Video: 25, Frame start: 2338, euclidean_dist: 5.549974585180253, len occurrence: 37
# Seed: 206, Video: 2, Frame start: 1641, euclidean_dist: 4.6595126125191015, len occurrence: 36
# Seed: 206, Video: 6, Frame start: 3411, euclidean_dist: 4.594204940777041, len occurrence: 36
# Seed: 206, Video: 7, Frame start: 2738, euclidean_dist: 4.106934595703055, len occurrence: 36
# Seed: 206, Video: 8, Frame start: 3230, euclidean_dist: 6.091140917826496, len occurrence: 36
# Seed: 206, Video: 9, Frame start: 10577, euclidean_dist: 5.692477796492799, len occurrence: 36
# Seed: 206, Video: 10, Frame start: 2046, euclidean_dist: 4.30536918734523, len occurrence: 36
# Seed: 206, Video: 11, Frame start: 2094, euclidean_dist: 5.777181234892631, len occurrence: 36
# Seed: 206, Video: 15, Frame start: 704, euclidean_dist: 4.716494929711407, len occurrence: 36
# Seed: 206, Video: 17, Frame start: 1730, euclidean_dist: 3.3241055816935123, len occurrence: 36
# Seed: 206, Video: 22, Frame start: 8747, euclidean_dist: 6.391295242139357, len occurrence: 36
# Seed: 206, Video: 24, Frame start: 5196, euclidean_dist: 4.43188291204156, len occurrence: 36
# Seed: 206, Video: 24, Frame start: 3543, euclidean_dist: 5.645676206984492, len occurrence: 36
# Seed: 206, Video: 25, Frame start: 5275, euclidean_dist: 6.035780078896967, len occurrence: 36
# Seed: 206, Video: 27, Frame start: 4417, euclidean_dist: 5.869102339861142, len occurrence: 36
# Seed: 206, Video: 30, Frame start: 3328, euclidean_dist: 6.898097828475497, len occurrence: 36
# Seed: 206, Video: 30, Frame start: 3905, euclidean_dist: 3.8117158680013103, len occurrence: 36
# Seed: 206, Video: 30, Frame start: 3869, euclidean_dist: 6.700729924101074, len occurrence: 36
# Seed: 206, Video: 30, Frame start: 751, euclidean_dist: 3.438900412044498, len occurrence: 36
# Seed: 206, Video: 35, Frame start: 6266, euclidean_dist: 5.652261631097821, len occurrence: 36
# Seed: 206, Video: 35, Frame start: 3368, euclidean_dist: 4.5833343339541734, len occurrence: 36
# Seed: 206, Video: 35, Frame start: 5960, euclidean_dist: 4.997521437092896, len occurrence: 36
# Seed: 206, Video: 35, Frame start: 7005, euclidean_dist: 0.0, len occurrence: 36
# Seed: 206, Video: 35, Frame start: 5816, euclidean_dist: 3.771350677147435, len occurrence: 36
# Seed: 206, Video: 35, Frame start: 2496, euclidean_dist: 4.1088130683992246, len occurrence: 36
# Seed: 206, Video: 36, Frame start: 8132, euclidean_dist: 3.3692618909753413, len occurrence: 36
# Seed: 206, Video: 36, Frame start: 12369, euclidean_dist: 3.7618960835278776, len occurrence: 36
# Seed: 206, Video: 36, Frame start: 1320, euclidean_dist: 3.2182178956276664, len occurrence: 36
# Seed: 206, Video: 36, Frame start: 6374, euclidean_dist: 1.753271995656892, len occurrence: 36
# Seed: 206, Video: 40, Frame start: 135, euclidean_dist: 2.996105595660909, len occurrence: 36
# Seed: 206, Video: 52, Frame start: 114, euclidean_dist: 5.270414890062285, len occurrence: 36
# Seed: 206, Video: 57, Frame start: 2412, euclidean_dist: 1.9901549283788258, len occurrence: 36
# Seed: 206, Video: 58, Frame start: 79, euclidean_dist: 4.516280688682948, len occurrence: 36
# Seed: 206, Video: 59, Frame start: 5718, euclidean_dist: 5.664604699607293, len occurrence: 36
# Seed: 206, Video: 59, Frame start: 1345, euclidean_dist: 5.004553490408173, len occurrence: 36
# Seed: 206, Video: 63, Frame start: 1349, euclidean_dist: 3.0528429497334013, len occurrence: 36
# Seed: 206, Video: 65, Frame start: 3732, euclidean_dist: 4.866591536329969, len occurrence: 36
# Seed: 206, Video: 66, Frame start: 117, euclidean_dist: 4.147448838279923, len occurrence: 36
# Seed: 206, Video: 69, Frame start: 1086, euclidean_dist: 5.254061649180698, len occurrence: 36
# Seed: 206, Video: 70, Frame start: 565, euclidean_dist: 3.5989481286688614, len occurrence: 36
# Seed: 206, Video: 70, Frame start: 143, euclidean_dist: 4.9876664501784695, len occurrence: 36
# Seed: 207, Video: 6, Frame start: 3192, euclidean_dist: 5.785118624408199, len occurrence: 37
# Seed: 207, Video: 14, Frame start: 4494, euclidean_dist: 6.9416871938268345, len occurrence: 37
# Seed: 207, Video: 20, Frame start: 758, euclidean_dist: 6.624446647553617, len occurrence: 37
# Seed: 207, Video: 59, Frame start: 599, euclidean_dist: 5.248354291444986, len occurrence: 37
# Seed: 207, Video: 62, Frame start: 612, euclidean_dist: 6.429412260667437, len occurrence: 37
# Seed: 208, Video: 18, Frame start: 315, euclidean_dist: 3.9209412922530724, len occurrence: 38
# Seed: 208, Video: 25, Frame start: 3829, euclidean_dist: 3.9775487577347253, len occurrence: 38
# Seed: 209, Video: 7, Frame start: 753, euclidean_dist: 4.124132440894688, len occurrence: 31
# Seed: 209, Video: 7, Frame start: 1963, euclidean_dist: 6.577270062252892, len occurrence: 31
# Seed: 209, Video: 9, Frame start: 2809, euclidean_dist: 4.372138859910521, len occurrence: 31
# Seed: 209, Video: 10, Frame start: 2210, euclidean_dist: 5.976030332897266, len occurrence: 31
# Seed: 209, Video: 17, Frame start: 5187, euclidean_dist: 5.583815944474125, len occurrence: 31
# Seed: 209, Video: 21, Frame start: 723, euclidean_dist: 6.146239514237834, len occurrence: 31
# Seed: 209, Video: 21, Frame start: 3880, euclidean_dist: 5.0918267033638775, len occurrence: 31
# Seed: 209, Video: 21, Frame start: 3266, euclidean_dist: 5.4262436352957195, len occurrence: 31
# Seed: 209, Video: 26, Frame start: 654, euclidean_dist: 4.272082970450088, len occurrence: 31
# Seed: 209, Video: 27, Frame start: 565, euclidean_dist: 4.964521792740512, len occurrence: 31
# Seed: 209, Video: 29, Frame start: 77, euclidean_dist: 5.076859293502999, len occurrence: 31
# Seed: 209, Video: 29, Frame start: 359, euclidean_dist: 3.335029352374836, len occurrence: 31
# Seed: 209, Video: 30, Frame start: 4051, euclidean_dist: 4.398003168197311, len occurrence: 31
# Seed: 209, Video: 33, Frame start: 339, euclidean_dist: 5.41792825638036, len occurrence: 31
# Seed: 209, Video: 33, Frame start: 980, euclidean_dist: 5.0774904109787675, len occurrence: 31
# Seed: 209, Video: 35, Frame start: 7140, euclidean_dist: 4.79591706786497, len occurrence: 31
# Seed: 209, Video: 36, Frame start: 10452, euclidean_dist: 4.756217591925639, len occurrence: 31
# Seed: 209, Video: 36, Frame start: 4981, euclidean_dist: 4.486035461978683, len occurrence: 31
# Seed: 209, Video: 38, Frame start: 951, euclidean_dist: 5.753107292835775, len occurrence: 31
# Seed: 209, Video: 53, Frame start: 2049, euclidean_dist: 4.967287389084565, len occurrence: 31
# Seed: 209, Video: 57, Frame start: 2933, euclidean_dist: 5.973590114115565, len occurrence: 31
# Seed: 209, Video: 59, Frame start: 1399, euclidean_dist: 5.632641018076436, len occurrence: 31
# Seed: 209, Video: 59, Frame start: 1739, euclidean_dist: 3.136790682972763, len occurrence: 31
# Seed: 210, Video: 4, Frame start: 4462, euclidean_dist: 5.026339107013554, len occurrence: 31
# Seed: 210, Video: 9, Frame start: 450, euclidean_dist: 4.112169645930101, len occurrence: 31
# Seed: 210, Video: 10, Frame start: 5217, euclidean_dist: 3.7947294451842852, len occurrence: 31
# Seed: 210, Video: 15, Frame start: 940, euclidean_dist: 2.662265975486251, len occurrence: 31
# Seed: 210, Video: 16, Frame start: 3446, euclidean_dist: 4.89916590068769, len occurrence: 31
# Seed: 210, Video: 22, Frame start: 7676, euclidean_dist: 5.598567535289403, len occurrence: 31
# Seed: 210, Video: 24, Frame start: 4368, euclidean_dist: 4.689435123506488, len occurrence: 31
# Seed: 210, Video: 24, Frame start: 4097, euclidean_dist: 5.24512154839049, len occurrence: 31
# Seed: 210, Video: 24, Frame start: 430, euclidean_dist: 4.917820408946378, len occurrence: 31
# Seed: 210, Video: 26, Frame start: 1560, euclidean_dist: 2.5698398789275654, len occurrence: 31
# Seed: 210, Video: 27, Frame start: 4594, euclidean_dist: 4.483640319085747, len occurrence: 31
# Seed: 210, Video: 27, Frame start: 1462, euclidean_dist: 5.826320050069582, len occurrence: 31
# Seed: 210, Video: 27, Frame start: 777, euclidean_dist: 4.429003437993941, len occurrence: 31
# Seed: 210, Video: 30, Frame start: 3920, euclidean_dist: 4.990208644337493, len occurrence: 31
# Seed: 210, Video: 36, Frame start: 378, euclidean_dist: 3.5225590928170365, len occurrence: 31
# Seed: 210, Video: 36, Frame start: 9031, euclidean_dist: 4.040814198010761, len occurrence: 31
# Seed: 210, Video: 36, Frame start: 8838, euclidean_dist: 3.40270534450537, len occurrence: 31
# Seed: 210, Video: 36, Frame start: 10731, euclidean_dist: 3.521685516842927, len occurrence: 31
# Seed: 210, Video: 36, Frame start: 5591, euclidean_dist: 3.9844933580773585, len occurrence: 31
# Seed: 210, Video: 37, Frame start: 641, euclidean_dist: 3.4740346444688703, len occurrence: 31
# Seed: 210, Video: 37, Frame start: 357, euclidean_dist: 3.3974136291127013, len occurrence: 31
# Seed: 210, Video: 41, Frame start: 2155, euclidean_dist: 4.806500057458478, len occurrence: 31
# Seed: 210, Video: 41, Frame start: 574, euclidean_dist: 4.010179132946318, len occurrence: 31
# Seed: 210, Video: 42, Frame start: 613, euclidean_dist: 2.8849969321306554, len occurrence: 31
# Seed: 210, Video: 42, Frame start: 895, euclidean_dist: 4.740647689684006, len occurrence: 31
# Seed: 210, Video: 51, Frame start: 1145, euclidean_dist: 4.271835583615066, len occurrence: 31
# Seed: 210, Video: 54, Frame start: 1369, euclidean_dist: 3.8732542631879547, len occurrence: 31
# Seed: 210, Video: 57, Frame start: 312, euclidean_dist: 3.290333552071729, len occurrence: 31
# Seed: 210, Video: 58, Frame start: 2168, euclidean_dist: 3.908430871998242, len occurrence: 31
# Seed: 210, Video: 58, Frame start: 764, euclidean_dist: 4.338498230370008, len occurrence: 31
# Seed: 210, Video: 58, Frame start: 1092, euclidean_dist: 3.5701502980688633, len occurrence: 31
# Seed: 210, Video: 59, Frame start: 486, euclidean_dist: 2.8443153563636407, len occurrence: 31
# Seed: 210, Video: 59, Frame start: 2720, euclidean_dist: 4.103978877710919, len occurrence: 31
# Seed: 210, Video: 59, Frame start: 4321, euclidean_dist: 2.8233249858417118, len occurrence: 31
# Seed: 210, Video: 61, Frame start: 820, euclidean_dist: 5.192948453100325, len occurrence: 31
# Seed: 210, Video: 63, Frame start: 108, euclidean_dist: 4.075743837255169, len occurrence: 31
# Seed: 210, Video: 63, Frame start: 621, euclidean_dist: 5.070993333612638, len occurrence: 31
# Seed: 210, Video: 65, Frame start: 179, euclidean_dist: 4.050107925717611, len occurrence: 31
# Seed: 210, Video: 65, Frame start: 3964, euclidean_dist: 4.525651869650929, len occurrence: 31
# Seed: 210, Video: 69, Frame start: 1121, euclidean_dist: 3.2692193456556553, len occurrence: 31
# Seed: 211, Video: 1, Frame start: 1521, euclidean_dist: 5.734485121503413, len occurrence: 31
# Seed: 211, Video: 9, Frame start: 8701, euclidean_dist: 4.56769734496817, len occurrence: 31
# Seed: 211, Video: 9, Frame start: 9523, euclidean_dist: 3.242800280692102, len occurrence: 31
# Seed: 211, Video: 16, Frame start: 1891, euclidean_dist: 4.791585060530573, len occurrence: 31
# Seed: 211, Video: 16, Frame start: 6132, euclidean_dist: 5.892011835225672, len occurrence: 31
# Seed: 211, Video: 16, Frame start: 2736, euclidean_dist: 5.846730439592924, len occurrence: 31
# Seed: 211, Video: 27, Frame start: 474, euclidean_dist: 1.9448938563560998, len occurrence: 31
# Seed: 211, Video: 28, Frame start: 4328, euclidean_dist: 5.486900539152781, len occurrence: 31
# Seed: 211, Video: 28, Frame start: 1561, euclidean_dist: 3.8710166815845573, len occurrence: 31
# Seed: 211, Video: 29, Frame start: 227, euclidean_dist: 4.957106231319855, len occurrence: 31
# Seed: 211, Video: 31, Frame start: 514, euclidean_dist: 5.340576652300969, len occurrence: 31
# Seed: 211, Video: 34, Frame start: 1767, euclidean_dist: 6.115811487486036, len occurrence: 31
# Seed: 211, Video: 35, Frame start: 554, euclidean_dist: 2.8713338430380317, len occurrence: 31
# Seed: 211, Video: 35, Frame start: 363, euclidean_dist: 5.278076247108812, len occurrence: 31
# Seed: 211, Video: 35, Frame start: 2798, euclidean_dist: 3.82888318735367, len occurrence: 31
# Seed: 211, Video: 36, Frame start: 6705, euclidean_dist: 5.007141767902521, len occurrence: 31
# Seed: 211, Video: 38, Frame start: 2737, euclidean_dist: 5.053619947455972, len occurrence: 31
# Seed: 211, Video: 45, Frame start: 204, euclidean_dist: 5.621604027335547, len occurrence: 31
# Seed: 211, Video: 49, Frame start: 2573, euclidean_dist: 5.554966158661159, len occurrence: 31
# Seed: 211, Video: 51, Frame start: 139, euclidean_dist: 5.590263248338456, len occurrence: 31
# Seed: 211, Video: 54, Frame start: 361, euclidean_dist: 6.092132427454903, len occurrence: 31
# Seed: 211, Video: 58, Frame start: 2579, euclidean_dist: 3.7820304254905968, len occurrence: 31
# Seed: 211, Video: 58, Frame start: 2123, euclidean_dist: 2.8489236741161164, len occurrence: 31
# Seed: 211, Video: 61, Frame start: 922, euclidean_dist: 5.22554377075168, len occurrence: 31
# Seed: 211, Video: 64, Frame start: 241, euclidean_dist: 4.444124368543704, len occurrence: 31
# Seed: 211, Video: 65, Frame start: 1911, euclidean_dist: 5.820887455176058, len occurrence: 31
# Seed: 211, Video: 66, Frame start: 342, euclidean_dist: 5.080733378013343, len occurrence: 31
# Seed: 211, Video: 67, Frame start: 2, euclidean_dist: 6.2141718360224365, len occurrence: 31
# Number irregulars: 3597
