# %% [markdown]
# # Import dependencies

# %%
import os
import sys
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

import time

# Import library with current code functions
sys.path.append(os.path.join("..", "lib"))
import manual_labeler_functions as man_lab_fun, automatic_labeler_functions as aut_lab_fun, general_functions as gf, files_paths as fp

# %% [markdown]
# ## Getting the list of measure files to be labeled and the list of seed available

# %%
FILE_LIST_VD_MEASURE = gf.find_files_in_all_subdirectories([fp.DATASET_YT, fp.DATASET_LOCAL], fp.VD_MEASURE_L0)
FILE_LIST_LABELED_SEED = gf.find_files_in_all_subdirectories([fp.DATASET_SEED], fp.VD_LABELED_L0)


start_range = 71
end_range = 100

filtered_vd_measure_files = [
    f for f in FILE_LIST_VD_MEASURE
    if start_range <= int(os.path.basename(os.path.dirname(f)).split('_')[-1]) <= end_range
]


filtered_vd_measure_files
# Out:
# ['..\\Dataset\\DD-Local\\VD_D_0000000071\\VD_MEASURE_L0.CSV',
#  '..\\Dataset\\DD-Local\\VD_D_0000000072\\VD_MEASURE_L0.CSV',
#  '..\\Dataset\\DD-Local\\VD_D_0000000073\\VD_MEASURE_L0.CSV',
#  '..\\Dataset\\DD-Local\\VD_D_0000000074\\VD_MEASURE_L0.CSV',
#  '..\\Dataset\\DD-Local\\VD_D_0000000075\\VD_MEASURE_L0.CSV',
#  '..\\Dataset\\DD-Local\\VD_D_0000000076\\VD_MEASURE_L0.CSV',
#  '..\\Dataset\\DD-Local\\VD_D_0000000077\\VD_MEASURE_L0.CSV',
#  '..\\Dataset\\DD-Local\\VD_D_0000000078\\VD_MEASURE_L0.CSV',
#  '..\\Dataset\\DD-Local\\VD_D_0000000079\\VD_MEASURE_L0.CSV',
#  '..\\Dataset\\DD-Local\\VD_D_0000000080\\VD_MEASURE_L0.CSV',
#  '..\\Dataset\\DD-Local\\VD_D_0000000081\\VD_MEASURE_L0.CSV',
#  '..\\Dataset\\DD-Local\\VD_D_0000000082\\VD_MEASURE_L0.CSV',
#  '..\\Dataset\\DD-Local\\VD_D_0000000083\\VD_MEASURE_L0.CSV',
#  '..\\Dataset\\DD-Local\\VD_D_0000000084\\VD_MEASURE_L0.CSV',
#  '..\\Dataset\\DD-Local\\VD_D_0000000085\\VD_MEASURE_L0.CSV',
#  '..\\Dataset\\DD-Local\\VD_D_0000000086\\VD_MEASURE_L0.CSV',
#  '..\\Dataset\\DD-Local\\VD_D_0000000087\\VD_MEASURE_L0.CSV',
#  '..\\Dataset\\DD-Local\\VD_D_0000000088\\VD_MEASURE_L0.CSV',
#  '..\\Dataset\\DD-Local\\VD_D_0000000089\\VD_MEASURE_L0.CSV',
#  '..\\Dataset\\DD-Local\\VD_D_0000000090\\VD_MEASURE_L0.CSV',
#  '..\\Dataset\\DD-Local\\VD_D_0000000091\\VD_MEASURE_L0.CSV',
#  '..\\Dataset\\DD-Local\\VD_D_0000000092\\VD_MEASURE_L0.CSV',
#  '..\\Dataset\\DD-Local\\VD_D_0000000093\\VD_MEASURE_L0.CSV',
#  '..\\Dataset\\DD-Local\\VD_D_0000000094\\VD_MEASURE_L0.CSV',
#  '..\\Dataset\\DD-Local\\VD_D_0000000095\\VD_MEASURE_L0.CSV',
#  '..\\Dataset\\DD-Local\\VD_D_0000000096\\VD_MEASURE_L0.CSV',
#  '..\\Dataset\\DD-Local\\VD_D_0000000097\\VD_MEASURE_L0.CSV',
#  '..\\Dataset\\DD-Local\\VD_D_0000000098\\VD_MEASURE_L0.CSV',
#  '..\\Dataset\\DD-Local\\VD_D_0000000099\\VD_MEASURE_L0.CSV',
#  '..\\Dataset\\DD-Local\\VD_D_0000000100\\VD_MEASURE_L0.CSV']

# %% [markdown]
# ## Remove all VD_LABELED_L0 file

# %%
def remove_file(FILE_LIST_PATH, file_name):
    for current_path in FILE_LIST_PATH:
        vd_labeled_path = os.path.join(os.path.dirname(current_path), file_name)
        if os.path.exists(vd_labeled_path):
            os.remove(vd_labeled_path)
            print(f"The file was removed: {vd_labeled_path}")
        else:
            print("File not found.")

# %%
remove_file(FILE_LIST_VD_MEASURE, fp.VD_LABELED_L0)

# %% [markdown]
# ## Select reference SEED

# %%
FILE_LIST_SEED_VD_INFO = gf.find_files_in_all_subdirectories([fp.DATASET_SEED], fp.VD_INFO)

# %% [markdown]
# ## Verificar quantidade de uma classe

# %%
import os
import re
import pandas as pd

def count_class_totals_and_instances(FILE_LIST_PATH, file_name, column_name, conditions, length_threshold=30):
    class_totals = {condition: 0 for condition in conditions}  
    class_instances = {condition: 0 for condition in conditions}  
    short_instances = {condition: 0 for condition in conditions}  
    instances_between_29_32 = {condition: 0 for condition in conditions}  
    instances_greater_32 = {condition: 0 for condition in conditions}  
    instance_lengths = {condition: [] for condition in conditions}  
    results_per_folder = {condition: [] for condition in conditions}
    paths_greater_32 = {condition: set() for condition in conditions}  
    paths_greater_70 = {condition: set() for condition in conditions}  

    for current_path in FILE_LIST_PATH:
        vd_labeled_path = os.path.join(os.path.dirname(current_path), file_name)

        if os.path.exists(vd_labeled_path):
            try:
                df = pd.read_csv(vd_labeled_path)

                if column_name in df.columns:
                    folder_name = os.path.basename(os.path.dirname(current_path))

                    match = re.search(r'VD_D_(\d+)', folder_name)
                    folder_number = int(match.group(1)) if match else -1  

                    for condition in conditions:
                        mask = df[column_name].str.contains(condition, case=False, na=False)
                        total_frames = mask.sum()
                        mask_diff = mask & ~mask.shift(fill_value=False)
                        total_instances = mask_diff.sum()

                        current_length = 0
                        short_instance_count = 0
                        between_29_32_count = 0
                        greater_32_count = 0
                        lengths = []

                        for val in mask:
                            if val:
                                current_length += 1
                            elif current_length > 0:
                                lengths.append(current_length)
                                if current_length < length_threshold:
                                    short_instance_count += 1
                                elif 29 <= current_length <= 32:
                                    between_29_32_count += 1
                                else:
                                    greater_32_count += 1
                                    paths_greater_32[condition].add(vd_labeled_path)
                                    if folder_number > 70:
                                        paths_greater_70[condition].add(vd_labeled_path)
                                current_length = 0

                        if current_length > 0:
                            lengths.append(current_length)
                            if current_length < length_threshold:
                                short_instance_count += 1
                            elif 29 <= current_length <= 32:
                                between_29_32_count += 1
                            else:
                                greater_32_count += 1
                                paths_greater_32[condition].add(vd_labeled_path)
                                if folder_number > 70:
                                    paths_greater_70[condition].add(vd_labeled_path)

                        instance_lengths[condition].extend(lengths)
                        results_per_folder[condition].append(
                            (folder_name, total_frames, total_instances, short_instance_count, between_29_32_count, greater_32_count)
                        )
                        class_totals[condition] += total_frames
                        class_instances[condition] += total_instances
                        short_instances[condition] += short_instance_count
                        instances_between_29_32[condition] += between_29_32_count
                        instances_greater_32[condition] += greater_32_count

            except Exception as e:
                print(f"Erro ao processar o arquivo {vd_labeled_path}: {e}")
        else:
            print(f"Arquivo não encontrado: {vd_labeled_path}")

    # Imprime os resultados
    for condition in conditions:
        print(f"\nResultados para '{condition}':")
        for folder_name, total_frames, total_instances, short_count, between_29_32_count, greater_32_count in results_per_folder[condition]:
            print(
                f"{folder_name} - {total_frames} frames, {total_instances} instâncias, "
                f"{short_count} instâncias < {length_threshold}, "
                f"{between_29_32_count} instâncias entre 29 e 32, "
                f"{greater_32_count} instâncias > 32"
            )

        total_inst = class_instances[condition]
        short_perc = (short_instances[condition] / total_inst * 100) if total_inst else 0
        between_29_32_perc = (instances_between_29_32[condition] / total_inst * 100) if total_inst else 0
        greater_32_perc = (instances_greater_32[condition] / total_inst * 100) if total_inst else 0
        avg_length = sum(instance_lengths[condition]) / len(instance_lengths[condition]) if instance_lengths[condition] else 0

        print(
            f"Total geral: {class_totals[condition]} frames, {total_inst} instâncias\n"
            f"{short_perc:.2f}% das instâncias são < {length_threshold}\n"
            f"{between_29_32_perc:.2f}% das instâncias estão entre 29 e 32\n"
            f"{greater_32_perc:.2f}% das instâncias são > 32\n"
            f"Média do tamanho das instâncias: {avg_length:.2f}"
        )

        # Imprime os caminhos dos arquivos com instâncias maiores que 32 e numeração > 70
        total_greater_32 = len(paths_greater_32[condition])
        total_greater_70 = len(paths_greater_70[condition])

        if total_greater_32 > 0:
            print(f"\nDe todos os {total_greater_32} vídeos com instâncias > 32 para '{condition}',")
            print(f"{total_greater_70} vídeos possuem VD_D_XX > 70.")
        
            print(f"\nArquivos contendo instâncias > 32 para '{condition}' (somente se VD_D_XX > 70):")
            for path in paths_greater_70[condition]:  
                print(path)

# Configuração dos caminhos
FILE_LIST_VD_MEASURE = gf.find_files_in_all_subdirectories([fp.DATASET_YT, fp.DATASET_LOCAL], fp.VD_MEASURE_L0)

# Executa a função
count_class_totals_and_instances(
    FILE_LIST_PATH=FILE_LIST_VD_MEASURE,
    file_name=fp.VD_LABELED_L0,
    column_name="label_measures",
    conditions=["OTHERS", "HAPPY", "NEUTRAL"]
)
# Out:
# Resultados para 'OTHERS':
# VD_D_0000000043 - 226 frames, 7 instâncias, 0 instâncias < 30, 6 instâncias entre 29 e 32, 1 instâncias > 32
# VD_D_0000000044 - 407 frames, 12 instâncias, 1 instâncias < 30, 8 instâncias entre 29 e 32, 3 instâncias > 32
# VD_D_0000000045 - 343 frames, 11 instâncias, 2 instâncias < 30, 6 instâncias entre 29 e 32, 3 instâncias > 32
# VD_D_0000000046 - 1017 frames, 33 instâncias, 8 instâncias < 30, 20 instâncias entre 29 e 32, 5 instâncias > 32
# VD_D_0000000047 - 227 frames, 8 instâncias, 2 instâncias < 30, 6 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000048 - 696 frames, 22 instâncias, 2 instâncias < 30, 18 instâncias entre 29 e 32, 2 instâncias > 32
# VD_D_0000000049 - 446 frames, 14 instâncias, 1 instâncias < 30, 10 instâncias entre 29 e 32, 3 instâncias > 32
# VD_D_0000000050 - 449 frames, 14 instâncias, 2 instâncias < 30, 7 instâncias entre 29 e 32, 5 instâncias > 32
# VD_D_0000000051 - 1289 frames, 43 instâncias, 9 instâncias < 30, 30 instâncias entre 29 e 32, 4 instâncias > 32
# VD_D_0000000052 - 820 frames, 27 instâncias, 5 instâncias < 30, 19 instâncias entre 29 e 32, 3 instâncias > 32
# VD_D_0000000053 - 215 frames, 7 instâncias, 0 instâncias < 30, 7 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000054 - 512 frames, 17 instâncias, 3 instâncias < 30, 12 instâncias entre 29 e 32, 2 instâncias > 32
# VD_D_0000000055 - 153 frames, 5 instâncias, 0 instâncias < 30, 5 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000056 - 1313 frames, 44 instâncias, 11 instâncias < 30, 28 instâncias entre 29 e 32, 5 instâncias > 32
# VD_D_0000000057 - 215 frames, 7 instâncias, 0 instâncias < 30, 7 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000058 - 452 frames, 15 instâncias, 1 instâncias < 30, 14 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000059 - 1052 frames, 35 instâncias, 8 instâncias < 30, 22 instâncias entre 29 e 32, 5 instâncias > 32
# VD_D_0000000060 - 141 frames, 5 instâncias, 2 instâncias < 30, 2 instâncias entre 29 e 32, 1 instâncias > 32
# VD_D_0000000061 - 1265 frames, 42 instâncias, 7 instâncias < 30, 30 instâncias entre 29 e 32, 5 instâncias > 32
# VD_D_0000000062 - 573 frames, 20 instâncias, 6 instâncias < 30, 13 instâncias entre 29 e 32, 1 instâncias > 32
# VD_D_0000000063 - 643 frames, 20 instâncias, 2 instâncias < 30, 13 instâncias entre 29 e 32, 5 instâncias > 32
# VD_D_0000000064 - 720 frames, 23 instâncias, 3 instâncias < 30, 15 instâncias entre 29 e 32, 5 instâncias > 32
# VD_D_0000000065 - 154 frames, 5 instâncias, 0 instâncias < 30, 5 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000066 - 547 frames, 18 instâncias, 4 instâncias < 30, 12 instâncias entre 29 e 32, 2 instâncias > 32
# VD_D_0000000067 - 699 frames, 23 instâncias, 5 instâncias < 30, 14 instâncias entre 29 e 32, 4 instâncias > 32
# VD_D_0000000068 - 277 frames, 9 instâncias, 2 instâncias < 30, 5 instâncias entre 29 e 32, 2 instâncias > 32
# VD_D_0000000069 - 508 frames, 16 instâncias, 1 instâncias < 30, 13 instâncias entre 29 e 32, 2 instâncias > 32
# VD_D_0000000070 - 820 frames, 27 instâncias, 3 instâncias < 30, 22 instâncias entre 29 e 32, 2 instâncias > 32
# VD_D_0000000071 - 5300 frames, 172 instâncias, 21 instâncias < 30, 134 instâncias entre 29 e 32, 17 instâncias > 32
# VD_D_0000000072 - 672 frames, 21 instâncias, 2 instâncias < 30, 14 instâncias entre 29 e 32, 5 instâncias > 32
# VD_D_0000000073 - 275 frames, 9 instâncias, 2 instâncias < 30, 6 instâncias entre 29 e 32, 1 instâncias > 32
# VD_D_0000000074 - 1333 frames, 45 instâncias, 9 instâncias < 30, 33 instâncias entre 29 e 32, 3 instâncias > 32
# VD_D_0000000075 - 1627 frames, 54 instâncias, 10 instâncias < 30, 38 instâncias entre 29 e 32, 6 instâncias > 32
# VD_D_0000000076 - 332 frames, 11 instâncias, 1 instâncias < 30, 9 instâncias entre 29 e 32, 1 instâncias > 32
# VD_D_0000000077 - 92 frames, 3 instâncias, 0 instâncias < 30, 3 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000078 - 3627 frames, 116 instâncias, 24 instâncias < 30, 73 instâncias entre 29 e 32, 19 instâncias > 32
# VD_D_0000000079 - 1446 frames, 47 instâncias, 4 instâncias < 30, 40 instâncias entre 29 e 32, 3 instâncias > 32
# VD_D_0000000080 - 2081 frames, 66 instâncias, 1 instâncias < 30, 59 instâncias entre 29 e 32, 6 instâncias > 32
# VD_D_0000000081 - 959 frames, 30 instâncias, 2 instâncias < 30, 22 instâncias entre 29 e 32, 6 instâncias > 32
# VD_D_0000000082 - 4458 frames, 146 instâncias, 22 instâncias < 30, 108 instâncias entre 29 e 32, 16 instâncias > 32
# VD_D_0000000083 - 231 frames, 8 instâncias, 2 instâncias < 30, 6 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000084 - 1114 frames, 36 instâncias, 7 instâncias < 30, 23 instâncias entre 29 e 32, 6 instâncias > 32
# VD_D_0000000085 - 91 frames, 3 instâncias, 0 instâncias < 30, 3 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000086 - 977 frames, 32 instâncias, 6 instâncias < 30, 24 instâncias entre 29 e 32, 2 instâncias > 32
# VD_D_0000000087 - 1778 frames, 58 instâncias, 8 instâncias < 30, 44 instâncias entre 29 e 32, 6 instâncias > 32
# VD_D_0000000088 - 493 frames, 15 instâncias, 2 instâncias < 30, 8 instâncias entre 29 e 32, 5 instâncias > 32
# VD_D_0000000089 - 2457 frames, 78 instâncias, 8 instâncias < 30, 57 instâncias entre 29 e 32, 13 instâncias > 32
# VD_D_0000000090 - 1693 frames, 55 instâncias, 8 instâncias < 30, 41 instâncias entre 29 e 32, 6 instâncias > 32
# VD_D_0000000091 - 5131 frames, 166 instâncias, 26 instâncias < 30, 121 instâncias entre 29 e 32, 19 instâncias > 32
# VD_D_0000000092 - 1602 frames, 52 instâncias, 8 instâncias < 30, 38 instâncias entre 29 e 32, 6 instâncias > 32
# VD_D_0000000093 - 104 frames, 3 instâncias, 0 instâncias < 30, 1 instâncias entre 29 e 32, 2 instâncias > 32
# VD_D_0000000094 - 827 frames, 27 instâncias, 5 instâncias < 30, 19 instâncias entre 29 e 32, 3 instâncias > 32
# VD_D_0000000095 - 3734 frames, 118 instâncias, 8 instâncias < 30, 94 instâncias entre 29 e 32, 16 instâncias > 32
# VD_D_0000000096 - 395 frames, 12 instâncias, 1 instâncias < 30, 8 instâncias entre 29 e 32, 3 instâncias > 32
# VD_D_0000000097 - 343 frames, 11 instâncias, 2 instâncias < 30, 7 instâncias entre 29 e 32, 2 instâncias > 32
# VD_D_0000000098 - 110 frames, 4 instâncias, 2 instâncias < 30, 2 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000099 - 494 frames, 17 instâncias, 6 instâncias < 30, 9 instâncias entre 29 e 32, 2 instâncias > 32
# VD_D_0000000100 - 807 frames, 25 instâncias, 2 instâncias < 30, 19 instâncias entre 29 e 32, 4 instâncias > 32
# VD_Y_0000000001 - 202 frames, 6 instâncias, 0 instâncias < 30, 4 instâncias entre 29 e 32, 2 instâncias > 32
# VD_Y_0000000002 - 897 frames, 29 instâncias, 4 instâncias < 30, 20 instâncias entre 29 e 32, 5 instâncias > 32
# VD_Y_0000000003 - 564 frames, 19 instâncias, 7 instâncias < 30, 9 instâncias entre 29 e 32, 3 instâncias > 32
# VD_Y_0000000004 - 343 frames, 11 instâncias, 0 instâncias < 30, 10 instâncias entre 29 e 32, 1 instâncias > 32
# VD_Y_0000000005 - 218 frames, 7 instâncias, 1 instâncias < 30, 5 instâncias entre 29 e 32, 1 instâncias > 32
# VD_Y_0000000006 - 1338 frames, 43 instâncias, 6 instâncias < 30, 29 instâncias entre 29 e 32, 8 instâncias > 32
# VD_Y_0000000007 - 1131 frames, 36 instâncias, 2 instâncias < 30, 29 instâncias entre 29 e 32, 5 instâncias > 32
# VD_Y_0000000008 - 2655 frames, 83 instâncias, 5 instâncias < 30, 65 instâncias entre 29 e 32, 13 instâncias > 32
# VD_Y_0000000009 - 244 frames, 8 instâncias, 1 instâncias < 30, 6 instâncias entre 29 e 32, 1 instâncias > 32
# VD_Y_0000000010 - 564 frames, 18 instâncias, 2 instâncias < 30, 14 instâncias entre 29 e 32, 2 instâncias > 32
# VD_Y_0000000011 - 769 frames, 25 instâncias, 3 instâncias < 30, 19 instâncias entre 29 e 32, 3 instâncias > 32
# VD_Y_0000000012 - 222 frames, 7 instâncias, 0 instâncias < 30, 6 instâncias entre 29 e 32, 1 instâncias > 32
# VD_Y_0000000013 - 313 frames, 10 instâncias, 0 instâncias < 30, 9 instâncias entre 29 e 32, 1 instâncias > 32
# VD_Y_0000000014 - 348 frames, 11 instâncias, 0 instâncias < 30, 10 instâncias entre 29 e 32, 1 instâncias > 32
# VD_Y_0000000015 - 362 frames, 12 instâncias, 2 instâncias < 30, 9 instâncias entre 29 e 32, 1 instâncias > 32
# VD_Y_0000000016 - 430 frames, 14 instâncias, 2 instâncias < 30, 10 instâncias entre 29 e 32, 2 instâncias > 32
# VD_Y_0000000017 - 453 frames, 15 instâncias, 2 instâncias < 30, 13 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000018 - 416 frames, 13 instâncias, 0 instâncias < 30, 11 instâncias entre 29 e 32, 2 instâncias > 32
# VD_Y_0000000019 - 340 frames, 11 instâncias, 2 instâncias < 30, 7 instâncias entre 29 e 32, 2 instâncias > 32
# VD_Y_0000000020 - 929 frames, 29 instâncias, 1 instâncias < 30, 21 instâncias entre 29 e 32, 7 instâncias > 32
# VD_Y_0000000021 - 694 frames, 23 instâncias, 4 instâncias < 30, 18 instâncias entre 29 e 32, 1 instâncias > 32
# VD_Y_0000000022 - 194 frames, 6 instâncias, 0 instâncias < 30, 5 instâncias entre 29 e 32, 1 instâncias > 32
# VD_Y_0000000023 - 241 frames, 8 instâncias, 1 instâncias < 30, 7 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000024 - 234 frames, 7 instâncias, 0 instâncias < 30, 5 instâncias entre 29 e 32, 2 instâncias > 32
# VD_Y_0000000025 - 279 frames, 9 instâncias, 1 instâncias < 30, 7 instâncias entre 29 e 32, 1 instâncias > 32
# VD_Y_0000000026 - 248 frames, 8 instâncias, 0 instâncias < 30, 8 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000027 - 159 frames, 5 instâncias, 1 instâncias < 30, 3 instâncias entre 29 e 32, 1 instâncias > 32
# VD_Y_0000000028 - 317 frames, 10 instâncias, 0 instâncias < 30, 9 instâncias entre 29 e 32, 1 instâncias > 32
# VD_Y_0000000029 - 551 frames, 17 instâncias, 2 instâncias < 30, 12 instâncias entre 29 e 32, 3 instâncias > 32
# VD_Y_0000000030 - 461 frames, 15 instâncias, 3 instâncias < 30, 10 instâncias entre 29 e 32, 2 instâncias > 32
# VD_Y_0000000031 - 1109 frames, 35 instâncias, 6 instâncias < 30, 24 instâncias entre 29 e 32, 5 instâncias > 32
# VD_Y_0000000032 - 369 frames, 12 instâncias, 2 instâncias < 30, 9 instâncias entre 29 e 32, 1 instâncias > 32
# VD_Y_0000000033 - 252 frames, 8 instâncias, 2 instâncias < 30, 4 instâncias entre 29 e 32, 2 instâncias > 32
# VD_Y_0000000034 - 148 frames, 5 instâncias, 1 instâncias < 30, 4 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000035 - 487 frames, 15 instâncias, 1 instâncias < 30, 10 instâncias entre 29 e 32, 4 instâncias > 32
# VD_Y_0000000036 - 701 frames, 22 instâncias, 4 instâncias < 30, 13 instâncias entre 29 e 32, 5 instâncias > 32
# VD_Y_0000000037 - 731 frames, 23 instâncias, 1 instâncias < 30, 18 instâncias entre 29 e 32, 4 instâncias > 32
# VD_Y_0000000038 - 858 frames, 29 instâncias, 6 instâncias < 30, 20 instâncias entre 29 e 32, 3 instâncias > 32
# VD_Y_0000000039 - 265 frames, 9 instâncias, 1 instâncias < 30, 8 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000040 - 286 frames, 9 instâncias, 1 instâncias < 30, 6 instâncias entre 29 e 32, 2 instâncias > 32
# VD_Y_0000000041 - 119 frames, 4 instâncias, 1 instâncias < 30, 3 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000042 - 208 frames, 7 instâncias, 2 instâncias < 30, 3 instâncias entre 29 e 32, 2 instâncias > 32
# Total geral: 82411 frames, 2662 instâncias
# 13.86% das instâncias são < 30
# 73.03% das instâncias estão entre 29 e 32
# 13.11% das instâncias são > 32
# Média do tamanho das instâncias: 30.96
#
# De todos os 84 vídeos com instâncias > 32 para 'OTHERS',
# 26 vídeos possuem VD_D_XX > 70.
#
# Arquivos contendo instâncias > 32 para 'OTHERS' (somente se VD_D_XX > 70):
# ..\Dataset\DD-Local\VD_D_0000000082\VD_LABELED_L0.CSV
# ..\Dataset\DD-Local\VD_D_0000000093\VD_LABELED_L0.CSV
# ..\Dataset\DD-Local\VD_D_0000000091\VD_LABELED_L0.CSV
# ..\Dataset\DD-Local\VD_D_0000000095\VD_LABELED_L0.CSV
# ..\Dataset\DD-Local\VD_D_0000000073\VD_LABELED_L0.CSV
# ..\Dataset\DD-Local\VD_D_0000000076\VD_LABELED_L0.CSV
# ..\Dataset\DD-Local\VD_D_0000000078\VD_LABELED_L0.CSV
# ..\Dataset\DD-Local\VD_D_0000000074\VD_LABELED_L0.CSV
# ..\Dataset\DD-Local\VD_D_0000000090\VD_LABELED_L0.CSV
# ..\Dataset\DD-Local\VD_D_0000000099\VD_LABELED_L0.CSV
# ..\Dataset\DD-Local\VD_D_0000000096\VD_LABELED_L0.CSV
# ..\Dataset\DD-Local\VD_D_0000000087\VD_LABELED_L0.CSV
# ..\Dataset\DD-Local\VD_D_0000000079\VD_LABELED_L0.CSV
# ..\Dataset\DD-Local\VD_D_0000000081\VD_LABELED_L0.CSV
# ..\Dataset\DD-Local\VD_D_0000000092\VD_LABELED_L0.CSV
# ..\Dataset\DD-Local\VD_D_0000000100\VD_LABELED_L0.CSV
# ..\Dataset\DD-Local\VD_D_0000000094\VD_LABELED_L0.CSV
# ..\Dataset\DD-Local\VD_D_0000000071\VD_LABELED_L0.CSV
# ..\Dataset\DD-Local\VD_D_0000000084\VD_LABELED_L0.CSV
# ..\Dataset\DD-Local\VD_D_0000000080\VD_LABELED_L0.CSV
# ..\Dataset\DD-Local\VD_D_0000000097\VD_LABELED_L0.CSV
# ..\Dataset\DD-Local\VD_D_0000000086\VD_LABELED_L0.CSV
# ..\Dataset\DD-Local\VD_D_0000000088\VD_LABELED_L0.CSV
# ..\Dataset\DD-Local\VD_D_0000000089\VD_LABELED_L0.CSV
# ..\Dataset\DD-Local\VD_D_0000000072\VD_LABELED_L0.CSV
# ..\Dataset\DD-Local\VD_D_0000000075\VD_LABELED_L0.CSV
#
# Resultados para 'HAPPY':
# VD_D_0000000043 - 95 frames, 5 instâncias, 4 instâncias < 30, 1 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000044 - 171 frames, 5 instâncias, 3 instâncias < 30, 1 instâncias entre 29 e 32, 1 instâncias > 32
# VD_D_0000000045 - 64 frames, 4 instâncias, 4 instâncias < 30, 0 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000046 - 367 frames, 20 instâncias, 17 instâncias < 30, 3 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000047 - 173 frames, 9 instâncias, 7 instâncias < 30, 2 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000048 - 323 frames, 14 instâncias, 7 instâncias < 30, 7 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000049 - 259 frames, 12 instâncias, 8 instâncias < 30, 4 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000050 - 179 frames, 9 instâncias, 6 instâncias < 30, 3 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000051 - 694 frames, 35 instâncias, 28 instâncias < 30, 6 instâncias entre 29 e 32, 1 instâncias > 32
# VD_D_0000000052 - 575 frames, 27 instâncias, 21 instâncias < 30, 5 instâncias entre 29 e 32, 1 instâncias > 32
# VD_D_0000000053 - 254 frames, 9 instâncias, 1 instâncias < 30, 8 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000054 - 323 frames, 16 instâncias, 12 instâncias < 30, 4 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000055 - 162 frames, 9 instâncias, 9 instâncias < 30, 0 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000056 - 668 frames, 40 instâncias, 34 instâncias < 30, 6 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000057 - 97 frames, 4 instâncias, 2 instâncias < 30, 2 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000058 - 465 frames, 20 instâncias, 10 instâncias < 30, 10 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000059 - 435 frames, 19 instâncias, 10 instâncias < 30, 9 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000060 - 122 frames, 6 instâncias, 6 instâncias < 30, 0 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000061 - 617 frames, 31 instâncias, 23 instâncias < 30, 8 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000062 - 342 frames, 19 instâncias, 16 instâncias < 30, 3 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000063 - 474 frames, 24 instâncias, 19 instâncias < 30, 5 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000064 - 660 frames, 30 instâncias, 20 instâncias < 30, 10 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000065 - 89 frames, 5 instâncias, 5 instâncias < 30, 0 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000066 - 646 frames, 26 instâncias, 14 instâncias < 30, 12 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000067 - 481 frames, 21 instâncias, 12 instâncias < 30, 9 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000068 - 85 frames, 3 instâncias, 1 instâncias < 30, 2 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000069 - 446 frames, 17 instâncias, 9 instâncias < 30, 7 instâncias entre 29 e 32, 1 instâncias > 32
# VD_D_0000000070 - 414 frames, 20 instâncias, 15 instâncias < 30, 5 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000071 - 3015 frames, 134 instâncias, 83 instâncias < 30, 51 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000072 - 372 frames, 15 instâncias, 8 instâncias < 30, 7 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000073 - 181 frames, 7 instâncias, 3 instâncias < 30, 4 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000074 - 718 frames, 32 instâncias, 21 instâncias < 30, 11 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000075 - 747 frames, 32 instâncias, 20 instâncias < 30, 12 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000076 - 73 frames, 3 instâncias, 1 instâncias < 30, 2 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000077 - 67 frames, 3 instâncias, 2 instâncias < 30, 1 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000078 - 1418 frames, 67 instâncias, 50 instâncias < 30, 17 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000079 - 907 frames, 39 instâncias, 22 instâncias < 30, 17 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000080 - 756 frames, 34 instâncias, 21 instâncias < 30, 13 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000081 - 491 frames, 23 instâncias, 15 instâncias < 30, 8 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000082 - 1875 frames, 86 instâncias, 57 instâncias < 30, 29 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000083 - 288 frames, 16 instâncias, 14 instâncias < 30, 2 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000084 - 422 frames, 22 instâncias, 16 instâncias < 30, 6 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000085 - 55 frames, 2 instâncias, 1 instâncias < 30, 1 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000086 - 518 frames, 22 instâncias, 15 instâncias < 30, 7 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000087 - 1428 frames, 60 instâncias, 35 instâncias < 30, 25 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000088 - 425 frames, 20 instâncias, 15 instâncias < 30, 5 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000089 - 1528 frames, 64 instâncias, 35 instâncias < 30, 29 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000090 - 1019 frames, 47 instâncias, 33 instâncias < 30, 14 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000091 - 3775 frames, 157 instâncias, 99 instâncias < 30, 56 instâncias entre 29 e 32, 2 instâncias > 32
# VD_D_0000000092 - 1113 frames, 46 instâncias, 27 instâncias < 30, 19 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000093 - 114 frames, 4 instâncias, 1 instâncias < 30, 3 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000094 - 381 frames, 18 instâncias, 12 instâncias < 30, 6 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000095 - 1509 frames, 62 instâncias, 33 instâncias < 30, 29 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000096 - 56 frames, 3 instâncias, 2 instâncias < 30, 1 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000097 - 170 frames, 6 instâncias, 2 instâncias < 30, 4 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000098 - 67 frames, 3 instâncias, 2 instâncias < 30, 1 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000099 - 382 frames, 17 instâncias, 9 instâncias < 30, 8 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000100 - 397 frames, 17 instâncias, 10 instâncias < 30, 7 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000001 - 94 frames, 5 instâncias, 4 instâncias < 30, 1 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000002 - 503 frames, 23 instâncias, 13 instâncias < 30, 10 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000003 - 290 frames, 14 instâncias, 9 instâncias < 30, 5 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000004 - 197 frames, 9 instâncias, 5 instâncias < 30, 4 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000005 - 142 frames, 7 instâncias, 6 instâncias < 30, 1 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000006 - 540 frames, 28 instâncias, 21 instâncias < 30, 7 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000007 - 403 frames, 16 instâncias, 10 instâncias < 30, 6 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000008 - 1158 frames, 48 instâncias, 28 instâncias < 30, 20 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000009 - 129 frames, 6 instâncias, 5 instâncias < 30, 1 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000010 - 173 frames, 8 instâncias, 6 instâncias < 30, 2 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000011 - 550 frames, 27 instâncias, 20 instâncias < 30, 7 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000012 - 13 frames, 1 instâncias, 1 instâncias < 30, 0 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000013 - 336 frames, 14 instâncias, 9 instâncias < 30, 5 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000014 - 242 frames, 9 instâncias, 3 instâncias < 30, 6 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000015 - 272 frames, 13 instâncias, 9 instâncias < 30, 4 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000016 - 319 frames, 14 instâncias, 8 instâncias < 30, 6 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000017 - 310 frames, 16 instâncias, 12 instâncias < 30, 4 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000018 - 131 frames, 7 instâncias, 6 instâncias < 30, 1 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000019 - 125 frames, 7 instâncias, 7 instâncias < 30, 0 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000020 - 487 frames, 21 instâncias, 11 instâncias < 30, 10 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000021 - 385 frames, 19 instâncias, 15 instâncias < 30, 4 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000022 - 60 frames, 2 instâncias, 0 instâncias < 30, 2 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000023 - 140 frames, 6 instâncias, 3 instâncias < 30, 3 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000024 - 13 frames, 1 instâncias, 1 instâncias < 30, 0 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000025 - 241 frames, 12 instâncias, 7 instâncias < 30, 5 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000026 - 139 frames, 5 instâncias, 2 instâncias < 30, 3 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000027 - 141 frames, 6 instâncias, 3 instâncias < 30, 3 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000028 - 201 frames, 9 instâncias, 6 instâncias < 30, 3 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000029 - 275 frames, 11 instâncias, 4 instâncias < 30, 7 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000030 - 303 frames, 12 instâncias, 8 instâncias < 30, 4 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000031 - 760 frames, 29 instâncias, 15 instâncias < 30, 14 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000032 - 106 frames, 6 instâncias, 5 instâncias < 30, 1 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000033 - 191 frames, 9 instâncias, 6 instâncias < 30, 3 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000034 - 98 frames, 5 instâncias, 5 instâncias < 30, 0 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000035 - 211 frames, 8 instâncias, 5 instâncias < 30, 3 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000036 - 332 frames, 14 instâncias, 10 instâncias < 30, 4 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000037 - 328 frames, 14 instâncias, 8 instâncias < 30, 6 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000038 - 576 frames, 26 instâncias, 16 instâncias < 30, 10 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000039 - 149 frames, 8 instâncias, 6 instâncias < 30, 2 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000040 - 121 frames, 5 instâncias, 3 instâncias < 30, 2 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000041 - 144 frames, 5 instâncias, 1 instâncias < 30, 4 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000042 - 260 frames, 10 instâncias, 3 instâncias < 30, 7 instâncias entre 29 e 32, 0 instâncias > 32
# Total geral: 45535 frames, 2035 instâncias
# 64.47% das instâncias são < 30
# 35.23% das instâncias estão entre 29 e 32
# 0.29% das instâncias são > 32
# Média do tamanho das instâncias: 22.38
#
# De todos os 5 vídeos com instâncias > 32 para 'HAPPY',
# 1 vídeos possuem VD_D_XX > 70.
#
# Arquivos contendo instâncias > 32 para 'HAPPY' (somente se VD_D_XX > 70):
# ..\Dataset\DD-Local\VD_D_0000000091\VD_LABELED_L0.CSV
#
# Resultados para 'NEUTRAL':
# VD_D_0000000043 - 275 frames, 14 instâncias, 11 instâncias < 30, 3 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000044 - 174 frames, 9 instâncias, 7 instâncias < 30, 2 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000045 - 240 frames, 14 instâncias, 11 instâncias < 30, 3 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000046 - 793 frames, 39 instâncias, 25 instâncias < 30, 14 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000047 - 725 frames, 38 instâncias, 30 instâncias < 30, 8 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000048 - 737 frames, 39 instâncias, 31 instâncias < 30, 8 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000049 - 527 frames, 30 instâncias, 24 instâncias < 30, 6 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000050 - 456 frames, 23 instâncias, 16 instâncias < 30, 7 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000051 - 1116 frames, 57 instâncias, 45 instâncias < 30, 12 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000052 - 1204 frames, 61 instâncias, 47 instâncias < 30, 14 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000053 - 307 frames, 14 instâncias, 8 instâncias < 30, 6 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000054 - 648 frames, 35 instâncias, 24 instâncias < 30, 11 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000055 - 278 frames, 13 instâncias, 9 instâncias < 30, 4 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000056 - 1100 frames, 60 instâncias, 47 instâncias < 30, 13 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000057 - 183 frames, 8 instâncias, 3 instâncias < 30, 5 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000058 - 643 frames, 31 instâncias, 20 instâncias < 30, 11 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000059 - 715 frames, 33 instâncias, 20 instâncias < 30, 13 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000060 - 235 frames, 12 instâncias, 7 instâncias < 30, 5 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000061 - 1205 frames, 60 instâncias, 47 instâncias < 30, 13 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000062 - 902 frames, 47 instâncias, 33 instâncias < 30, 12 instâncias entre 29 e 32, 2 instâncias > 32
# VD_D_0000000063 - 645 frames, 35 instâncias, 29 instâncias < 30, 6 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000064 - 1141 frames, 54 instâncias, 34 instâncias < 30, 20 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000065 - 320 frames, 19 instâncias, 17 instâncias < 30, 2 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000066 - 877 frames, 43 instâncias, 29 instâncias < 30, 14 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000067 - 582 frames, 32 instâncias, 25 instâncias < 30, 7 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000068 - 326 frames, 12 instâncias, 5 instâncias < 30, 7 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000069 - 606 frames, 31 instâncias, 22 instâncias < 30, 9 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000070 - 673 frames, 35 instâncias, 26 instâncias < 30, 9 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000071 - 5009 frames, 244 instâncias, 184 instâncias < 30, 60 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000072 - 736 frames, 29 instâncias, 17 instâncias < 30, 12 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000073 - 182 frames, 8 instâncias, 5 instâncias < 30, 3 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000074 - 957 frames, 46 instâncias, 34 instâncias < 30, 12 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000075 - 813 frames, 42 instâncias, 34 instâncias < 30, 8 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000076 - 164 frames, 6 instâncias, 3 instâncias < 30, 3 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000077 - 145 frames, 8 instâncias, 6 instâncias < 30, 2 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000078 - 2977 frames, 153 instâncias, 110 instâncias < 30, 42 instâncias entre 29 e 32, 1 instâncias > 32
# VD_D_0000000079 - 981 frames, 47 instâncias, 36 instâncias < 30, 9 instâncias entre 29 e 32, 2 instâncias > 32
# VD_D_0000000080 - 1938 frames, 84 instâncias, 60 instâncias < 30, 23 instâncias entre 29 e 32, 1 instâncias > 32
# VD_D_0000000081 - 1409 frames, 80 instâncias, 64 instâncias < 30, 16 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000082 - 2976 frames, 132 instâncias, 94 instâncias < 30, 38 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000083 - 481 frames, 23 instâncias, 18 instâncias < 30, 5 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000084 - 1057 frames, 56 instâncias, 44 instâncias < 30, 12 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000085 - 111 frames, 5 instâncias, 4 instâncias < 30, 1 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000086 - 1229 frames, 63 instâncias, 46 instâncias < 30, 17 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000087 - 2103 frames, 94 instâncias, 53 instâncias < 30, 41 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000088 - 802 frames, 33 instâncias, 18 instâncias < 30, 15 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000089 - 2180 frames, 98 instâncias, 58 instâncias < 30, 39 instâncias entre 29 e 32, 1 instâncias > 32
# VD_D_0000000090 - 1440 frames, 62 instâncias, 41 instâncias < 30, 19 instâncias entre 29 e 32, 2 instâncias > 32
# VD_D_0000000091 - 4110 frames, 190 instâncias, 127 instâncias < 30, 62 instâncias entre 29 e 32, 1 instâncias > 32
# VD_D_0000000092 - 1313 frames, 58 instâncias, 38 instâncias < 30, 18 instâncias entre 29 e 32, 2 instâncias > 32
# VD_D_0000000093 - 123 frames, 5 instâncias, 3 instâncias < 30, 2 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000094 - 710 frames, 32 instâncias, 23 instâncias < 30, 9 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000095 - 3106 frames, 142 instâncias, 86 instâncias < 30, 53 instâncias entre 29 e 32, 3 instâncias > 32
# VD_D_0000000096 - 232 frames, 11 instâncias, 8 instâncias < 30, 3 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000097 - 242 frames, 12 instâncias, 9 instâncias < 30, 2 instâncias entre 29 e 32, 1 instâncias > 32
# VD_D_0000000098 - 241 frames, 12 instâncias, 9 instâncias < 30, 3 instâncias entre 29 e 32, 0 instâncias > 32
# VD_D_0000000099 - 742 frames, 38 instâncias, 29 instâncias < 30, 8 instâncias entre 29 e 32, 1 instâncias > 32
# VD_D_0000000100 - 826 frames, 37 instâncias, 24 instâncias < 30, 13 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000001 - 222 frames, 6 instâncias, 1 instâncias < 30, 4 instâncias entre 29 e 32, 1 instâncias > 32
# VD_Y_0000000002 - 544 frames, 27 instâncias, 20 instâncias < 30, 7 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000003 - 522 frames, 24 instâncias, 16 instâncias < 30, 8 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000004 - 175 frames, 9 instâncias, 7 instâncias < 30, 2 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000005 - 379 frames, 17 instâncias, 13 instâncias < 30, 4 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000006 - 976 frames, 53 instâncias, 44 instâncias < 30, 9 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000007 - 862 frames, 36 instâncias, 29 instâncias < 30, 7 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000008 - 1399 frames, 65 instâncias, 48 instâncias < 30, 17 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000009 - 107 frames, 4 instâncias, 3 instâncias < 30, 1 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000010 - 428 frames, 20 instâncias, 14 instâncias < 30, 6 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000011 - 712 frames, 33 instâncias, 24 instâncias < 30, 9 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000012 - 226 frames, 9 instâncias, 4 instâncias < 30, 5 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000013 - 324 frames, 14 instâncias, 9 instâncias < 30, 5 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000014 - 148 frames, 8 instâncias, 6 instâncias < 30, 2 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000015 - 309 frames, 16 instâncias, 12 instâncias < 30, 4 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000016 - 282 frames, 13 instâncias, 8 instâncias < 30, 5 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000017 - 327 frames, 12 instâncias, 6 instâncias < 30, 6 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000018 - 256 frames, 13 instâncias, 9 instâncias < 30, 4 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000019 - 234 frames, 11 instâncias, 7 instâncias < 30, 4 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000020 - 709 frames, 36 instâncias, 26 instâncias < 30, 10 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000021 - 641 frames, 29 instâncias, 20 instâncias < 30, 9 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000022 - 107 frames, 5 instâncias, 4 instâncias < 30, 1 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000023 - 361 frames, 14 instâncias, 5 instâncias < 30, 9 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000024 - 94 frames, 4 instâncias, 2 instâncias < 30, 2 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000025 - 268 frames, 15 instâncias, 12 instâncias < 30, 3 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000026 - 156 frames, 7 instâncias, 4 instâncias < 30, 3 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000027 - 147 frames, 7 instâncias, 5 instâncias < 30, 2 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000028 - 260 frames, 11 instâncias, 6 instâncias < 30, 5 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000029 - 670 frames, 32 instâncias, 20 instâncias < 30, 12 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000030 - 470 frames, 22 instâncias, 16 instâncias < 30, 6 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000031 - 769 frames, 34 instâncias, 20 instâncias < 30, 14 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000032 - 114 frames, 5 instâncias, 2 instâncias < 30, 3 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000033 - 164 frames, 8 instâncias, 6 instâncias < 30, 2 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000034 - 86 frames, 5 instâncias, 4 instâncias < 30, 1 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000035 - 227 frames, 9 instâncias, 5 instâncias < 30, 4 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000036 - 325 frames, 15 instâncias, 11 instâncias < 30, 4 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000037 - 632 frames, 31 instâncias, 26 instâncias < 30, 5 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000038 - 910 frames, 48 instâncias, 37 instâncias < 30, 11 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000039 - 164 frames, 8 instâncias, 7 instâncias < 30, 1 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000040 - 237 frames, 9 instâncias, 4 instâncias < 30, 5 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000041 - 229 frames, 11 instâncias, 7 instâncias < 30, 4 instâncias entre 29 e 32, 0 instâncias > 32
# VD_Y_0000000042 - 243 frames, 11 instâncias, 8 instâncias < 30, 3 instâncias entre 29 e 32, 0 instâncias > 32
# Total geral: 73383 frames, 3514 instâncias
# 70.40% das instâncias são < 30
# 29.08% das instâncias estão entre 29 e 32
# 0.51% das instâncias são > 32
# Média do tamanho das instâncias: 20.88
#
# De todos os 12 vídeos com instâncias > 32 para 'NEUTRAL',
# 10 vídeos possuem VD_D_XX > 70.
#
# Arquivos contendo instâncias > 32 para 'NEUTRAL' (somente se VD_D_XX > 70):
# ..\Dataset\DD-Local\VD_D_0000000099\VD_LABELED_L0.CSV
# ..\Dataset\DD-Local\VD_D_0000000097\VD_LABELED_L0.CSV
# ..\Dataset\DD-Local\VD_D_0000000079\VD_LABELED_L0.CSV
# ..\Dataset\DD-Local\VD_D_0000000091\VD_LABELED_L0.CSV
# ..\Dataset\DD-Local\VD_D_0000000095\VD_LABELED_L0.CSV
# ..\Dataset\DD-Local\VD_D_0000000089\VD_LABELED_L0.CSV
# ..\Dataset\DD-Local\VD_D_0000000092\VD_LABELED_L0.CSV
# ..\Dataset\DD-Local\VD_D_0000000080\VD_LABELED_L0.CSV
# ..\Dataset\DD-Local\VD_D_0000000078\VD_LABELED_L0.CSV
# ..\Dataset\DD-Local\VD_D_0000000090\VD_LABELED_L0.CSV

# %%
count_happy = count_neutral = count_others = 0

for vd_info_file in FILE_LIST_SEED_VD_INFO:
    vd_info_df = pd.read_csv(vd_info_file)
    #print("vd_info_df", vd_info_df['link_video'])

    count_happy += len([emotion for emotion in vd_info_df['link_video'] if 'happy' in str(vd_info_df['link_video'])])
    count_neutral += len([emotion for emotion in vd_info_df['link_video'] if 'neutral' in str(vd_info_df['link_video'])])
    count_others += len([emotion for emotion in vd_info_df['link_video']if 'others' in str(vd_info_df['link_video'])])

print("Number of happy seeds:", count_happy)
print("Number of neutral seeds:", count_neutral)
print("Number of others seeds:", count_others)

# %%
FILE_LIST_LABELED_SEED

# %% [markdown]
# ## Automatic Labeler

# %%
current_labeling_class = 0 # Change for the correspondent number of your labeling class
frame_distance_threshold = 2
euclidean_distance_threshold = 1.2
current_total_saved_series = 0

matches_memory = []
all_matches_memory = []
all_mass_memory = []
all_idxs_match_frame_seq_memory = []
all_seeds_occurrences_len = []

all_data_memory = []

for j, labeled_file in enumerate(FILE_LIST_LABELED_SEED[:]):
    RESUME_DT = pd.DataFrame()
    print(f'\nSearch with seed: {os.path.basename(os.path.dirname(labeled_file))}\n')

    current_seed_matches_memory = []
    current_seed_all_matches_memory = []
    current_seed_all_mass_memory = []

    current_seed_data_memory = []
    
    for i, current_path_location in enumerate(filtered_vd_measure_files):

        path_dir = os.path.dirname(labeled_file)
        vd_labeled_path = os.path.join(path_dir, fp.VD_LABELED_L0)
        vd_labeled = pd.read_csv(vd_labeled_path)
        vd_labeled.drop(columns=['Unnamed: 0'], inplace=True)

        all_class = man_lab_fun.GET_ALL_CLASSES(vd_labeled)
        label_name = all_class[current_labeling_class]

        reference_measures = man_lab_fun.GET_MEASURES_FROM_CLASS(vd_labeled, label_name)

        frames = man_lab_fun.GET_FRAMES_FROM_CLASS(vd_labeled, label_name)

        all_measures_in_frame_interval = vd_labeled.loc[0:len(frames)]

        selected_measures_in_frame_interval = all_measures_in_frame_interval[reference_measures]

        dict_label_parameters = {'label_name': label_name, 'reference_measures': reference_measures}

        RESUME_DT, matches, all_matches, all_mass, idxs_match_frame_seq, occurrences_len = aut_lab_fun.label_current_series(current_path_location, RESUME_DT, selected_measures_in_frame_interval, dict_label_parameters, os.path.dirname(labeled_file), LABELED_FILE_NAME=fp.VD_LABELED_L0, distance_threshold=euclidean_distance_threshold, frame_threshold=frame_distance_threshold)  

        current_seed_data_memory.append([])

        for k, (frame, dist) in enumerate(idxs_match_frame_seq):
            frame_dist_len_data = []
            frame_dist_len_data.append(frame)
            frame_dist_len_data.append(dist)
            frame_dist_len_data.append(occurrences_len[k])

            current_seed_data_memory[i].append(frame_dist_len_data)

    all_data_memory.append(current_seed_data_memory)

    final_sum = RESUME_DT['final'].sum()
    current_total_saved_series += final_sum
    print(f'Number of occurrences found for the current seed: {final_sum}') 
    print(f'Total of occurrences: {current_total_saved_series}')
# Out:
# Search with seed: VD_R_0000000001
#
# Number of occurrences found for the current seed: 27
# Total of occurrences: 27
#
# Search with seed: VD_R_0000000002
#
# Number of occurrences found for the current seed: 8
# Total of occurrences: 35
#
# Search with seed: VD_R_0000000003
#
# Number of occurrences found for the current seed: 6
# Total of occurrences: 41
#
# Search with seed: VD_R_0000000004
#
# Number of occurrences found for the current seed: 25
# Total of occurrences: 66
#
# Search with seed: VD_R_0000000005
#
# Number of occurrences found for the current seed: 42
# Total of occurrences: 108
#
# Search with seed: VD_R_0000000006
#
# Number of occurrences found for the current seed: 42
# Total of occurrences: 150
#
# Search with seed: VD_R_0000000007
#
# Number of occurrences found for the current seed: 42
# Total of occurrences: 192
#
# Search with seed: VD_R_0000000008
#
# Number of occurrences found for the current seed: 34
# Total of occurrences: 226
#
# Search with seed: VD_R_0000000009
#
# Number of occurrences found for the current seed: 37
# Total of occurrences: 263
#
# Search with seed: VD_R_0000000010
#
# Number of occurrences found for the current seed: 21
# Total of occurrences: 284
#
# Search with seed: VD_R_0000000011
#
# Number of occurrences found for the current seed: 23
# Total of occurrences: 307
#
# Search with seed: VD_R_0000000012
#
# Number of occurrences found for the current seed: 11
# Total of occurrences: 318
#
# Search with seed: VD_R_0000000013
#
# Number of occurrences found for the current seed: 2
# Total of occurrences: 320
#
# Search with seed: VD_R_0000000014
#
# Number of occurrences found for the current seed: 11
# Total of occurrences: 331
#
# Search with seed: VD_R_0000000015
#
# Number of occurrences found for the current seed: 47
# Total of occurrences: 378
#
# Search with seed: VD_R_0000000016
#
# Number of occurrences found for the current seed: 8
# Total of occurrences: 386
#
# Search with seed: VD_R_0000000017
#
# Number of occurrences found for the current seed: 8
# Total of occurrences: 394
#
# Search with seed: VD_R_0000000018
#
# Number of occurrences found for the current seed: 9
# Total of occurrences: 403
#
# Search with seed: VD_R_0000000019
#
# Number of occurrences found for the current seed: 14
# Total of occurrences: 417
#
# Search with seed: VD_R_0000000020
#
# Number of occurrences found for the current seed: 18
# Total of occurrences: 435
#
# Search with seed: VD_R_0000000021
#
# Number of occurrences found for the current seed: 33
# Total of occurrences: 468
#
# Search with seed: VD_R_0000000022
#
# Number of occurrences found for the current seed: 20
# Total of occurrences: 488
#
# Search with seed: VD_R_0000000023
#
# Number of occurrences found for the current seed: 15
# Total of occurrences: 503
#
# Search with seed: VD_R_0000000024
#
# Number of occurrences found for the current seed: 14
# Total of occurrences: 517
#
# Search with seed: VD_R_0000000025
#
# Number of occurrences found for the current seed: 17
# Total of occurrences: 534
#
# Search with seed: VD_R_0000000026
#
# Number of occurrences found for the current seed: 6
# Total of occurrences: 540
#
# Search with seed: VD_R_0000000027
#
# Number of occurrences found for the current seed: 36
# Total of occurrences: 576
#
# Search with seed: VD_R_0000000028
#
# Number of occurrences found for the current seed: 14
# Total of occurrences: 590
#
# Search with seed: VD_R_0000000029
#
# Number of occurrences found for the current seed: 5
# Total of occurrences: 595
#
# Search with seed: VD_R_0000000030
#
# Number of occurrences found for the current seed: 2
# Total of occurrences: 597
#
# Search with seed: VD_R_0000000031
#
# Number of occurrences found for the current seed: 4
# Total of occurrences: 601
#
# Search with seed: VD_R_0000000032
#
# Number of occurrences found for the current seed: 6
# Total of occurrences: 607
#
# Search with seed: VD_R_0000000033
#
# Number of occurrences found for the current seed: 32
# Total of occurrences: 639
#
# Search with seed: VD_R_0000000034
#
# Number of occurrences found for the current seed: 31
# Total of occurrences: 670
#
# Search with seed: VD_R_0000000035
#
# Number of occurrences found for the current seed: 22
# Total of occurrences: 692
#
# Search with seed: VD_R_0000000036
#
# Number of occurrences found for the current seed: 39
# Total of occurrences: 731
#
# Search with seed: VD_R_0000000037
#
# Number of occurrences found for the current seed: 16
# Total of occurrences: 747
#
# Search with seed: VD_R_0000000038
#
# Number of occurrences found for the current seed: 23
# Total of occurrences: 770
#
# Search with seed: VD_R_0000000039
#
# Number of occurrences found for the current seed: 74
# Total of occurrences: 844
#
# Search with seed: VD_R_0000000040
#
# Number of occurrences found for the current seed: 16
# Total of occurrences: 860
#
# Search with seed: VD_R_0000000041
#
# Number of occurrences found for the current seed: 9
# Total of occurrences: 869
#
# Search with seed: VD_R_0000000042
#
# Number of occurrences found for the current seed: 7
# Total of occurrences: 876
#
# Search with seed: VD_R_0000000043
#
# Number of occurrences found for the current seed: 23
# Total of occurrences: 899
#
# Search with seed: VD_R_0000000044
#
# Number of occurrences found for the current seed: 33
# Total of occurrences: 932
#
# Search with seed: VD_R_0000000045
#
# Number of occurrences found for the current seed: 27
# Total of occurrences: 959
#
# Search with seed: VD_R_0000000046
#
# Number of occurrences found for the current seed: 21
# Total of occurrences: 980
#
# Search with seed: VD_R_0000000047
#
# Number of occurrences found for the current seed: 31
# Total of occurrences: 1011
#
# Search with seed: VD_R_0000000048
#
# Number of occurrences found for the current seed: 13
# Total of occurrences: 1024
#
# Search with seed: VD_R_0000000049
#
# Number of occurrences found for the current seed: 8
# Total of occurrences: 1032
#
# Search with seed: VD_R_0000000050
#
# Number of occurrences found for the current seed: 25
# Total of occurrences: 1057
#
# Search with seed: VD_R_0000000051
#
# Number of occurrences found for the current seed: 27
# Total of occurrences: 1084
#
# Search with seed: VD_R_0000000052
#
# Number of occurrences found for the current seed: 14
# Total of occurrences: 1098
#
# Search with seed: VD_R_0000000053
#
# Number of occurrences found for the current seed: 8
# Total of occurrences: 1106
#
# Search with seed: VD_R_0000000054
#
# Number of occurrences found for the current seed: 24
# Total of occurrences: 1130
#
# Search with seed: VD_R_0000000055
#
# Number of occurrences found for the current seed: 8
# Total of occurrences: 1138
#
# Search with seed: VD_R_0000000056
#
# Number of occurrences found for the current seed: 5
# Total of occurrences: 1143
#
# Search with seed: VD_R_0000000057
#
# Number of occurrences found for the current seed: 5
# Total of occurrences: 1148
#
# Search with seed: VD_R_0000000058
#
# Number of occurrences found for the current seed: 10
# Total of occurrences: 1158
#
# Search with seed: VD_R_0000000059
#
# Number of occurrences found for the current seed: 13
# Total of occurrences: 1171
#
# Search with seed: VD_R_0000000060
#
# Number of occurrences found for the current seed: 249
# Total of occurrences: 1420
#
# Search with seed: VD_R_0000000061
#
# Number of occurrences found for the current seed: 13
# Total of occurrences: 1433
#
# Search with seed: VD_R_0000000062
#
# Number of occurrences found for the current seed: 12
# Total of occurrences: 1445
#
# Search with seed: VD_R_0000000063
#
# Number of occurrences found for the current seed: 29
# Total of occurrences: 1474
#
# Search with seed: VD_R_0000000064
#
# Number of occurrences found for the current seed: 26
# Total of occurrences: 1500
#
# Search with seed: VD_R_0000000065
#
# Number of occurrences found for the current seed: 15
# Total of occurrences: 1515
#
# Search with seed: VD_R_0000000066
#
# Number of occurrences found for the current seed: 6
# Total of occurrences: 1521
#
# Search with seed: VD_R_0000000067
#
# Number of occurrences found for the current seed: 17
# Total of occurrences: 1538
#
# Search with seed: VD_R_0000000068
#
# Number of occurrences found for the current seed: 12
# Total of occurrences: 1550
#
# Search with seed: VD_R_0000000069
#
# Number of occurrences found for the current seed: 4
# Total of occurrences: 1554
#
# Search with seed: VD_R_0000000070
#
# Number of occurrences found for the current seed: 11
# Total of occurrences: 1565
#
# Search with seed: VD_R_0000000071
#
# Number of occurrences found for the current seed: 21
# Total of occurrences: 1586
#
# Search with seed: VD_R_0000000072
#
# Number of occurrences found for the current seed: 25
# Total of occurrences: 1611
#
# Search with seed: VD_R_0000000073
#
# Number of occurrences found for the current seed: 22
# Total of occurrences: 1633
#
# Search with seed: VD_R_0000000074
#
# Number of occurrences found for the current seed: 24
# Total of occurrences: 1657
#
# Search with seed: VD_R_0000000075
#
# Number of occurrences found for the current seed: 23
# Total of occurrences: 1680
#
# Search with seed: VD_R_0000000076
#
# Number of occurrences found for the current seed: 31
# Total of occurrences: 1711
#
# Search with seed: VD_R_0000000077
#
# Number of occurrences found for the current seed: 10
# Total of occurrences: 1721
#
# Search with seed: VD_R_0000000078
#
# Number of occurrences found for the current seed: 10
# Total of occurrences: 1731
#
# Search with seed: VD_R_0000000079
#
# Number of occurrences found for the current seed: 10
# Total of occurrences: 1741
#
# Search with seed: VD_R_0000000080
#
# Number of occurrences found for the current seed: 353
# Total of occurrences: 2094
#
# Search with seed: VD_R_0000000081
#
# Number of occurrences found for the current seed: 7
# Total of occurrences: 2101
#
# Search with seed: VD_R_0000000082
#
# Number of occurrences found for the current seed: 23
# Total of occurrences: 2124
#
# Search with seed: VD_R_0000000083
#
# Number of occurrences found for the current seed: 14
# Total of occurrences: 2138
#
# Search with seed: VD_R_0000000084
#
# Number of occurrences found for the current seed: 15
# Total of occurrences: 2153
#
# Search with seed: VD_R_0000000085
#
# Number of occurrences found for the current seed: 4
# Total of occurrences: 2157
#
# Search with seed: VD_R_0000000086
#
# Number of occurrences found for the current seed: 22
# Total of occurrences: 2179
#
# Search with seed: VD_R_0000000087
#
# Number of occurrences found for the current seed: 1
# Total of occurrences: 2180
#
# Search with seed: VD_R_0000000088
#
# Number of occurrences found for the current seed: 15
# Total of occurrences: 2195
#
# Search with seed: VD_R_0000000089
#
# Number of occurrences found for the current seed: 31
# Total of occurrences: 2226
#
# Search with seed: VD_R_0000000090
#
# Number of occurrences found for the current seed: 21
# Total of occurrences: 2247
#
# Search with seed: VD_R_0000000091
#
# Number of occurrences found for the current seed: 28
# Total of occurrences: 2275
#
# Search with seed: VD_R_0000000092
#
# Number of occurrences found for the current seed: 41
# Total of occurrences: 2316
#
# Search with seed: VD_R_0000000093
#
# Number of occurrences found for the current seed: 24
# Total of occurrences: 2340
#
# Search with seed: VD_R_0000000094
#
# Number of occurrences found for the current seed: 12
# Total of occurrences: 2352
#
# Search with seed: VD_R_0000000095
#
# Number of occurrences found for the current seed: 26
# Total of occurrences: 2378
#
# Search with seed: VD_R_0000000096
#
# Number of occurrences found for the current seed: 13
# Total of occurrences: 2391
#
# Search with seed: VD_R_0000000097
#
# Number of occurrences found for the current seed: 26
# Total of occurrences: 2417
#
# Search with seed: VD_R_0000000098
#
# Number of occurrences found for the current seed: 6
# Total of occurrences: 2423
#
# Search with seed: VD_R_0000000099
#
# Number of occurrences found for the current seed: 9
# Total of occurrences: 2432
#
# Search with seed: VD_R_0000000100
#
# Number of occurrences found for the current seed: 26
# Total of occurrences: 2458
#
# Search with seed: VD_R_0000000101
#
# Number of occurrences found for the current seed: 14
# Total of occurrences: 2472
#
# Search with seed: VD_R_0000000102
#
# Number of occurrences found for the current seed: 46
# Total of occurrences: 2518
#
# Search with seed: VD_R_0000000103
#
# Number of occurrences found for the current seed: 28
# Total of occurrences: 2546
#
# Search with seed: VD_R_0000000104
#
# Number of occurrences found for the current seed: 39
# Total of occurrences: 2585
#
# Search with seed: VD_R_0000000105
#
# Number of occurrences found for the current seed: 2
# Total of occurrences: 2587
#
# Search with seed: VD_R_0000000106
#
# Number of occurrences found for the current seed: 1
# Total of occurrences: 2588
#
# Search with seed: VD_R_0000000107
#
# Number of occurrences found for the current seed: 20
# Total of occurrences: 2608
#
# Search with seed: VD_R_0000000108
#
# Number of occurrences found for the current seed: 10
# Total of occurrences: 2618
#
# Search with seed: VD_R_0000000109
#
# Number of occurrences found for the current seed: 43
# Total of occurrences: 2661
#
# Search with seed: VD_R_0000000110
#
# Number of occurrences found for the current seed: 262
# Total of occurrences: 2923
#
# Search with seed: VD_R_0000000111
#
# Number of occurrences found for the current seed: 21
# Total of occurrences: 2944
#
# Search with seed: VD_R_0000000112
#
# Number of occurrences found for the current seed: 11
# Total of occurrences: 2955
#
# Search with seed: VD_R_0000000113
#
# Number of occurrences found for the current seed: 44
# Total of occurrences: 2999
#
# Search with seed: VD_R_0000000114
#
# Number of occurrences found for the current seed: 15
# Total of occurrences: 3014
#
# Search with seed: VD_R_0000000115
#
# Number of occurrences found for the current seed: 52
# Total of occurrences: 3066
#
# Search with seed: VD_R_0000000116
#
# Number of occurrences found for the current seed: 12
# Total of occurrences: 3078
#
# Search with seed: VD_R_0000000117
#
# Number of occurrences found for the current seed: 10
# Total of occurrences: 3088
#
# Search with seed: VD_R_0000000118
#
# Number of occurrences found for the current seed: 6
# Total of occurrences: 3094
#
# Search with seed: VD_R_0000000119
#
# Number of occurrences found for the current seed: 27
# Total of occurrences: 3121
#
# Search with seed: VD_R_0000000120
#
# Number of occurrences found for the current seed: 60
# Total of occurrences: 3181
#
# Search with seed: VD_R_0000000121
#
# Number of occurrences found for the current seed: 29
# Total of occurrences: 3210
#
# Search with seed: VD_R_0000000122
#
# Number of occurrences found for the current seed: 26
# Total of occurrences: 3236
#
# Search with seed: VD_R_0000000123
#
# Number of occurrences found for the current seed: 25
# Total of occurrences: 3261
#
# Search with seed: VD_R_0000000124
#
# Number of occurrences found for the current seed: 36
# Total of occurrences: 3297
#
# Search with seed: VD_R_0000000125
#
# Number of occurrences found for the current seed: 8
# Total of occurrences: 3305
#
# Search with seed: VD_R_0000000126
#
# Number of occurrences found for the current seed: 13
# Total of occurrences: 3318
#
# Search with seed: VD_R_0000000127
#
# Number of occurrences found for the current seed: 37
# Total of occurrences: 3355
#
# Search with seed: VD_R_0000000128
#
# Number of occurrences found for the current seed: 17
# Total of occurrences: 3372
#
# Search with seed: VD_R_0000000129
#
# Number of occurrences found for the current seed: 9
# Total of occurrences: 3381
#
# Search with seed: VD_R_0000000130
#
# Number of occurrences found for the current seed: 5
# Total of occurrences: 3386
#
# Search with seed: VD_R_0000000131
#
# Number of occurrences found for the current seed: 10
# Total of occurrences: 3396
#
# Search with seed: VD_R_0000000132
#
# Number of occurrences found for the current seed: 19
# Total of occurrences: 3415
#
# Search with seed: VD_R_0000000133
#
# Number of occurrences found for the current seed: 1
# Total of occurrences: 3416
#
# Search with seed: VD_R_0000000134
#
# Number of occurrences found for the current seed: 15
# Total of occurrences: 3431
#
# Search with seed: VD_R_0000000135
#
# Number of occurrences found for the current seed: 18
# Total of occurrences: 3449
#
# Search with seed: VD_R_0000000136
#
# Number of occurrences found for the current seed: 7
# Total of occurrences: 3456
#
# Search with seed: VD_R_0000000137
#
# Number of occurrences found for the current seed: 6
# Total of occurrences: 3462
#
# Search with seed: VD_R_0000000138
#
# Number of occurrences found for the current seed: 12
# Total of occurrences: 3474
#
# Search with seed: VD_R_0000000139
#
# Number of occurrences found for the current seed: 11
# Total of occurrences: 3485
#
# Search with seed: VD_R_0000000140
#
# Number of occurrences found for the current seed: 13
# Total of occurrences: 3498
#
# Search with seed: VD_R_0000000141
#
# Number of occurrences found for the current seed: 19
# Total of occurrences: 3517
#
# Search with seed: VD_R_0000000142
#
# Number of occurrences found for the current seed: 6
# Total of occurrences: 3523
#
# Search with seed: VD_R_0000000143
#
# Number of occurrences found for the current seed: 5
# Total of occurrences: 3528
#
# Search with seed: VD_R_0000000144
#
# Number of occurrences found for the current seed: 8
# Total of occurrences: 3536
#
# Search with seed: VD_R_0000000145
#
# Number of occurrences found for the current seed: 3
# Total of occurrences: 3539
#
# Search with seed: VD_R_0000000146
#
# Number of occurrences found for the current seed: 10
# Total of occurrences: 3549
#
# Search with seed: VD_R_0000000147
#
# Number of occurrences found for the current seed: 5
# Total of occurrences: 3554
#
# Search with seed: VD_R_0000000148
#
# Number of occurrences found for the current seed: 18
# Total of occurrences: 3572
#
# Search with seed: VD_R_0000000149
#
# Number of occurrences found for the current seed: 2
# Total of occurrences: 3574
#
# Search with seed: VD_R_0000000150
#
# Number of occurrences found for the current seed: 11
# Total of occurrences: 3585
#
# Search with seed: VD_R_0000000151
#
# Number of occurrences found for the current seed: 2
# Total of occurrences: 3587
#
# Search with seed: VD_R_0000000152
#
# Number of occurrences found for the current seed: 9
# Total of occurrences: 3596
#
# Search with seed: VD_R_0000000153
#
# Number of occurrences found for the current seed: 14
# Total of occurrences: 3610
#
# Search with seed: VD_R_0000000154
#
# Number of occurrences found for the current seed: 20
# Total of occurrences: 3630
#
# Search with seed: VD_R_0000000155
#
# Number of occurrences found for the current seed: 19
# Total of occurrences: 3649
#
# Search with seed: VD_R_0000000156
#
# Number of occurrences found for the current seed: 1
# Total of occurrences: 3650
#
# Search with seed: VD_R_0000000157
#
# Number of occurrences found for the current seed: 9
# Total of occurrences: 3659
#
# Search with seed: VD_R_0000000158
#
# Number of occurrences found for the current seed: 7
# Total of occurrences: 3666
#
# Search with seed: VD_R_0000000159
#
# Number of occurrences found for the current seed: 4
# Total of occurrences: 3670
#
# Search with seed: VD_R_0000000160
#
# Number of occurrences found for the current seed: 4
# Total of occurrences: 3674
#
# Search with seed: VD_R_0000000161
#
# Number of occurrences found for the current seed: 26
# Total of occurrences: 3700
#
# Search with seed: VD_R_0000000162
#
# Number of occurrences found for the current seed: 13
# Total of occurrences: 3713
#
# Search with seed: VD_R_0000000163
#
# Number of occurrences found for the current seed: 2
# Total of occurrences: 3715
#
# Search with seed: VD_R_0000000164
#
# Number of occurrences found for the current seed: 12
# Total of occurrences: 3727
#
# Search with seed: VD_R_0000000165
#
# Number of occurrences found for the current seed: 15
# Total of occurrences: 3742
#
# Search with seed: VD_R_0000000166
#
# Number of occurrences found for the current seed: 6
# Total of occurrences: 3748
#
# Search with seed: VD_R_0000000167
#
# Number of occurrences found for the current seed: 11
# Total of occurrences: 3759
#
# Search with seed: VD_R_0000000168
#
# Number of occurrences found for the current seed: 2
# Total of occurrences: 3761
#
# Search with seed: VD_R_0000000169
#
# Number of occurrences found for the current seed: 7
# Total of occurrences: 3768
#
# Search with seed: VD_R_0000000170
#
# Number of occurrences found for the current seed: 5
# Total of occurrences: 3773
#
# Search with seed: VD_R_0000000171
#
# Number of occurrences found for the current seed: 4
# Total of occurrences: 3777
#
# Search with seed: VD_R_0000000172
#
# Number of occurrences found for the current seed: 2
# Total of occurrences: 3779
#
# Search with seed: VD_R_0000000173
#
# Number of occurrences found for the current seed: 0
# Total of occurrences: 3779
#
# Search with seed: VD_R_0000000174
#
# Number of occurrences found for the current seed: 8
# Total of occurrences: 3787
#
# Search with seed: VD_R_0000000175
#
# Number of occurrences found for the current seed: 19
# Total of occurrences: 3806
#
# Search with seed: VD_R_0000000176
#
# Number of occurrences found for the current seed: 6
# Total of occurrences: 3812
#
# Search with seed: VD_R_0000000177
#
# Number of occurrences found for the current seed: 11
# Total of occurrences: 3823
#
# Search with seed: VD_R_0000000178
#
# Number of occurrences found for the current seed: 13
# Total of occurrences: 3836
#
# Search with seed: VD_R_0000000179
#
# Number of occurrences found for the current seed: 13
# Total of occurrences: 3849
#
# Search with seed: VD_R_0000000180
#
# Number of occurrences found for the current seed: 5
# Total of occurrences: 3854
#
# Search with seed: VD_R_0000000181
#
# Number of occurrences found for the current seed: 5
# Total of occurrences: 3859
#
# Search with seed: VD_R_0000000182
#
# Number of occurrences found for the current seed: 0
# Total of occurrences: 3859
#
# Search with seed: VD_R_0000000183
#
# Number of occurrences found for the current seed: 4
# Total of occurrences: 3863
#
# Search with seed: VD_R_0000000184
#
# Number of occurrences found for the current seed: 7
# Total of occurrences: 3870
#
# Search with seed: VD_R_0000000185
#
# Number of occurrences found for the current seed: 7
# Total of occurrences: 3877
#
# Search with seed: VD_R_0000000186
#
# Number of occurrences found for the current seed: 7
# Total of occurrences: 3884
#
# Search with seed: VD_R_0000000187
#
# Number of occurrences found for the current seed: 4
# Total of occurrences: 3888
#
# Search with seed: VD_R_0000000188
#
# Number of occurrences found for the current seed: 0
# Total of occurrences: 3888
#
# Search with seed: VD_R_0000000189
#
# Number of occurrences found for the current seed: 2
# Total of occurrences: 3890
#
# Search with seed: VD_R_0000000190
#
# Number of occurrences found for the current seed: 1
# Total of occurrences: 3891
#
# Search with seed: VD_R_0000000191
#
# Number of occurrences found for the current seed: 0
# Total of occurrences: 3891
#
# Search with seed: VD_R_0000000192
#
# Number of occurrences found for the current seed: 0
# Total of occurrences: 3891
#
# Search with seed: VD_R_0000000193
#
# Number of occurrences found for the current seed: 1
# Total of occurrences: 3892
#
# Search with seed: VD_R_0000000194
#
# Number of occurrences found for the current seed: 4
# Total of occurrences: 3896
#
# Search with seed: VD_R_0000000195
#
# Number of occurrences found for the current seed: 0
# Total of occurrences: 3896
#
# Search with seed: VD_R_0000000196
#
# Number of occurrences found for the current seed: 2
# Total of occurrences: 3898
#
# Search with seed: VD_R_0000000197
#
# Number of occurrences found for the current seed: 2
# Total of occurrences: 3900
#
# Search with seed: VD_R_0000000198
#
# Number of occurrences found for the current seed: 1
# Total of occurrences: 3901
#
# Search with seed: VD_R_0000000199
#
# Number of occurrences found for the current seed: 2
# Total of occurrences: 3903
#
# Search with seed: VD_R_0000000200
#
# Number of occurrences found for the current seed: 1
# Total of occurrences: 3904
#
# Search with seed: VD_R_0000000201
#
# Number of occurrences found for the current seed: 2
# Total of occurrences: 3906
#
# Search with seed: VD_R_0000000202
#
# Number of occurrences found for the current seed: 8
# Total of occurrences: 3914
#
# Search with seed: VD_R_0000000203
#
# Number of occurrences found for the current seed: 2
# Total of occurrences: 3916
#
# Search with seed: VD_R_0000000204
#
# Number of occurrences found for the current seed: 1
# Total of occurrences: 3917
#
# Search with seed: VD_R_0000000205
#
# Number of occurrences found for the current seed: 3
# Total of occurrences: 3920
#
# Search with seed: VD_R_0000000206
#
# Number of occurrences found for the current seed: 19
# Total of occurrences: 3939
#
# Search with seed: VD_R_0000000207
#
# Number of occurrences found for the current seed: 0
# Total of occurrences: 3939
#
# Search with seed: VD_R_0000000208
#
# Number of occurrences found for the current seed: 0
# Total of occurrences: 3939
#
# Search with seed: VD_R_0000000209
#
# Number of occurrences found for the current seed: 11
# Total of occurrences: 3950
#
# Search with seed: VD_R_0000000210
#
# Number of occurrences found for the current seed: 16
# Total of occurrences: 3966
#
# Search with seed: VD_R_0000000211
#
# Number of occurrences found for the current seed: 12
# Total of occurrences: 3978
#
# Search with seed: VD_R_0000000212
#
# Number of occurrences found for the current seed: 4
# Total of occurrences: 3982
#
# Search with seed: VD_R_0000000213
#
# Number of occurrences found for the current seed: 21
# Total of occurrences: 4003
#
# Search with seed: VD_R_0000000214
#
# Number of occurrences found for the current seed: 12
# Total of occurrences: 4015
#
# Search with seed: VD_R_0000000215
#
# Number of occurrences found for the current seed: 5
# Total of occurrences: 4020
#
# Search with seed: VD_R_0000000216
#
# Number of occurrences found for the current seed: 9
# Total of occurrences: 4029
#
# Search with seed: VD_R_0000000217
#
# Number of occurrences found for the current seed: 6
# Total of occurrences: 4035
#
# Search with seed: VD_R_0000000218
#
# Number of occurrences found for the current seed: 10
# Total of occurrences: 4045
#
# Search with seed: VD_R_0000000219
#
# Number of occurrences found for the current seed: 1
# Total of occurrences: 4046
#
# Search with seed: VD_R_0000000220
#
# Number of occurrences found for the current seed: 5
# Total of occurrences: 4051
#
# Search with seed: VD_R_0000000221
#
# Number of occurrences found for the current seed: 2
# Total of occurrences: 4053
#
# Search with seed: VD_R_0000000222
#
# Number of occurrences found for the current seed: 2
# Total of occurrences: 4055
#
# Search with seed: VD_R_0000000223
#
# Number of occurrences found for the current seed: 2
# Total of occurrences: 4057
#
# Search with seed: VD_R_0000000224
#
# Number of occurrences found for the current seed: 2
# Total of occurrences: 4059
#
# Search with seed: VD_R_0000000225
#
# Number of occurrences found for the current seed: 2
# Total of occurrences: 4061
#
# Search with seed: VD_R_0000000226
#
# Number of occurrences found for the current seed: 3
# Total of occurrences: 4064
#
# Search with seed: VD_R_0000000227
#
# Number of occurrences found for the current seed: 4
# Total of occurrences: 4068
#
# Search with seed: VD_R_0000000228
#
# Number of occurrences found for the current seed: 24
# Total of occurrences: 4092
#
# Search with seed: VD_R_0000000229
#
# Number of occurrences found for the current seed: 8
# Total of occurrences: 4100
#
# Search with seed: VD_R_0000000230
#
# Number of occurrences found for the current seed: 12
# Total of occurrences: 4112
#
# Search with seed: VD_R_0000000231
#
# Number of occurrences found for the current seed: 1
# Total of occurrences: 4113
#
# Search with seed: VD_R_0000000232
#
# Number of occurrences found for the current seed: 7
# Total of occurrences: 4120
#
# Search with seed: VD_R_0000000233
#
# Number of occurrences found for the current seed: 9
# Total of occurrences: 4129
#
# Search with seed: VD_R_0000000234
#
# Number of occurrences found for the current seed: 6
# Total of occurrences: 4135
#
# Search with seed: VD_R_0000000235
#
# Number of occurrences found for the current seed: 3
# Total of occurrences: 4138
#
# Search with seed: VD_R_0000000236
#
# Number of occurrences found for the current seed: 5
# Total of occurrences: 4143
#
# Search with seed: VD_R_0000000237
#
# Number of occurrences found for the current seed: 12
# Total of occurrences: 4155
#
# Search with seed: VD_R_0000000238
#
# Number of occurrences found for the current seed: 4
# Total of occurrences: 4159
#
# Search with seed: VD_R_0000000239
#
# Number of occurrences found for the current seed: 6
# Total of occurrences: 4165
#
# Search with seed: VD_R_0000000240
#
# Number of occurrences found for the current seed: 7
# Total of occurrences: 4172
#
# Search with seed: VD_R_0000000241
#
# Number of occurrences found for the current seed: 9
# Total of occurrences: 4181
#
# Search with seed: VD_R_0000000242
#
# Number of occurrences found for the current seed: 3
# Total of occurrences: 4184
#
# Search with seed: VD_R_0000000243
#
# Number of occurrences found for the current seed: 3
# Total of occurrences: 4187
#
# Search with seed: VD_R_0000000244
#
# Number of occurrences found for the current seed: -2
# Total of occurrences: 4185
#
# Search with seed: VD_R_0000000245
#
# Number of occurrences found for the current seed: 3
# Total of occurrences: 4188
#
# Search with seed: VD_R_0000000246
#
# Number of occurrences found for the current seed: 5
# Total of occurrences: 4193
#
# Search with seed: VD_R_0000000247
#
# Number of occurrences found for the current seed: 4
# Total of occurrences: 4197
#
# Search with seed: VD_R_0000000248
#
# Number of occurrences found for the current seed: 6
# Total of occurrences: 4203
#
# Search with seed: VD_R_0000000249
#
# Number of occurrences found for the current seed: 8
# Total of occurrences: 4211
#
# Search with seed: VD_R_0000000250
#
# Number of occurrences found for the current seed: 3
# Total of occurrences: 4214
#
# Search with seed: VD_R_0000000251
#
# Number of occurrences found for the current seed: 11
# Total of occurrences: 4225
#
# Search with seed: VD_R_0000000252
#
# Number of occurrences found for the current seed: 9
# Total of occurrences: 4234
#
# Search with seed: VD_R_0000000253
#
# Number of occurrences found for the current seed: 6
# Total of occurrences: 4240
#
# Search with seed: VD_R_0000000254
#
# Number of occurrences found for the current seed: 5
# Total of occurrences: 4245
#
# Search with seed: VD_R_0000000255
#
# Number of occurrences found for the current seed: 7
# Total of occurrences: 4252
#
# Search with seed: VD_R_0000000256
#
# Number of occurrences found for the current seed: 4
# Total of occurrences: 4256
#
# Search with seed: VD_R_0000000257
#
# Number of occurrences found for the current seed: 1
# Total of occurrences: 4257
#
# Search with seed: VD_R_0000000258
#
# Number of occurrences found for the current seed: 8
# Total of occurrences: 4265
#
# Search with seed: VD_R_0000000259
#
# Number of occurrences found for the current seed: 0
# Total of occurrences: 4265
#
# Search with seed: VD_R_0000000260
#
# Number of occurrences found for the current seed: 11
# Total of occurrences: 4276
#
# Search with seed: VD_R_0000000261
#
# Number of occurrences found for the current seed: 8
# Total of occurrences: 4284
#
# Search with seed: VD_R_0000000262
#
# Number of occurrences found for the current seed: 7
# Total of occurrences: 4291
#
# Search with seed: VD_R_0000000263
#
# Number of occurrences found for the current seed: 8
# Total of occurrences: 4299
#
# Search with seed: VD_R_0000000264
#
# Number of occurrences found for the current seed: 18
# Total of occurrences: 4317
#
# Search with seed: VD_R_0000000265
#
# Number of occurrences found for the current seed: 8
# Total of occurrences: 4325
#
# Search with seed: VD_R_0000000266
#
# Number of occurrences found for the current seed: 12
# Total of occurrences: 4337
#
# Search with seed: VD_R_0000000267
#
# Number of occurrences found for the current seed: 7
# Total of occurrences: 4344
#
# Search with seed: VD_R_0000000268
#
# Number of occurrences found for the current seed: 12
# Total of occurrences: 4356
#
# Search with seed: VD_R_0000000269
#
# Number of occurrences found for the current seed: 12
# Total of occurrences: 4368
#
# Search with seed: VD_R_0000000270
#
# Number of occurrences found for the current seed: 2
# Total of occurrences: 4370
#
# Search with seed: VD_R_0000000271
#
# Number of occurrences found for the current seed: 0
# Total of occurrences: 4370
#
# Search with seed: VD_R_0000000272
#
# Number of occurrences found for the current seed: 2
# Total of occurrences: 4372
#
# Search with seed: VD_R_0000000273
#
# Number of occurrences found for the current seed: 0
# Total of occurrences: 4372
#
# Search with seed: VD_R_0000000274
#
# Number of occurrences found for the current seed: 6
# Total of occurrences: 4378
#
# Search with seed: VD_R_0000000275
#
# Number of occurrences found for the current seed: 5
# Total of occurrences: 4383
#
# Search with seed: VD_R_0000000276
#
# Number of occurrences found for the current seed: 4
# Total of occurrences: 4387
#
# Search with seed: VD_R_0000000277
#
# Number of occurrences found for the current seed: 8
# Total of occurrences: 4395
#
# Search with seed: VD_R_0000000278
#
# Number of occurrences found for the current seed: 22
# Total of occurrences: 4417
#
# Search with seed: VD_R_0000000279
#
# Number of occurrences found for the current seed: 0
# Total of occurrences: 4417
#
# Search with seed: VD_R_0000000280
#
# Number of occurrences found for the current seed: 4
# Total of occurrences: 4421

# %%
current_labeling_class_others = 0  # Este valor será ajustado dinamicamente com base na presença de "others"
frame_distance_threshold_others = 2
euclidean_distance_threshold_others = 1.2
current_total_saved_series_others = 0

matches_memory_others = []
all_matches_memory_others = []
all_mass_memory_others = []
all_idxs_match_frame_seq_memory_others = []
all_seeds_occurrences_len_others = []

all_data_memory_others = []

for j_others, labeled_file_others in enumerate(FILE_LIST_LABELED_SEED[:]):
    RESUME_DT_others = pd.DataFrame()

    # Carregar o DataFrame rotulado
    path_dir_others = os.path.dirname(labeled_file_others)
    vd_labeled_path_others = os.path.join(path_dir_others, fp.VD_LABELED_L0)
    vd_labeled_others = pd.read_csv(vd_labeled_path_others)
    vd_labeled_others.drop(columns=['Unnamed: 0'], inplace=True)

    # Obter todas as classes disponíveis na seed
    all_class_others = man_lab_fun.GET_ALL_CLASSES(vd_labeled_others)

    # Verificar se a classe "others" está presente
    if "others" not in all_class_others:
        print(f"Skipping seed: {os.path.basename(os.path.dirname(labeled_file_others))} (class 'others' not found)")
        continue

    # Ajustar o índice para a classe "others"
    current_labeling_class_others = all_class_others.index("others")
    label_name_others = all_class_others[current_labeling_class_others]

    print(f'\nProcessing seed: {os.path.basename(os.path.dirname(labeled_file_others))} with class "others"\n')

    current_seed_matches_memory_others = []
    current_seed_all_matches_memory_others = []
    current_seed_all_mass_memory_others = []
    current_seed_data_memory_others = []

    for i_others, current_path_location_others in enumerate(FILE_LIST_VD_MEASURE):
        # Obter as medidas e os frames associados à classe "others"
        reference_measures_others = man_lab_fun.GET_MEASURES_FROM_CLASS(vd_labeled_others, label_name_others)
        frames_others = man_lab_fun.GET_FRAMES_FROM_CLASS(vd_labeled_others, label_name_others)

        # Selecionar os frames de interesse e medidas correspondentes
        all_measures_in_frame_interval_others = vd_labeled_others.loc[0:len(frames_others)]
        selected_measures_in_frame_interval_others = all_measures_in_frame_interval_others[reference_measures_others]

        dict_label_parameters_others = {'label_name': label_name_others, 'reference_measures': reference_measures_others}

        # Processar a série atual
        RESUME_DT_others, matches_others, all_matches_others, all_mass_others, idxs_match_frame_seq_others, occurrences_len_others = aut_lab_fun.label_current_series(
            current_path_location_others, RESUME_DT_others, selected_measures_in_frame_interval_others, dict_label_parameters_others, 
            os.path.dirname(labeled_file_others), LABELED_FILE_NAME="VD_LABELED_L0_OTHERS",  # Nome do arquivo ajustado
            distance_threshold=euclidean_distance_threshold_others, frame_threshold=frame_distance_threshold_others
        )

        # Armazenar os resultados
        current_seed_data_memory_others.append([])

        for k_others, (frame_others, dist_others) in enumerate(idxs_match_frame_seq_others):
            frame_dist_len_data_others = []
            frame_dist_len_data_others.append(frame_others)
            frame_dist_len_data_others.append(dist_others)
            frame_dist_len_data_others.append(occurrences_len_others[k_others])

            current_seed_data_memory_others[i_others].append(frame_dist_len_data_others)

    all_data_memory_others.append(current_seed_data_memory_others)

    final_sum_others = RESUME_DT_others['final'].sum()
    current_total_saved_series_others += final_sum_others
    print(f'Number of occurrences found for the current seed: {final_sum_others}')
    print(f'Total of occurrences: {current_total_saved_series_others}')

# %% [markdown]
# ## True matches

# %%
number_irregulars = 0
for i, seed in enumerate(all_data_memory):
    #print(f"=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-= Seed {i+1} =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=")
    for j, video in enumerate(seed):
        #print(f" =-=-=-=-=-= Video: {j+1}, number of occurrences: {len(video)} =-=-=-=-=-=")
        for occurrence in video:
            if occurrence[2] != 30:
                #print(f"Frame start: {occurrence[0]}, euclidean_dist: {occurrence[1]}, len occurrence: {occurrence[2]}")
                print(f"Seed: {i+1}, Video: {j+1}, Frame start: {occurrence[0]}, euclidean_dist: {occurrence[1]}, len occurrence: {occurrence[2]}")
                number_irregulars += 1
print("Number irregulars:", number_irregulars)
